# %%
import pandas as pd

df = pd.read_csv('./data/auto-mpg.csv')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df = pd.read_csv('./data/auto-mpg.csv', header=None)
df
# Out:
#        0          1             2           3       4             5  \
# 0    mpg  cylinders  displacement  horsepower  weight  acceleration
# 1     18          8           307         130    3504            12
# 2     15          8           350         165    3693          11.5
# 3     18          8           318         150    3436            11
# 4     16          8           304         150    3433            12
# ..   ...        ...           ...         ...     ...           ...
# 394   27          4           140          86    2790          15.6
# 395   44          4            97          52    2130          24.6
# 396   32          4           135          84    2295          11.6
# 397   28          4           120          79    2625          18.6
# 398   31          4           119          82    2720          19.4
#
#               6       7                          8
# 0    model year  origin                   car name
# ...

# %%
df.drop(0,inplace=True)

# %%
df
# Out:
#       0  1    2    3     4     5   6  7                          8
# 1    18  8  307  130  3504    12  70  1  chevrolet chevelle malibu
# 2    15  8  350  165  3693  11.5  70  1          buick skylark 320
# 3    18  8  318  150  3436    11  70  1         plymouth satellite
# 4    16  8  304  150  3433    12  70  1              amc rebel sst
# 5    17  8  302  140  3449  10.5  70  1                ford torino
# ..   .. ..  ...  ...   ...   ...  .. ..                        ...
# 394  27  4  140   86  2790  15.6  82  1            ford mustang gl
# 395  44  4   97   52  2130  24.6  82  2                  vw pickup
# 396  32  4  135   84  2295  11.6  82  1              dodge rampage
# 397  28  4  120   79  2625  18.6  82  1                ford ranger
# 398  31  4  119   82  2720  19.4  82  1                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# 열이름 지정 : 연비 , 실린더수, 배기량, 출력, 차중, 가속능력, 출시년도 , 제조국, 모델명

# %%
df.columns = ['연비' , '실린더수', '배기량', '출력', '차중', '가속능력', '출시년도', '제조국', '모델명']
df.head()
# Out:
#    연비 실린더수  배기량   출력    차중  가속능력 출시년도 제조국                        모델명
# 1  18    8  307  130  3504    12   70   1  chevrolet chevelle malibu
# 2  15    8  350  165  3693  11.5   70   1          buick skylark 320
# 3  18    8  318  150  3436    11   70   1         plymouth satellite
# 4  16    8  304  150  3433    12   70   1              amc rebel sst
# 5  17    8  302  140  3449  10.5   70   1                ford torino

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 398 entries, 1 to 398
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연비      398 non-null    object
#  1   실린더수    398 non-null    object
#  2   배기량     398 non-null    object
#  3   출력      398 non-null    object
#  4   차중      398 non-null    object
#  5   가속능력    398 non-null    object
#  6   출시년도    398 non-null    object
#  7   제조국     398 non-null    object
#  8   모델명     398 non-null    object
# dtypes: object(9)
# memory usage: 31.1+ KB

# %%
df = df.astype({'연비' : float , '실린더수':int , '배기량':float , '출력':float , '차중' :float , '가속능력':float, '출시년도':int , '제조국':int})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-9617a71f7c9a> in <module>
# ----> 1 df = df.astype({'연비' : float , '실린더수':int , '배기량':float , '출력':float , '차중' :float , '가속능력':float, '출시년도':int , '제조국':int})
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5860                 if col_name in dtype:
#    5861                     results.append(
# -> 5862                         col.astype(dtype=dtype[col_name], copy=copy, errors=errors)
#    5863                     )
#    5864                 else:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
# ...

# %%
for temp in df.columns:
    df[temp] = df[temp].str.replace('?','0')
# Out:
# <ipython-input-12-5d73ca9ebb65>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df[temp] = df[temp].str.replace('?','0')

# %%
df = df.astype({'연비' : float , '실린더수':int , '배기량':float , '출력':float , '차중' :float , '가속능력':float, '출시년도':int , '제조국':int})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 398 entries, 1 to 398
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연비      398 non-null    float64
#  1   실린더수    398 non-null    int32
#  2   배기량     398 non-null    float64
#  3   출력      398 non-null    float64
#  4   차중      398 non-null    float64
#  5   가속능력    398 non-null    float64
#  6   출시년도    398 non-null    int32
#  7   제조국     398 non-null    int32
#  8   모델명     398 non-null    object
# dtypes: float64(5), int32(3), object(1)
# memory usage: 26.4+ KB

# %%
df.describe()
# Out:
#                연비        실린더수         배기량          출력           차중  \
# count  398.000000  398.000000  398.000000  398.000000   398.000000
# mean    23.514573    5.454774  193.425879  102.894472  2970.424623
# std      7.815984    1.701004  104.269838   40.269544   846.841774
# min      9.000000    3.000000   68.000000    0.000000  1613.000000
# 25%     17.500000    4.000000  104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000  148.500000   92.000000  2803.500000
# 75%     29.000000    8.000000  262.000000  125.000000  3608.000000
# max     46.600000    8.000000  455.000000  230.000000  5140.000000
#
#              가속능력        출시년도         제조국
# count  398.000000  398.000000  398.000000
# mean    15.568090   76.010050    1.572864
# std      2.757689    3.697627    0.802055
# min      8.000000   70.000000    1.000000
# 25%     13.825000   73.000000    1.000000
# 50%     15.500000   76.000000    1.000000
# 75%     17.175000   79.000000    2.000000
# ...

# %%
df.count()
# Out:
# 연비      398
# 실린더수    398
# 배기량     398
# 출력      398
# 차중      398
# 가속능력    398
# 출시년도    398
# 제조국     398
# 모델명     398
# dtype: int64

# %%
df.mean()
# Out:
# 연비        23.514573
# 실린더수       5.454774
# 배기량      193.425879
# 출력       102.894472
# 차중      2970.424623
# 가속능력      15.568090
# 출시년도      76.010050
# 제조국        1.572864
# dtype: float64

# %%
df['연비'].mean()
# Out:
# 23.514572864321615

# %%
df[['연비','차중']].mean()
# Out:
# 연비      23.514573
# 차중    2970.424623
# dtype: float64

# %%
#중간값
df.median()
# Out:
# 연비        23.0
# 실린더수       4.0
# 배기량      148.5
# 출력        92.0
# 차중      2803.5
# 가속능력      15.5
# 출시년도      76.0
# 제조국        1.0
# dtype: float64

# %%
df.연비.median()
# Out:
# 23.0

# %%
df['연비'].median()
# Out:
# 23.0

# %%
df.max()
# Out:
# 연비                  46.6
# 실린더수                   8
# 배기량                455.0
# 출력                 230.0
# 차중                5140.0
# 가속능력                24.8
# 출시년도                  82
# 제조국                    3
# 모델명     vw rabbit custom
# dtype: object

# %%
df.min()
# Out:
# 연비                          9.0
# 실린더수                          3
# 배기량                        68.0
# 출력                          0.0
# 차중                       1613.0
# 가속능력                        8.0
# 출시년도                         70
# 제조국                           1
# 모델명     amc ambassador brougham
# dtype: object

# %%
df.std()
# Out:
# 연비        7.815984
# 실린더수      1.701004
# 배기량     104.269838
# 출력       40.269544
# 차중      846.841774
# 가속능력      2.757689
# 출시년도      3.697627
# 제조국       0.802055
# dtype: float64

# %%
for temp in df.columns:
    try:
        df[temp] = df[temp].str.replace('?','0')
    except:
        print("오류났어요" + temp)
# Out:
# 오류났어요연비
# 오류났어요실린더수
# 오류났어요배기량
# 오류났어요출력
# 오류났어요차중
# 오류났어요가속능력
# 오류났어요출시년도
# 오류났어요제조국
# <ipython-input-30-bf9116e16d0d>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df[temp] = df[temp].str.replace('?','0')

# %%
df.corr()
# Out:
#             연비      실린더수       배기량        출력        차중      가속능력      출시년도  \
# 연비    1.000000 -0.775396 -0.804203 -0.754276 -0.831741  0.420289  0.579267
# 실린더수 -0.775396  1.000000  0.950721  0.821656  0.896017 -0.505419 -0.348746
# 배기량  -0.804203  0.950721  1.000000  0.871927  0.932824 -0.543684 -0.370164
# 출력   -0.754276  0.821656  0.871927  1.000000  0.837987 -0.673940 -0.411587
# 차중   -0.831741  0.896017  0.932824  0.837987  1.000000 -0.417457 -0.306564
# 가속능력  0.420289 -0.505419 -0.543684 -0.673940 -0.417457  1.000000  0.288137
# 출시년도  0.579267 -0.348746 -0.370164 -0.411587 -0.306564  0.288137  1.000000
# 제조국   0.563450 -0.562543 -0.609409 -0.418636 -0.581024  0.205873  0.180662
#
#            제조국
# 연비    0.563450
# 실린더수 -0.562543
# 배기량  -0.609409
# 출력   -0.418636
# 차중   -0.581024
# 가속능력  0.205873
# 출시년도  0.180662
# 제조국   1.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import matplotlib
import platform
if platform.system() == 'Windows': 
    matplotlib.rc('font', family='Malgun Gothic')

# %%
import seaborn as sns
colormap = plt.cm.PuBu
plt.figure(figsize=(10,8))
plt.title("자동차 상관관계 분석", y=1.05 , size = 15)
sns.heatmap(df.corr() , linewidths = 0.1 , vmax = 1.0 , square = True, linecolor="white" , annot=True, annot_kws={"size":16}  )
# Out:
# <AxesSubplot:title={'center':'자동차 상관관계 분석'}>
