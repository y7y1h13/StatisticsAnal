# %%
import seaborn as sns

anscombe = sns.load_dataset('anscombe')
print(anscombe)
print(type(anscombe))
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
# 그리기 임포트
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
dataset_1 = anscombe[anscombe['dataset'] == 'I'] #dataset이 I인 것만 추출

# %%
plt.plot(dataset_1['x'], dataset_1['y']) # (x, y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(dataset_1['x'], dataset_1['y'],'o') # o는 점을 나타낸다.
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### 1. 전체 그래프가 위치할 기본 틀을 만든다.
# ### 2. 그래프를 그려 넣을 그래프 격자를 만든다.
# ### 3. 격자에 그래프를 하나씩 추가한다. 그래프 추가되는 순서는 왼쪽부터
# ### 4. 격자의 첫 번째 행이 꽉 차면 두 번째 행에 그래프를 그려 넣는다.

# %%
dataset_2 = anscombe[anscombe['dataset'] == 'II']
dataset_3 = anscombe[anscombe['dataset'] == 'III']
dataset_4 = anscombe[anscombe['dataset'] == 'IV']#데이터 저장

# %%
fig = plt.figure()#기본틀
axes1 = fig.add_subplot(2, 2, 1)
axes2 = fig.add_subplot(2, 2, 2)
axes3 = fig.add_subplot(2, 2, 3)
axes4 = fig.add_subplot(2, 2, 4)
# 가로, 세로, 위치


axes1.plot(dataset_1['x'], dataset_1['y'],'o')
axes2.plot(dataset_2['x'], dataset_2['y'],'o')
axes3.plot(dataset_3['x'], dataset_3['y'],'o')
axes4.plot(dataset_4['x'], dataset_4['y'],'o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axes1.set_title('dataset_1')
axes2.set_title('dataset_2')
axes3.set_title('dataset_3')
axes4.set_title('dataset_4')
#제목
fig
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig.suptitle('Anscombe Data') # 큰 제목
fig
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig.tight_layout()# 레이아웃 조절
fig
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### 다양한 그래프

# %%
import seaborn as sns
tips = sns.load_dataset('tips')
# 그리기 임포트
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
print(tips)
print(type(tips))
#지불 금액, 팁, 성별, 흡연 유무, 요일, 시간, 전체 인원 정보
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# <class 'pandas.core.frame.DataFrame'>

# %%
#히스토그램은 데이터프레임의 열 데이터 분포와 빈도를 살펴보는 용도로 사용

# %%
# 틀과 격자 생성
fig = plt.figure()
axes1 = fig.add_subplot(1,1,1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axes1.hist(tips['total_bill'],bins=10) #bins=10,x축 간격을 10으로 조정(도수분포표) / 0~10, 10~15, 15~20, 25~30....
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Frequency')
axes1.set_ylabel('Total Bill')
fig
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### 산점도 그래프
# ### 산점도 그래프는 변수 2개 사용, 이변량 그래프

# %%
#산점도 그래프
#산점도 그래프는 변수 2개를 이용함
#두 변수의 상관 관계
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(tips['total_bill'],tips['tip'])
axes1.set_title('Scatterplot of Total Bill vs Tip')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Tip')

# %% [markdown]
# ### 박스 그래프
# ### 이산형 변수와 연속형 변수 함께 사용
# ### 이상형이란 남,여 처럼 명확하게 구분
# ### 연속형은 명확하게 셀 수 없는 범위

# %%
boxplot = plt.figure()
axes1 = boxplot.add_subplot(1,1,1)
axes1.boxplot([tips[tips['sex'] == 'Female']['tip'],
              tips[tips['sex'] == 'Male']['tip']],
             labels=['Female', 'Male'])

axes1.set_xlabel('Sex')
axes1.set_ylabel('Tip')
axes1.set_title('Boxplot of Tips by Sex')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %% [markdown]
# ### 다변량 그래프
# ### 변수 여러개를 이용하여 그리기 위해

# %%
#성별은 문자열데이터, 하지만 그래프에서는 문자열 못씀 / 함수로 만들어서 여자면 0 남자면 1로 해준다.
def recode_sex(sex):
    if sex == 'Female':
        return 0
    else:
        return 1

# %%
tips['sex_color'] = tips['sex'].apply(recode_sex)

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(
    x=tips['total_bill'],
    y=tips['tip'],
    s=tips['size']*10, #점의 크기(전체인원 정보에 따라서 점의 크기를 변환)
    c=tips['sex_color'], #점의 색상(0, 1에 따라서 색이 바뀐다)
    alpha=0.5)# 투명도 0.5

axes1.set_title('Total Bill vs Tip Colored by Sex and Sized by Size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.

# %% [markdown]
# ### seaborn 라이브러리 활용하기

# %%
import seaborn as sns

tips = sns.load_dataset('tips')

# %%
ax = plt.subplots()#기본 틀 만들기
ax = sns.distplot(tips['total_bill'])#열데이터 전달
ax.set_title('Total Bill Histogram with Density Plot')
# Out:
# <img src="data:image/png;base64,..." width="640">
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Total Bill Histogram with Density Plot')

# %%
#위에서 보면 distplot를 사용하면 히스토그램과 밀집도 그래프를 같이 그린다.
#밀집도 그래프는 주어진 데이터를 정규화시켜 넓이가 1이 되도록 그린 그래프
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'],kde=False)
ax.set_title('Total Bill Histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')
# Out:
# <img src="data:image/png;base64,..." width="640">
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Frequency')

# %%
#밀집도 그래프만 나타내기
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], hist=False)
ax.set_title('Total Bill Density')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Unit Probability')
# Out:
# <img src="data:image/png;base64,..." width="640">
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Unit Probability')

# %%
# 그래프 세개 한번에 그리기
# 양탄자 그래프는 그래프의 축에 동일한 길이의 직선을 붙여 데이터의 밀집 정도를 표현한 그래프
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], rug=True)
ax.set_title('Total Bill Histogram with Density and Rug Plot')
ax.set_xlabel('Total Bill')
# Out:
# <img src="data:image/png;base64,..." width="640">
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Total Bill')

# %%
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# count 그래프 -> 이산값을 나타낸 그래프
ax = plt.subplots()
ax = sns.countplot('day',data=tips)
ax.set_title('Count of days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')
# Out:
# <img src="data:image/png;base64,..." width="640">
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Frequency')

# %%
#seaborn 라이브러리로 산점도 그래프 그리기
#회귀선도 같이나온다
ax = plt.subplots()
ax = sns.regplot(x='total_bill', y='tip',data=tips)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Tip')

# %%
#회귀선 제거
ax = plt.subplots()
ax = sns.regplot(x='total_bill',y='tip',data=tips,fit_reg=False)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Tip')

# %%
# 산점도와 히스토그램을 한번에 그려주는 jointplot
joint = sns.jointplot(x='total_bill', y='tip', data=tips)
joint.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# <img src="data:image/png;base64,..." width="600">
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %%
#산점도는 점이 곂치면 구분하기 어렵다.
#육각 그래프 사용
hexbin = sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')
hexbin.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
hexbin.fig.suptitle('Hexbin Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# <img src="data:image/png;base64,..." width="600">
# Text(0.5, 1.03, 'Hexbin Joint Plot of Total Bill and Tip')

# %%
#이차원 밀집도 그리기
# kdeplot

ax = plt.subplots()
ax = sns.kdeplot(data=tips['total_bill'],
                data2=tips['tip'],
                shade=True)#True로 설정하면 음영 효과 준다.
ax.set_title('Kernel Density Plot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# <img src="data:image/png;base64,..." width="640">
# D:\anaconda\lib\site-packages\seaborn\distributions.py:1639: FutureWarning: Use `x` and `y` rather than `data` `and `data2`
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Tip')

# %%
#바 그래프 그리기
# 지정한 변수의 평균을 계산

ax = plt.subplots()
ax = sns.barplot(x='time', y='total_bill', data=tips)
ax.set_title('Bar plot of average total bill for time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Average total bill')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Average total bill')

# %%
# 박스 그래프 그리기
ax = plt.subplots()
ax = sns.boxplot(x='time', y='total_bill', data=tips)
ax.set_title('Boxplot of total bill by time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total Bill')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Total Bill')

# %%
#박스 그래프는 분산이 모호하다.
#그래서 박스를 살찌운다

ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill',data=tips)
ax.set_title('Violin plot of total bill by time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total Bill')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Total Bill')

# %%
#관계 그래프
# 모든 그래프의 종합
fig = sns.pairplot(tips)
#대각선으로 그으면 둘다 같음
# Out:
# <img src="data:image/png;base64,..." width="750">

# %%
# 중복된 그래프는 자기가 원하는 그래프로 교체하면된다.
#map_upper는 대각선 위, map_lower는 대각선 아래, map_diag는 대각선을 중심으로
pair_grid = sns.PairGrid(tips)
pair_grid = pair_grid.map_upper(sns.regplot)
pair_grid = pair_grid.map_lower(sns.kdeplot)
pair_grid = pair_grid.map_diag(sns.distplot, rug=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="750">
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# D:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# 앞에서는 matplotlib로 다변량 그렸다. 이번에는 seaborn 으로 해볼것
# 바이올린에 색 추가하기

ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# 산점도, 관계 그래프 색 추가
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', fit_reg=False)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
fig = sns.pairplot(tips, hue='sex')
# Out:
# <img src="data:image/png;base64,..." width="850">
