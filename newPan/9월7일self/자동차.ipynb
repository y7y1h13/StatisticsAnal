# %%
import pandas as pd

df = pd.read_csv('../data/auto-mpg.csv')
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df = pd.read_csv('../data/auto-mpg.csv',header=None)
df
# Out:
#        0          1             2           3       4             5  \
# 0    mpg  cylinders  displacement  horsepower  weight  acceleration
# 1     18          8           307         130    3504            12
# 2     15          8           350         165    3693          11.5
# 3     18          8           318         150    3436            11
# 4     16          8           304         150    3433            12
# ..   ...        ...           ...         ...     ...           ...
# 394   27          4           140          86    2790          15.6
# 395   44          4            97          52    2130          24.6
# 396   32          4           135          84    2295          11.6
# 397   28          4           120          79    2625          18.6
# 398   31          4           119          82    2720          19.4
#
#               6       7                          8
# 0    model year  origin                   car name
# 1            70       1  chevrolet chevelle malibu
# 2            70       1          buick skylark 320
# 3            70       1         plymouth satellite
# 4            70       1              amc rebel sst
# ..          ...     ...                        ...
# 394          82       1            ford mustang gl
# 395          82       2                  vw pickup
# 396          82       1              dodge rampage
# 397          82       1                ford ranger
# 398          82       1                 chevy s-10
#
# [399 rows x 9 columns]

# %%
df.drop(0, inplace=True)

# %%
df
# Out:
#       0  1    2    3     4     5   6  7                          8
# 1    18  8  307  130  3504    12  70  1  chevrolet chevelle malibu
# 2    15  8  350  165  3693  11.5  70  1          buick skylark 320
# 3    18  8  318  150  3436    11  70  1         plymouth satellite
# 4    16  8  304  150  3433    12  70  1              amc rebel sst
# 5    17  8  302  140  3449  10.5  70  1                ford torino
# ..   .. ..  ...  ...   ...   ...  .. ..                        ...
# 394  27  4  140   86  2790  15.6  82  1            ford mustang gl
# 395  44  4   97   52  2130  24.6  82  2                  vw pickup
# 396  32  4  135   84  2295  11.6  82  1              dodge rampage
# 397  28  4  120   79  2625  18.6  82  1                ford ranger
# 398  31  4  119   82  2720  19.4  82  1                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# ### 열 이름 지정 : 연비, 실린더수, 배기량, 출력, 차중, 가속능력, 출시년도, 제조국, 모델명

# %%
df.columns=['연비','실린더수','배기량','출력','차중','가속능력','출시년도','제조국','모델명']

# %%
df.head(3)
# Out:
#    연비 실린더수  배기량   출력    차중  가속능력 출시년도 제조국                        모델명
# 1  18    8  307  130  3504    12   70   1  chevrolet chevelle malibu
# 2  15    8  350  165  3693  11.5   70   1          buick skylark 320
# 3  18    8  318  150  3436    11   70   1         plymouth satellite

# %%
df.info()#본능
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 398 entries, 1 to 398
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연비      398 non-null    object
#  1   실린더수    398 non-null    object
#  2   배기량     398 non-null    object
#  3   출력      398 non-null    object
#  4   차중      398 non-null    object
#  5   가속능력    398 non-null    object
#  6   출시년도    398 non-null    object
#  7   제조국     398 non-null    object
#  8   모델명     398 non-null    object
# dtypes: object(9)
# memory usage: 31.1+ KB

# %%
df[(df['출력'] == '?')] = '0' 
# for temp in df.columns:
#     df[temp] = df[temp].str.replace('?','0')
df = df.astype({'출력':'float64','연비':'float64','실린더수':'int64','배기량':'float64','차중':'float64','가속능력':'float64','출시년도':'int64','제조국':int})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 398 entries, 1 to 398
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연비      398 non-null    float64
#  1   실린더수    398 non-null    int64
#  2   배기량     398 non-null    float64
#  3   출력      398 non-null    float64
#  4   차중      398 non-null    float64
#  5   가속능력    398 non-null    float64
#  6   출시년도    398 non-null    int64
#  7   제조국     398 non-null    int32
#  8   모델명     398 non-null    object
# dtypes: float64(5), int32(1), int64(2), object(1)
# memory usage: 29.5+ KB

# %%
#원래 오류가남

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 398 entries, 1 to 398
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연비      398 non-null    float64
#  1   실린더수    398 non-null    int64
#  2   배기량     398 non-null    float64
#  3   출력      398 non-null    float64
#  4   차중      398 non-null    float64
#  5   가속능력    398 non-null    float64
#  6   출시년도    398 non-null    int64
#  7   제조국     398 non-null    int32
#  8   모델명     398 non-null    object
# dtypes: float64(5), int32(1), int64(2), object(1)
# memory usage: 29.5+ KB

# %%
df.describe()
# Out:
#                연비        실린더수         배기량          출력           차중  \
# count  398.000000  398.000000  398.000000  398.000000   398.000000
# mean    23.092462    5.389447  191.481156  102.894472  2932.695980
# std      8.257130    1.819732  106.524569   40.269544   917.908333
# min      0.000000    0.000000    0.000000    0.000000     0.000000
# 25%     17.000000    4.000000   98.000000   75.000000  2216.000000
# 50%     22.150000    4.000000  146.000000   92.000000  2789.500000
# 75%     29.000000    8.000000  262.000000  125.000000  3608.000000
# max     46.600000    8.000000  455.000000  230.000000  5140.000000
#
#              가속능력        출시년도         제조국
# count  398.000000  398.000000  398.000000
# mean    15.307035   74.834171    1.552764
# std      3.330411    9.964806    0.822223
# min      0.000000    0.000000    0.000000
# 25%     13.525000   73.000000    1.000000
# 50%     15.500000   76.000000    1.000000
# 75%     17.000000   79.000000    2.000000
# max     24.800000   82.000000    3.000000

# %%
df.count()
# Out:
# 연비      398
# 실린더수    398
# 배기량     398
# 출력      398
# 차중      398
# 가속능력    398
# 출시년도    398
# 제조국     398
# 모델명     398
# dtype: int64

# %%
df.mean()
# Out:
# 연비        23.092462
# 실린더수       5.389447
# 배기량      191.481156
# 출력       102.894472
# 차중      2932.695980
# 가속능력      15.307035
# 출시년도      74.834171
# 제조국        1.552764
# dtype: float64

# %%
df['연비'].mean()
# Out:
# 23.092462311557792

# %%
df[['연비','차중']].mean()
# Out:
# 연비      23.092462
# 차중    2932.695980
# dtype: float64

# %%
df.연비.median()
# Out:
# 22.15

# %%
df.max()
# Out:
# 연비                  46.6
# 실린더수                   8
# 배기량                455.0
# 출력                 230.0
# 차중                5140.0
# 가속능력                24.8
# 출시년도                  82
# 제조국                    3
# 모델명     vw rabbit custom
# dtype: object

# %%
df.std()
# Out:
# 연비        8.257130
# 실린더수      1.819732
# 배기량     106.524569
# 출력       40.269544
# 차중      917.908333
# 가속능력      3.330411
# 출시년도      9.964806
# 제조국       0.822223
# dtype: float64

# %%
#오류가나면 예외처리를 해준다.
for temp in df.columns:
    try:#밑에있는 코드가 문제없이 돌아가면 처리하고
        df[temp] = df[temp].str.replace('?','0')
    except:#오류나면
        print('오류났어요' + temp)
# Out:
# 오류났어요연비
# 오류났어요실린더수
# 오류났어요배기량
# 오류났어요출력
# 오류났어요차중
# 오류났어요가속능력
# 오류났어요출시년도
# 오류났어요제조국
# <ipython-input-87-1bcd081f627b>:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df[temp] = df[temp].str.replace('?','0')

# %%
df.corr() #상관관계 분석
#숫자끼리만 상관관계를 분석해준다.
#0에 가까울수록 상관관계가 없다.
# Out:
#             연비      실린더수       배기량        출력        차중      가속능력      출시년도  \
# 연비    1.000000 -0.551501 -0.659169 -0.583028 -0.579852  0.523707  0.522072
# 실린더수 -0.551501  1.000000  0.944007  0.860006  0.911968 -0.177095  0.223326
# 배기량  -0.659169  0.944007  1.000000  0.900236  0.923429 -0.309063  0.074858
# 출력   -0.583028  0.860006  0.900236  1.000000  0.878396 -0.357254  0.149548
# 차중   -0.579852  0.911968  0.923429  0.878396  1.000000 -0.089374  0.264030
# 가속능력  0.523707 -0.177095 -0.309063 -0.357254 -0.089374  1.000000  0.617202
# 출시년도  0.522072  0.223326  0.074858  0.149548  0.264030  0.617202  1.000000
# 제조국   0.596539 -0.428751 -0.530394 -0.345745 -0.429746  0.303234  0.282372
#
#            제조국
# 연비    0.596539
# 실린더수 -0.428751
# 배기량  -0.530394
# 출력   -0.345745
# 차중   -0.429746
# 가속능력  0.303234
# 출시년도  0.282372
# 제조국   1.000000

# %% [markdown]
# ### 히트맵으로 그려보기

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import matplotlib
import platform
if platform.system() == 'Windows':
    matplotlib.rc('font', family='NanumGothic')
    #Malgun 
# %matplotlib inline

# %%
import seaborn as sns
colormap = plt.cm.PuBu#컬러값을 지정해준다.
plt.figure(figsize=(10,8))
plt.title('자동차 상관관계 분석',y=1.05,size=15)
sns.heatmap(df.corr(),linewidths=0.1, vmax=1.0, square=True,cmap=colormap, linecolor='white',annot=True,annot_kws={"size":16})
#default는 cmap=colormap이걸 뺴야한다
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)
# <AxesSubplot:title={'center':'자동차 상관관계 분석'}>
