# %%
import warnings
warnings.filterwarnings(action='ignore') 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import matplotlib
import platform
import seaborn as sns 
import matplotlib
matplotlib.rcParams['font.family']
if platform.system() == 'Windows':
    matplotlib.rc('font', family='Malgun Gothic')
    #Malgun 
# %matplotlib inline

# %%
df1 = pd.read_csv('./서울특별시 사회복지시설(노인여가복지시설) 목록.csv',encoding='cp949')
df2 = pd.read_csv('./서울특별시 경로당 정보.csv',encoding='cp949')

# %%
df1.head()
# Out:
#    총합             시설명   시설코드      시설종류명(시설유형) 시설종류상세명(시설종류) 자치구(시)구분  시설장명  \
# 0  97             NaN    NaN              NaN           NaN      NaN   NaN
# 1   1  성북구립 상월곡실버복지센터  A0495  (노인) 노인복지관(소규모)      노인여가복지시설      자치구   김경회
# 2   2   서초구립양재노인종합복지관  A0724       (노인) 노인복지관      노인여가복지시설      자치구  전경아
# 3   3   강서구립봉제산노인복지센터  A0922  (노인) 노인복지관(소규모)      노인여가복지시설      자치구   서순애
# 4   4     시립중랑노인종합복지관  A1022       (노인) 노인복지관      노인여가복지시설      자치구   조희정
#
#           시군구코드 시군구명                                   시설주소
# 0           NaN  NaN                                    NaN
# 1  1.129000e+09  성북구              서울특별시 성북구 화랑로18길 6 (상월곡동)
# 2  1.165000e+09  서초구  서울특별시 서초구 강남대로30길 73-7양재노인종합복지관 (양재동)
# 3  1.150000e+09  강서구                  서울특별시 강서구 초록마을로15길 12
# 4  1.126000e+09  중랑구                서울특별시 중랑구 겸재로9길 45(면목동)

# %%
df2=df2.T
df2
# Out:
#         총합      번호               사업장명                       소재지전체주소 도로명전체주소  \
# 0     3745     NaN                NaN                           NaN     NaN
# 1        1  3745.0       정릉꿈에그린(아)경로당         서울특별시 성북구 정릉동 정릉꿈에그린      NaN
# 2        2  3744.0       구파발10단 제3경로당       서울특별시 은평구 진관동 은평뉴타운구파발      NaN
# 3        3  3743.0        아현 아이파크 경로당           서울특별시 마포구 아현동 104동      NaN
# 4        4  3742.0  상암월드컵파크12단지(아)경로당    서울특별시 마포구 상암동 상암월드컵파크12단지      NaN
# ...    ...     ...                ...                           ...     ...
# 3741  3741     5.0        마곡엠밸리6단지경로당                서울특별시 강서구 마곡동      NaN
# 3742  3742     4.0              큰덕경로당                서울특별시 마포구 공덕동      NaN
# 3743  3743     3.0          구립양평3가경로당        서울특별시 영등포구 양평동3가 36번지      NaN
# 3744  3744     2.0   백련산힐스테이트1차아파트경로당                서울특별시 은평구 응암동      NaN
# 3745  3745     1.0   백련산힐스테이트2차아파트경로당  서울특별시 은평구 응암동 백련산힐스테이트2차아파트      NaN
#
# ...

# %%
a = df1[['총합']]
a
# Out:
#     총합
# 0   97
# 1    1
# 2    2
# 3    3
# 4    4
# ..  ..
# 93  93
# 94  94
# 95  95
# 96  96
# 97  97
#
# [98 rows x 1 columns]

# %%
b = df2[['총합']]
b
# Out:
#         총합
# 0     3745
# 1        1
# 2        2
# 3        3
# 4        4
# ...    ...
# 3741  3741
# 3742  3742
# 3743  3743
# 3744  3744
# 3745  3745
#
# [3746 rows x 1 columns]

# %%
a1 = a.iloc[0:1]
a1
# Out:
#    총합
# 0  97

# %%
b1 = b.iloc[0:1]
b1
# Out:
#      총합
# 0  3745

# %%
ab = pd.concat([a1+b1], axis=0)
ab
# Out:
#      총합
# 0  3842

# %%
df3 = pd.read_csv('./노인보호구역.csv')
df3
# Out:
#                                      노인, 장애인보호구역 지정현황  Unnamed: 1 Unnamed: 2  \
# 0                                                  NaN        NaN        NaN
# 1                                    󰏅 노인 보호구역(163개소)         NaN        NaN
# 2                                                  ...        NaN        NaN
# 3                                                  총합계        자치구        시설명
# 4                                                  163        NaN        NaN
# ..                                                 ...        ...        ...
# 188                                                NaN        NaN        NaN
# 189                                                NaN        NaN        NaN
# 190                                                NaN        NaN        NaN
# 191                                                NaN        NaN        NaN
# 192                                                NaN        NaN        NaN
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   노인, 장애인보호구역 지정현황   167 non-null    object
#  1   Unnamed: 1         164 non-null    object
#  2   Unnamed: 2         166 non-null    object
#  3   Unnamed: 3         164 non-null    object
#  4   Unnamed: 4         164 non-null    object
#  5   Unnamed: 5         1 non-null      object
# dtypes: object(6)
# memory usage: 9.2+ KB

# %%
df3.fillna(0)
# Out:
#                                      노인, 장애인보호구역 지정현황  Unnamed: 1 Unnamed: 2  \
# 0                                                    0          0          0
# 1                                    󰏅 노인 보호구역(163개소)           0          0
# 2                                                  ...          0          0
# 3                                                  총합계        자치구        시설명
# 4                                                  163          0          0
# ..                                                 ...        ...        ...
# 188                                                  0          0          0
# 189                                                  0          0          0
# 190                                                  0          0          0
# 191                                                  0          0          0
# 192                                                  0          0          0
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5
# ...

# %%
c = df3.iloc[4:5]
c
# Out:
#   노인, 장애인보호구역 지정현황  Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 4               163        NaN        NaN        NaN        NaN        NaN

# %%
c= c.T
c
# Out:
#                      4
# 노인, 장애인보호구역 지정현황   163
# Unnamed: 1         NaN
# Unnamed: 2         NaN
# Unnamed: 3         NaN
# Unnamed: 4         NaN
# Unnamed: 5         NaN

# %%
c1=c.iloc[0:1]
c1
# Out:
#                      4
# 노인, 장애인보호구역 지정현황   163

# %%
c1= c1.T
c1
# Out:
#   노인, 장애인보호구역 지정현황
# 4               163

# %%
c1.columns = ["노인 보호구역"]
c1
# Out:
#   노인 보호구역
# 4     163

# %%
c1.index = ['0']
c1
# Out:
#   노인 보호구역
# 0     163

# %%
ab.index = ['0']
ab
# Out:
#      총합
# 0  3842

# %%
ab.columns = ['노인 복지시설']
ab
# Out:
#   노인 복지시설
# 0    3842

# %%
all = pd.concat([c1,ab], axis=1)
all
# Out:
#   노인 보호구역 노인 복지시설
# 0     163    3842

# %%
all = all.rename({'0':'갯수'}, axis=0)
all
# Out:
#    노인 보호구역 노인 복지시설
# 갯수     163    3842

# %%
all = all.astype({'노인 보호구역':'int64','노인 복지시설':'int64'})

# %%
all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 갯수 to 갯수
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   노인 보호구역  1 non-null      int64
#  1   노인 복지시설  1 non-null      int64
# dtypes: int64(2)
# memory usage: 24.0+ bytes

# %%
all = all.T
all
# Out:
#            갯수
# 노인 보호구역   163
# 노인 복지시설  3842

# %%
all.index
# Out:
# Index(['노인 보호구역', '노인 복지시설'], dtype='object')

# %%
import matplotlib.pyplot as plt

data = all['갯수']
colors = ['#99CCFF', '#AAB9FF']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}
plt.title('노인 보호구역과 노인 보호시설 비교 ')
plt.pie(data,labels=all.index, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.show()
