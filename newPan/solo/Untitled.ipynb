# %%
import pandas as pd

# %%
df = pd.read_csv('./data3/air.csv')

# %%
df
# Out:
#          MONTH  DAY_OF_WEEK  DEP_DEL15  DISTANCE_GROUP      DEP_BLOCK  \
# 0            1            1          0               1        MORNING
# 1            1            1          0               3  EARLY_MORNING
# 2            1            1          0               2        MORNING
# 3            1            1          0               1  EARLY_MORNING
# 4            1            1          0               3        MORNING
# ...        ...          ...        ...             ...            ...
# 1402913      3            1          0               1      AFTERNOON
# 1402914      3            1          0               1      AFTERNOON
# 1402915      3            1          0               1      AFTERNOON
# 1402916      3            1          0               1        EVENING
# 1402917      3            1          0               1        EVENING
#
#          SEGMENT_NUMBER  CONCURRENT_FLIGHTS  NUMBER_OF_SEATS  \
# 0                     1                  49               66
# ...

# %%
#DEP_DEL15 = TARGET 15분 이상의 출발 지연의 이진수(1은 예)
#DISTANCE_GROUP = 출발 항공기로 비행할 거리 그룹
#SEGMENT_NUMBER = 이 꼬리 번호가 하루 동안 사용되는 세그먼트
#CONCURRENT_FLIGHTS	 = 동일한 출발 구역에서 공항에서 출발하는 동시 항공편
#AIRPORT_FLIGHTS_MONTH = 월간 Avg 공항 항공편
