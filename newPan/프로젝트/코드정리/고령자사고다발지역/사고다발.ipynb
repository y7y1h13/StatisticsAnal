# %%
import pandas as pd

# %%
df = pd.read_csv('../data/보행고령자 사고다발/보행고령자 사고다발지역.csv',)

# %%
df.head()
# Out:
#    사고다발지FID  사고다발지ID       법정동코드      지점코드      시도시군구명  \
# 0    145935  2013098  1111018000  11110001  서울특별시 종로구1
# 1    144334  2013098  1111016700  11110002  서울특별시 종로구2
# 2    151689  2013098  1111015400  11110003  서울특별시 종로구3
# 3    151688  2013098  1111017400  11110004  서울특별시 종로구4
# 4    144645  2013098  1114016000  11140001   서울특별시 중구1
#
#                               지점명  발생건수  사상자수  사망자수  중상자수  경상자수  부상신고자수  \
# 0  서울특별시 종로구 교북동(독립문_의주로_진출_1 부근)     3     3     0     3     0       0
# 1         서울특별시 종로구 충신동(이화사거리 부근)     5     5     0     5     0       0
# 2          서울특별시 종로구 장사동(종묘공원 부근)     6     6     0     4     1       1
# 3   서울특별시 종로구 창신동(동묘앞역_다산로_진입 부근)     6     6     1     5     0       0
# 4        서울특별시 중구 인현동1가(대림상가앞 부근)     3     3     0     1     2       0
#
#            경도         위도                                            다발지역폴리곤
# 0  126.960630  37.571937  {"type":"Polygon","coordinates":[[[126.9622309...
# 1  127.004402  37.576104  {"type":"Polygon","coordinates":[[[127.0060035...
# 2  126.993647  37.570706  {"type":"Polygon","coordinates":[[[126.9952475...
# 3  127.016856  37.572359  {"type":"Polygon","coordinates":[[[127.0184565...
# 4  126.995341  37.566380  {"type":"Polygon","coordinates":[[[126.9969423...

# %%
df_1 = df[['시도시군구명','지점명','발생건수','사상자수','경도','위도']]

# %%
df_1
# Out:
#              시도시군구명                             지점명  발생건수  사상자수          경도  \
# 0        서울특별시 종로구1  서울특별시 종로구 교북동(독립문_의주로_진출_1 부근)     3     3  126.960630
# 1        서울특별시 종로구2         서울특별시 종로구 충신동(이화사거리 부근)     5     5  127.004402
# 2        서울특별시 종로구3          서울특별시 종로구 장사동(종묘공원 부근)     6     6  126.993647
# 3        서울특별시 종로구4   서울특별시 종로구 창신동(동묘앞역_다산로_진입 부근)     6     6  127.016856
# 4         서울특별시 중구1        서울특별시 중구 인현동1가(대림상가앞 부근)     3     3  126.995341
# ...             ...                             ...   ...   ...         ...
# 4982   제주특별자치도 제주시2     제주특별자치도 제주시 노형동(제주노형우체국 부근)     3     3  126.477851
# 4983   제주특별자치도 제주시3     제주특별자치도 제주시 이도일동(KAL사거리 부근)     3     3  126.526879
# 4984  제주특별자치도 서귀포시1  제주특별자치도 서귀포시 서귀동(천지동사무소사거리 부근)     3     4  126.562089
# 4985  제주특별자치도 서귀포시2     제주특별자치도 서귀포시 성산읍(고성리교차로 부근)     2     2  126.915746
# 4986  제주특별자치도 서귀포시3  제주특별자치도 서귀포시 동홍동(천태종서귀포해운사 부근)     2     2  126.568175
#
#              위도
# 0     37.571937
# 1     37.576104
# 2     37.570706
# 3     37.572359
# 4     37.566380
# ...         ...
# 4982  33.487315
# 4983  33.503946
# 4984  33.246923
# 4985  33.448716
# 4986  33.256976
#
# [4987 rows x 6 columns]

# %%
acc = []
for i in range(len(df_1)):
    if '서울' in df_1.loc[i,'시도시군구명']:
#         print(df_1.loc[i,'시도시군구명'])
        acc.append(df_1.loc[i])
acc
# Out:
# [시도시군구명                        서울특별시 종로구1
#  지점명       서울특별시 종로구 교북동(독립문_의주로_진출_1 부근)
#  발생건수                                   3
#  사상자수                                   3
#  경도                             126.96063
#  위도                             37.571937
#  Name: 0, dtype: object,
#  시도시군구명                 서울특별시 종로구2
#  지점명       서울특별시 종로구 충신동(이화사거리 부근)
#  발생건수                            5
#  사상자수                            5
#  경도                     127.004402
#  위도                      37.576104
#  Name: 1, dtype: object,
#  시도시군구명                서울특별시 종로구3
#  지점명       서울특별시 종로구 장사동(종묘공원 부근)
#  발생건수                           6
#  사상자수                           6
#  경도                    126.993647
#  위도                     37.570706
#  Name: 2, dtype: object,
#  시도시군구명                       서울특별시 종로구4
#  지점명       서울특별시 종로구 창신동(동묘앞역_다산로_진입 부근)
#  발생건수                                  6
#  사상자수                                  6
#  경도                           127.016856
#  위도                            37.572359
#  Name: 3, dtype: object,
#  시도시군구명                   서울특별시 중구1
#  지점명       서울특별시 중구 인현동1가(대림상가앞 부근)
#  발생건수                             3
#  사상자수                             3
#  경도                      126.995341
#  위도                        37.56638
#  Name: 4, dtype: object,
#  시도시군구명                  서울특별시 중구2
#  지점명       서울특별시 중구 의주로1가(청암빌딩 부근)
#  발생건수                            4
#  사상자수                            4
#  경도                       126.9715
#  위도                      37.558126
#  Name: 5, dtype: object,
#  시도시군구명                        서울특별시 중구3
#  지점명       서울특별시 중구 신당동(약수역_다산로_진출_1 부근)
#  발생건수                                  8
#  사상자수                                  8
#  경도                           127.010539
#  위도                            37.554076
#  Name: 6, dtype: object,
#  시도시군구명                    서울특별시 용산구1
#  지점명       서울특별시 용산구 한강로2가(철도건설본부 부근)
#  발생건수                               3
#  사상자수                               3
#  경도                        126.966815
#  위도                         37.529175
#  Name: 7, dtype: object,
#  시도시군구명                 서울특별시 용산구2
#  지점명       서울특별시 용산구 한남동(순천향병원 부근)
#  발생건수                            3
#  사상자수                            3
#  경도                     127.004476
#  위도                      37.533462
#  Name: 8, dtype: object,
#  시도시군구명                       서울특별시 용산구3
#  지점명       서울특별시 용산구 이태원동(그랜드하얏트서울호텔 부근)
#  발생건수                                  3
#  사상자수                                  3
#  경도                           126.996186
#  위도                            37.541185
#  Name: 9, dtype: object,
#  시도시군구명                 서울특별시 성동구1
#  지점명       서울특별시 성동구 행당동(무학여고앞 부근)
#  발생건수                            3
#  사상자수                            3
#  경도                     127.032607
#  위도                      37.558349
#  Name: 10, dtype: object,
#  시도시군구명                          서울특별시 성동구2
#  지점명       서울특별시 성동구 도선동(왕십리역_왕십리길_진입_1 부근)
#  발생건수                                     4
#  사상자수                                     4
#  경도                              127.035133
#  위도                               37.561571
#  Name: 11, dtype: object,
#  시도시군구명                          서울특별시 광진구1
#  지점명       서울특별시 광진구 구의동(자양사거리_구의로_진출_1 부근)
#  발생건수                                     4
#  사상자수                                     4
#  경도                              127.085717
#  위도                               37.537502
#  Name: 12, dtype: object,
#  시도시군구명                 서울특별시 광진구2
#  지점명       서울특별시 광진구 구의동(구의사거리 부근)
#  발생건수                            5
#  사상자수                            5
#  경도                      127.08725
#  위도                      37.545509
#  Name: 13, dtype: object,
#  시도시군구명                   서울특별시 동대문구1
#  지점명       서울특별시 동대문구 답십리동(답십리사거리 부근)
#  발생건수                               4
#  사상자수                               5
#  경도                        127.057404
#  위도                         37.571831
#  Name: 14, dtype: object,
#  시도시군구명                    서울특별시 동대문구2
#  지점명       서울특별시 동대문구 제기동(식당재료유통할인 부근)
#  발생건수                                4
#  사상자수                                4
#  경도                          127.03998
#  위도                          37.582779
#  Name: 15, dtype: object,
#  시도시군구명                         서울특별시 동대문구3
#  지점명       서울특별시 동대문구 회기동(회기역앞_회기로_진출_1 부근)
#  발생건수                                     4
#  사상자수                                     5
#  경도                              127.054378
#  위도                               37.589948
#  Name: 16, dtype: object,
#  시도시군구명                         서울특별시 동대문구4
#  지점명       서울특별시 동대문구 신설동(신설동역_난정로_진입_1 부근)
#  발생건수                                     4
#  사상자수                                     4
#  경도                              127.022965
#  위도                               37.575074
#  Name: 17, dtype: object,
#  시도시군구명                  서울특별시 동대문구5
#  지점명       서울특별시 동대문구 제기동(홍파초교후문 부근)
#  발생건수                              4
#  사상자수                              5
#  경도                       127.040452
#  위도                        37.586327
#  Name: 18, dtype: object,
#  시도시군구명                 서울특별시 동대문구6
#  지점명       서울특별시 동대문구 휘경동(위생병원앞 부근)
#  발생건수                             4
#  사상자수                             5
#  경도                      127.062352
#  위도                       37.590171
#  Name: 19, dtype: object,
#  시도시군구명                   서울특별시 동대문구7
#  지점명       서울특별시 동대문구 용두동(용두 치안센터 부근)
#  발생건수                               6
#  사상자수                               6
#  경도                        127.033727
#  위도                         37.578086
#  Name: 20, dtype: object,
#  시도시군구명                              서울특별시 동대문구8
#  지점명       서울특별시 동대문구 청량리동(청량리역_일반국도6호선_진입_1 부근)
#  발생건수                                         16
#  사상자수                                         16
#  경도                                   127.044103
#  위도                                    37.579895
#  Name: 21, dtype: object,
#  시도시군구명               서울특별시 중랑구1
#  지점명       서울특별시 중랑구 면목동(면목역 부근)
#  발생건수                          3
#  사상자수                          3
#  경도                   127.087428
#  위도                    37.589024
#  Name: 22, dtype: object,
#  시도시군구명                      서울특별시 중랑구2
#  지점명       서울특별시 중랑구 상봉동(한일써너스빌리젠시2 부근)
#  발생건수                                 3
#  사상자수                                 3
#  경도                          127.093966
#  위도                           37.598463
#  Name: 23, dtype: object,
#  시도시군구명                   서울특별시 중랑구3
#  지점명       서울특별시 중랑구 신내동(중랑구청사거리 부근)
#  발생건수                              4
#  사상자수                              4
#  경도                       127.094775
#  위도                         37.60682
#  Name: 24, dtype: object,
#  시도시군구명                 서울특별시 중랑구4
#  지점명       서울특별시 중랑구 면목동(동원사거리 부근)
#  발생건수                            4
#  사상자수                            4
#  경도                     127.092896
#  위도                       37.58948
#  Name: 25, dtype: object,
#  시도시군구명                   서울특별시 중랑구5
#  지점명       서울특별시 중랑구 중화동(대원메디컬빌딩 부근)
#  발생건수                              5
#  사상자수                              5
#  경도                       127.078144
#  위도                        37.601539
#  Name: 26, dtype: object,
#  시도시군구명                     서울특별시 중랑구6
#  지점명       서울특별시 중랑구 상봉동(우리은행중랑교지점 부근)
#  발생건수                                5
#  사상자수                                6
#  경도                         127.075753
#  위도                          37.593814
#  Name: 27, dtype: object,
#  시도시군구명                서울특별시 중랑구7
#  지점명       서울특별시 중랑구 망우동(원동빌딩 부근)
#  발생건수                           6
#  사상자수                           6
#  경도                    127.098716
#  위도                     37.599422
#  Name: 28, dtype: object,
#  시도시군구명                    서울특별시 성북구1
#  지점명       서울특별시 성북구 동소문동7가(흥천사입구 부근)
#  발생건수                               3
#  사상자수                               3
#  경도                        127.015401
#  위도                         37.595991
#  Name: 29, dtype: object,
#  시도시군구명                   서울특별시 성북구2
#  지점명       서울특별시 성북구 석관동(석관동제일은행 부근)
#  발생건수                              3
#  사상자수                              3
#  경도                       127.061388
#  위도                        37.606336
#  Name: 30, dtype: object,
#  시도시군구명                  서울특별시 성북구3
#  지점명       서울특별시 성북구 정릉동(국민은행정릉 부근)
#  발생건수                             3
#  사상자수                             3
#  경도                      127.009945
#  위도                       37.608799
#  Name: 31, dtype: object,
#  시도시군구명                   서울특별시 성북구4
#  지점명       서울특별시 성북구 안암동3가(제삼주유소 부근)
#  발생건수                              3
#  사상자수                              3
#  경도                       127.022719
#  위도                        37.580499
#  Name: 32, dtype: object,
#  시도시군구명                   서울특별시 성북구5
#  지점명       서울특별시 성북구 동소문동1가(실과바늘 부근)
#  발생건수                              4
#  사상자수                              4
#  경도                       127.017585
#  위도                        37.593283
#  Name: 33, dtype: object,
#  시도시군구명                     서울특별시 성북구6
#  지점명       서울특별시 성북구 정릉동(정릉2동 주민센터 부근)
#  발생건수                                4
#  사상자수                                4
#  경도                         127.011364
#  위도                          37.605302
#  Name: 34, dtype: object,
#  시도시군구명                         서울특별시 성북구7
#  지점명       서울특별시 성북구 하월곡동(생명의전화(종합복지관) 부근)
#  발생건수                                    7
#  사상자수                                    7
#  경도                             127.037956
#  위도                              37.604038
#  Name: 35, dtype: object,
#  시도시군구명                   서울특별시 성북구8
#  지점명       서울특별시 성북구 종암동(종암2치안센터 부근)
#  발생건수                              7
#  사상자수                              7
#  경도                       127.033394
#  위도                        37.600892
#  Name: 36, dtype: object,
#  시도시군구명               서울특별시 강북구1
#  지점명       서울특별시 강북구 수유동(수유역 부근)
#  발생건수                          3
#  사상자수                          3
#  경도                   127.024929
#  위도                    37.637929
#  Name: 37, dtype: object,
#  시도시군구명                     서울특별시 강북구2
#  지점명       서울특별시 강북구 수유동((주)월드패션투어 부근)
#  발생건수                                4
#  사상자수                                4
#  경도                         127.015117
#  위도                          37.646189
#  Name: 38, dtype: object,
#  시도시군구명                  서울특별시 강북구3
#  지점명       서울특별시 강북구 미아동(방천시장입구 부근)
#  발생건수                             7
#  사상자수                             7
#  경도                      127.034705
#  위도                       37.612223
#  Name: 39, dtype: object,
#  시도시군구명                   서울특별시 도봉구1
#  지점명       서울특별시 도봉구 방학동(LG대경주유소 부근)
#  발생건수                              3
#  사상자수                              3
#  경도                       127.042843
#  위도                        37.665305
#  Name: 40, dtype: object,
#  시도시군구명                서울특별시 도봉구2
#  지점명       서울특별시 도봉구 창동(창동역서측 부근)
#  발생건수                           3
#  사상자수                           3
#  경도                    127.046113
#  위도                     37.653771
#  Name: 41, dtype: object,
#  시도시군구명                서울특별시 도봉구3
#  지점명       서울특별시 도봉구 쌍문동(숭미초교 부근)
#  발생건수                           3
#  사상자수                           3
#  경도                     127.02788
#  위도                     37.650393
#  Name: 42, dtype: object,
#  시도시군구명                   서울특별시 도봉구4
#  지점명       서울특별시 도봉구 도봉동(온누리도봉약국 부근)
#  발생건수                              3
#  사상자수                              3
#  경도                       127.044872
#  위도                        37.676799
#  Name: 43, dtype: object,
#  시도시군구명               서울특별시 도봉구5
#  지점명       서울특별시 도봉구 창동(창원초교 부근)
#  발생건수                          3
#  사상자수                          3
#  경도                   127.041392
#  위도                    37.652304
#  Name: 44, dtype: object,
#  시도시군구명                   서울특별시 도봉구6
#  지점명       서울특별시 도봉구 방학동(아람미술놀이방 부근)
#  발생건수                              4
#  사상자수                              4
#  경도                       127.033273
#  위도                        37.668952
#  Name: 45, dtype: object,
#  시도시군구명                     서울특별시 도봉구7
#  지점명       서울특별시 도봉구 방학동(동부센트리빌아파트 부근)
#  발생건수                                6
#  사상자수                                6
#  경도                         127.040035
#  위도                          37.662864
#  Name: 46, dtype: object,
#  시도시군구명                   서울특별시 노원구1
#  지점명       서울특별시 노원구 하계동(한성여객(주) 부근)
#  발생건수                              3
#  사상자수                              3
#  경도                       127.071462
#  위도                        37.637909
#  Name: 47, dtype: object,
#  시도시군구명                    서울특별시 노원구2
#  지점명       서울특별시 노원구 월계동(월계4동사무소앞 부근)
#  발생건수                               3
#  사상자수                               3
#  경도                        127.061185
#  위도                         37.631702
#  Name: 48, dtype: object,
#  시도시군구명               서울특별시 노원구3
#  지점명       서울특별시 노원구 공릉동(공릉역 부근)
#  발생건수                          3
#  사상자수                          3
#  경도                   127.073147
#  위도                    37.625138
#  Name: 49, dtype: object,
#  시도시군구명                  서울특별시 노원구4
#  지점명       서울특별시 노원구 상계동(상계초교입구 부근)
#  발생건수                             4
#  사상자수                             4
#  경도                      127.066609
#  위도                       37.657125
#  Name: 50, dtype: object,
#  시도시군구명                       서울특별시 노원구5
#  지점명       서울특별시 노원구 상계동(상계벽산아파트101동 부근)
#  발생건수                                  4
#  사상자수                                  4
#  경도                           127.071768
#  위도                            37.659418
#  Name: 51, dtype: object,
#  시도시군구명                 서울특별시 노원구6
#  지점명       서울특별시 노원구 월계동(월계초교앞 부근)
#  발생건수                            4
#  사상자수                            4
#  경도                     127.051341
#  위도                      37.625507
#  Name: 52, dtype: object,
#  시도시군구명                     서울특별시 은평구1
#  지점명       서울특별시 은평구 수색동(수색차량사무소입구 부근)
#  발생건수                                2
#  사상자수                                2
#  경도                         126.884939
#  위도                          37.588954
#  Name: 53, dtype: object,
#  시도시군구명                  서울특별시 은평구2
#  지점명       서울특별시 은평구 갈현동(길마독사거리 부근)
#  발생건수                             3
#  사상자수                             3
#  경도                      126.917869
#  위도                       37.615261
#  Name: 54, dtype: object,
#  시도시군구명                     서울특별시 은평구3
#  지점명       서울특별시 은평구 불광동(불광동라비앙프라자 부근)
#  발생건수                                3
#  사상자수                                3
#  경도                         126.932047
#  위도                          37.612574
#  Name: 55, dtype: object,
#  시도시군구명                서울특별시 은평구4
#  지점명       서울특별시 은평구 증산동(청솔식당 부근)
#  발생건수                           3
#  사상자수                           3
#  경도                    126.900889
#  위도                     37.579016
#  Name: 56, dtype: object,
#  시도시군구명                 서울특별시 은평구5
#  지점명       서울특별시 은평구 녹번동(선학수련원 부근)
#  발생건수                            4
#  사상자수                            4
#  경도                     126.928537
#  위도                      37.601633
#  Name: 57, dtype: object,
#  시도시군구명                 서울특별시 은평구6
#  지점명       서울특별시 은평구 신사동(신사사거리 부근)
#  발생건수                            4
#  사상자수                            5
#  경도                     126.908806
#  위도                      37.596185
#  Name: 58, dtype: object,
#  시도시군구명                 서울특별시 은평구7
#  지점명       서울특별시 은평구 대조동(역촌사거리 부근)
#  발생건수                            4
#  사상자수                            4
#  경도                     126.919848
#  위도                      37.608463
#  Name: 59, dtype: object,
#  시도시군구명                  서울특별시 은평구8
#  지점명       서울특별시 은평구 불광동(지현한방병원 부근)
#  발생건수                             4
#  사상자수                             5
#  경도                       126.92014
#  위도                       37.625429
#  Name: 60, dtype: object,
#  시도시군구명                        서울특별시 은평구9
#  지점명       서울특별시 은평구 불광동(연천초교길-연서로진입로 부근)
#  발생건수                                   4
#  사상자수                                   4
#  경도                             126.92609
#  위도                             37.621467
#  Name: 61, dtype: object,
#  시도시군구명                  서울특별시 은평구10
#  지점명       서울특별시 은평구 대조동(대조.불광시장 부근)
#  발생건수                              5
#  사상자수                              8
#  경도                       126.926613
#  위도                        37.608683
#  Name: 62, dtype: object,
#  시도시군구명                 서울특별시 은평구11
#  지점명       서울특별시 은평구 불광동(불광전화국앞 부근)
#  발생건수                             5
#  사상자수                             7
#  경도                      126.928292
#  위도                       37.612592
#  Name: 63, dtype: object,
#  시도시군구명                    서울특별시 은평구12
#  지점명       서울특별시 은평구 대조동(신한은행연신내지점 부근)
#  발생건수                                7
#  사상자수                                9
#  경도                         126.921246
#  위도                          37.619286
#  Name: 64, dtype: object,
#  시도시군구명                 서울특별시 서대문구1
#  지점명       서울특별시 서대문구 홍제동(충만한교회 부근)
#  발생건수                             3
#  사상자수                             3
#  경도                      126.947674
#  위도                       37.593553
#  Name: 65, dtype: object,
#  시도시군구명                   서울특별시 서대문구2
#  지점명       서울특별시 서대문구 남가좌동(중암교사거리 부근)
#  발생건수                               3
#  사상자수                               3
#  경도                        126.922059
#  위도                         37.572821
#  Name: 66, dtype: object,
#  시도시군구명                        서울특별시 서대문구3
#  지점명       서울특별시 서대문구 홍은동(홍은사거리_의주로_진출 부근)
#  발생건수                                    5
#  사상자수                                    5
#  경도                             126.941809
#  위도                              37.591242
#  Name: 67, dtype: object,
#  시도시군구명                             서울특별시 서대문구4
#  지점명       서울특별시 서대문구 창천동(신촌로터리_일반국도6호선_진출_ 부근)
#  발생건수                                         5
#  사상자수                                         5
#  경도                                  126.935768
#  위도                                   37.555459
#  Name: 68, dtype: object,
#  시도시군구명                            서울특별시 마포구1
#  지점명       서울특별시 마포구 아현동(굴레방다리_일반국도6호선_진출 부근)
#  발생건수                                       3
#  사상자수                                       3
#  경도                                126.955746
#  위도                                 37.557689
#  Name: 69, dtype: object,
#  시도시군구명                  서울특별시 마포구2
#  지점명       서울특별시 마포구 신수동(우마카서비스 부근)
#  발생건수                             4
#  사상자수                             4
#  경도                       126.93243
#  위도                       37.550319
#  Name: 70, dtype: object,
#  시도시군구명                서울특별시 양천구1
#  지점명       서울특별시 양천구 신월동(대흥빌딩 부근)
#  발생건수                           3
#  사상자수                           3
#  경도                    126.834865
#  위도                     37.520654
#  Name: 71, dtype: object,
#  시도시군구명                   서울특별시 양천구2
#  지점명       서울특별시 양천구 신정동(신정3평화은행 부근)
#  발생건수                              3
#  사상자수                              4
#  경도                       126.853553
#  위도                        37.517352
#  Name: 72, dtype: object,
#  시도시군구명                          서울특별시 강서구1
#  지점명       서울특별시 강서구 화곡동(홍익병원앞_등촌로_진입_1 부근)
#  발생건수                                     3
#  사상자수                                     3
#  경도                              126.863875
#  위도                               37.530665
#  Name: 73, dtype: object,
#  시도시군구명                  서울특별시 강서구2
#  지점명       서울특별시 강서구 화곡동(강서구청입구 부근)
#  발생건수                             3
#  사상자수                             3
#  경도                      126.852409
#  위도                       37.556113
#  Name: 74, dtype: object,
#  시도시군구명                 서울특별시 강서구3
#  지점명       서울특별시 강서구 화곡동(화곡사거리 부근)
#  발생건수                            4
#  사상자수                            4
#  경도                     126.847285
#  위도                      37.530715
#  Name: 75, dtype: object,
#  시도시군구명                서울특별시 강서구4
#  지점명       서울특별시 강서구 염창동(태진빌딩 부근)
#  발생건수                           4
#  사상자수                           4
#  경도                    126.876047
#  위도                     37.546968
#  Name: 76, dtype: object,
#  시도시군구명                 서울특별시 강서구5
#  지점명       서울특별시 강서구 내발산동(우장산역 부근)
#  발생건수                            5
#  사상자수                            6
#  경도                     126.834714
#  위도                      37.548137
#  Name: 77, dtype: object,
#  시도시군구명                 서울특별시 강서구6
#  지점명       서울특별시 강서구 화곡동(청구빌라트 부근)
#  발생건수                            6
#  사상자수                            6
#  경도                     126.845805
#  위도                      37.545478
#  Name: 78, dtype: object,
#  시도시군구명                    서울특별시 구로구1
#  지점명       서울특별시 구로구 구로동(한국인력관리공단 부근)
#  발생건수                               3
#  사상자수                               3
#  경도                        126.892436
#  위도                         37.485933
#  Name: 79, dtype: object,
#  시도시군구명                    서울특별시 구로구2
#  지점명       서울특별시 구로구 고척동(고척동청구아파트 부근)
#  발생건수                               3
#  사상자수                               3
#  경도                        126.863307
#  위도                         37.500553
#  Name: 80, dtype: object,
#  시도시군구명                       서울특별시 구로구3
#  지점명       서울특별시 구로구 오류동(새마을금고오류2동지점 부근)
#  발생건수                                  4
#  사상자수                                  4
#  경도                           126.840161
#  위도                            37.490828
#  Name: 81, dtype: object,
#  시도시군구명                 서울특별시 구로구4
#  지점명       서울특별시 구로구 오류동(시티월드앞 부근)
#  발생건수                            4
#  사상자수                            4
#  경도                     126.839827
#  위도                      37.495352
#  Name: 82, dtype: object,
#  시도시군구명                 서울특별시 구로구5
#  지점명       서울특별시 구로구 구로동(두산아파트 부근)
#  발생건수                            4
#  사상자수                            6
#  경도                     126.888865
#  위도                      37.489335
#  Name: 83, dtype: object,
#  시도시군구명               서울특별시 구로구6
#  지점명       서울특별시 구로구 개봉동(개봉역 부근)
#  발생건수                          7
#  사상자수                          7
#  경도                   126.857572
#  위도                    37.493533
#  Name: 84, dtype: object,
#  시도시군구명                    서울특별시 금천구1
#  지점명       서울특별시 금천구 시흥동(관악농협협동조합 부근)
#  발생건수                               3
#  사상자수                               5
#  경도                        126.909862
#  위도                         37.450526
#  Name: 85, dtype: object,
#  시도시군구명                서울특별시 금천구2
#  지점명       서울특별시 금천구 시흥동(장혁빌딩 부근)
#  발생건수                           3
#  사상자수                           3
#  경도                    126.905408
#  위도                     37.457202
#  Name: 86, dtype: object,
#  시도시군구명                 서울특별시 금천구3
#  지점명       서울특별시 금천구 시흥동(시흥사거리 부근)
#  발생건수                            3
#  사상자수                            3
#  경도                     126.900242
#  위도                       37.45472
#  Name: 87, dtype: object,
#  시도시군구명                   서울특별시 금천구4
#  지점명       서울특별시 금천구 시흥동(시흥4동사거리 부근)
#  발생건수                              4
#  사상자수                              4
#  경도                        126.90404
#  위도                        37.463383
#  Name: 88, dtype: object,
#  시도시군구명                     서울특별시 금천구5
#  지점명       서울특별시 금천구 독산동(독산1동새마을금고 부근)
#  발생건수                                7
#  사상자수                                7
#  경도                         126.897632
#  위도                          37.472176
#  Name: 89, dtype: object,
#  시도시군구명                     서울특별시 영등포구1
#  지점명       서울특별시 영등포구 영등포동1가(영등포로터리 부근)
#  발생건수                                 3
#  사상자수                                 3
#  경도                          126.912424
#  위도                            37.51833
#  Name: 90, dtype: object,
#  시도시군구명                 서울특별시 영등포구2
#  지점명       서울특별시 영등포구 영등포동(영등포역 부근)
#  발생건수                             3
#  사상자수                             3
#  경도                      126.906181
#  위도                       37.516216
#  Name: 91, dtype: object,
#  시도시군구명                       서울특별시 영등포구3
#  지점명       서울특별시 영등포구 신길동(대방역_노량진로_진출 부근)
#  발생건수                                   3
#  사상자수                                   4
#  경도                            126.924783
#  위도                             37.512954
#  Name: 92, dtype: object,
#  시도시군구명                     서울특별시 영등포구4
#  지점명       서울특별시 영등포구 당산동1가(영등포유통상가 부근)
#  발생건수                                 3
#  사상자수                                 3
#  경도                          126.897239
#  위도                           37.521163
#  Name: 93, dtype: object,
#  시도시군구명                          서울특별시 영등포구5
#  지점명       서울특별시 영등포구 신길동(신길광장공원앞_도림로_진출 부근)
#  발생건수                                      3
#  사상자수                                      4
#  경도                               126.904805
#  위도                                 37.49853
#  Name: 94, dtype: object,
#  시도시군구명                      서울특별시 영등포구6
#  지점명       서울특별시 영등포구 문래동5가(신정동현대아파트 부근)
#  발생건수                                  3
#  사상자수                                  3
#  경도                           126.876546
#  위도                            37.517635
#  Name: 95, dtype: object,
#  시도시군구명                서울특별시 영등포구7
#  지점명       서울특별시 영등포구 신길동(보라매역 부근)
#  발생건수                            3
#  사상자수                            3
#  경도                     126.920156
#  위도                      37.499301
#  Name: 96, dtype: object,
#  시도시군구명                     서울특별시 영등포구8
#  지점명       서울특별시 영등포구 영등포동4가(영등포시장앞 부근)
#  발생건수                                 3
#  사상자수                                 3
#  경도                          126.904385
#  위도                           37.520069
#  Name: 97, dtype: object,
#  시도시군구명                          서울특별시 영등포구9
#  지점명       서울특별시 영등포구 당산동6가(당산역_당산로_진입_1 부근)
#  발생건수                                      4
#  사상자수                                      4
#  경도                               126.902375
#  위도                                37.534411
#  Name: 98, dtype: object,
#  시도시군구명              서울특별시 영등포구10
#  지점명       서울특별시 영등포구 대림동(대림역 부근)
#  발생건수                           5
#  사상자수                           5
#  경도                    126.897318
#  위도                     37.492961
#  Name: 99, dtype: object,
#  시도시군구명               서울특별시 동작구1
#  지점명       서울특별시 동작구 사당동(남성역 부근)
#  발생건수                          3
#  사상자수                          3
#  경도                   126.970589
#  위도                    37.485093
#  Name: 100, dtype: object,
#  시도시군구명                서울특별시 동작구2
#  지점명       서울특별시 동작구 상도동(동광교회 부근)
#  발생건수                           4
#  사상자수                           4
#  경도                    126.934426
#  위도                     37.501951
#  Name: 101, dtype: object,
#  시도시군구명                 서울특별시 동작구3
#  지점명       서울특별시 동작구 흑석동(명수대상가 부근)
#  발생건수                            5
#  사상자수                            5
#  경도                     126.962252
#  위도                      37.507282
#  Name: 102, dtype: object,
#  시도시군구명                   서울특별시 동작구4
#  지점명       서울특별시 동작구 상도동(신대방삼거리역 부근)
#  발생건수                              5
#  사상자수                              5
#  경도                       126.928494
#  위도                        37.499402
#  Name: 103, dtype: object,
#  시도시군구명                 서울특별시 동작구5
#  지점명       서울특별시 동작구 상도동(상도지구대 부근)
#  발생건수                            6
#  사상자수                            6
#  경도                     126.939695
#  위도                      37.503763
#  Name: 104, dtype: object,
#  시도시군구명                서울특별시 관악구1
#  지점명       서울특별시 관악구 남현동(연송빌딩 부근)
#  발생건수                           3
#  사상자수                           3
#  경도                     126.98074
#  위도                     37.475912
#  Name: 105, dtype: object,
#  시도시군구명                    서울특별시 관악구2
#  지점명       서울특별시 관악구 신림동(구로디지털단지역 부근)
#  발생건수                               3
#  사상자수                               3
#  경도                        126.902923
#  위도                         37.484296
#  Name: 106, dtype: object,
#  시도시군구명                         서울특별시 관악구3
#  지점명       서울특별시 관악구 봉천동(까치고개_남부순환로_진입 부근)
#  발생건수                                    3
#  사상자수                                    4
#  경도                             126.966183
#  위도                              37.475903
#  Name: 107, dtype: object,
#  시도시군구명                서울특별시 관악구4
#  지점명       서울특별시 관악구 신림동(신대방역 부근)
#  발생건수                           3
#  사상자수                           3
#  경도                    126.912731
#  위도                     37.486941
#  Name: 108, dtype: object,
#  시도시군구명                서울특별시 관악구5
#  지점명       서울특별시 관악구 신림동(성지빌딩 부근)
#  발생건수                           4
#  사상자수                           4
#  경도                    126.930581
#  위도                     37.479723
#  Name: 109, dtype: object,
#  시도시군구명                   서울특별시 관악구6
#  지점명       서울특별시 관악구 신림동(성민사회복지관 부근)
#  발생건수                              4
#  사상자수                              4
#  경도                        126.93128
#  위도                        37.467692
#  Name: 110, dtype: object,
#  시도시군구명                  서울특별시 관악구7
#  지점명       서울특별시 관악구 봉천동(원당초교입구 부근)
#  발생건수                             5
#  사상자수                             5
#  경도                      126.955594
#  위도                       37.479061
#  Name: 111, dtype: object,
#  시도시군구명                서울특별시 관악구8
#  지점명       서울특별시 관악구 신림동(뿌리약국 부근)
#  발생건수                           5
#  사상자수                           5
#  경도                    126.918777
#  위도                     37.473985
#  Name: 112, dtype: object,
#  시도시군구명                  서울특별시 관악구9
#  지점명       서울특별시 관악구 신림동(미림여고입구 부근)
#  발생건수                             5
#  사상자수                             5
#  경도                      126.933508
#  위도                       37.471137
#  Name: 113, dtype: object,
#  시도시군구명                서울특별시 서초구1
#  지점명       서울특별시 서초구 방배동(삼산빌딩 부근)
#  발생건수                           4
#  사상자수                           4
#  경도                    126.981697
#  위도                     37.480152
#  Name: 114, dtype: object,
#  시도시군구명                서울특별시 서초구2
#  지점명       서울특별시 서초구 서초동(도일빌딩 부근)
#  발생건수                           5
#  사상자수                           5
#  경도                    127.014084
#  위도                     37.494165
#  Name: 115, dtype: object,
#  시도시군구명                            서울특별시 강남구1
#  지점명       서울특별시 강남구 논현동(강남을지병원사거리_도산대로_진 부근)
#  발생건수                                       3
#  사상자수                                       3
#  경도                                127.029072
#  위도                                 37.519598
#  Name: 116, dtype: object,
#  시도시군구명                서울특별시 강남구2
#  지점명       서울특별시 강남구 대치동(은마상가 부근)
#  발생건수                           3
#  사상자수                           3
#  경도                    127.062505
#  위도                     37.496174
#  Name: 117, dtype: object,
#  시도시군구명                  서울특별시 강남구3
#  지점명       서울특별시 강남구 개포동(구룡마을입구 부근)
#  발생건수                             5
#  사상자수                             6
#  경도                      127.064454
#  위도                        37.47957
#  Name: 118, dtype: object,
#  시도시군구명                          서울특별시 송파구1
#  지점명       서울특별시 송파구 석촌동(석촌역_백제고분로_진출_2 부근)
#  발생건수                                     3
#  사상자수                                     3
#  경도                              127.105809
#  위도                               37.504693
#  Name: 119, dtype: object,
#  시도시군구명                  서울특별시 송파구2
#  지점명       서울특별시 송파구 가락동(문정동우체국 부근)
#  발생건수                             4
#  사상자수                             4
#  경도                      127.111787
#  위도                       37.490352
#  Name: 120, dtype: object,
#  시도시군구명                 서울특별시 송파구3
#  지점명       서울특별시 송파구 마천동(거여삼거리 부근)
#  발생건수                            4
#  사상자수                            4
#  경도                     127.153181
#  위도                      37.493404
#  Name: 121, dtype: object,
#  시도시군구명                  서울특별시 송파구4
#  지점명       서울특별시 송파구 가락동(GS마트입구 부근)
#  발생건수                             5
#  사상자수                             5
#  경도                      127.117328
#  위도                       37.492298
#  Name: 122, dtype: object,
#  시도시군구명                  서울특별시 송파구5
#  지점명       서울특별시 송파구 삼전동(송파구민회관 부근)
#  발생건수                             5
#  사상자수                             5
#  경도                      127.090869
#  위도                       37.504148
#  Name: 123, dtype: object,
#  시도시군구명                  서울특별시 송파구6
#  지점명       서울특별시 송파구 가락동(가락시장입구 부근)
#  발생건수                             6
#  사상자수                             6
#  경도                      127.109719
#  위도                       37.494202
#  Name: 124, dtype: object,
#  시도시군구명                      서울특별시 송파구7
#  지점명       서울특별시 송파구 거여동(거여역(거여사거리) 부근)
#  발생건수                                10
#  사상자수                                10
#  경도                          127.145415
#  위도                           37.493055
#  Name: 125, dtype: object,
#  시도시군구명                 서울특별시 강동구1
#  지점명       서울특별시 강동구 성내동(성내초등교 부근)
#  발생건수                            3
#  사상자수                            3
#  경도                     127.121293
#  위도                      37.530599
#  Name: 126, dtype: object,
#  시도시군구명                  서울특별시 강동구2
#  지점명       서울특별시 강동구 천호동(강동구민회관 부근)
#  발생건수                             3
#  사상자수                             3
#  경도                      127.141887
#  위도                       37.546167
#  Name: 127, dtype: object,
#  시도시군구명                  서울특별시 강동구3
#  지점명       서울특별시 강동구 천호동(천호초교입구 부근)
#  발생건수                             4
#  사상자수                             4
#  경도                      127.132587
#  위도                       37.547813
#  Name: 128, dtype: object,
#  시도시군구명               서울특별시 강동구4
#  지점명       서울특별시 강동구 길동(길동시장 부근)
#  발생건수                          4
#  사상자수                          4
#  경도                   127.136908
#  위도                    37.534585
#  Name: 129, dtype: object,
#  시도시군구명                  서울특별시 강동구5
#  지점명       서울특별시 강동구 천호동(천호신사거리 부근)
#  발생건수                             5
#  사상자수                             5
#  경도                      127.126946
#  위도                       37.538351
#  Name: 130, dtype: object,
#  시도시군구명                    서울특별시 강동구6
#  지점명       서울특별시 강동구 둔촌동(세양청마루아파트 부근)
#  발생건수                               5
#  사상자수                               5
#  경도                        127.141842
#  위도                         37.534293
#  Name: 131, dtype: object,
#  시도시군구명                  서울특별시 종로구1
#  지점명       서울특별시 종로구 숭인동(아람보습학원 부근)
#  발생건수                             5
#  사상자수                             5
#  경도                      127.017959
#  위도                        37.57337
#  Name: 508, dtype: object,
#  시도시군구명                 서울특별시 종로구2
#  지점명       서울특별시 종로구 종로2가(기업은행 부근)
#  발생건수                            4
#  사상자수                            4
#  경도                     126.989159
#  위도                       37.57029
#  Name: 509, dtype: object,
#  시도시군구명                    서울특별시 중구1
#  지점명       서울특별시 중구 봉래동2가(서울역사거리 부근)
#  발생건수                              5
#  사상자수                              5
#  경도                       126.972527
#  위도                        37.555556
#  Name: 510, dtype: object,
#  시도시군구명               서울특별시 중구2
#  지점명       서울특별시 중구 신당동(약수역 부근)
#  발생건수                         5
#  사상자수                         6
#  경도                  127.010617
#  위도                   37.554635
#  Name: 511, dtype: object,
#  시도시군구명                       서울특별시 중구3
#  지점명       서울특별시 중구 남창동(서울역고가차도(동측) 부근)
#  발생건수                                 5
#  사상자수                                 5
#  경도                          126.977571
#  위도                           37.557962
#  Name: 512, dtype: object,
#  시도시군구명               서울특별시 중구4
#  지점명       서울특별시 중구 흥인동(신당역 부근)
#  발생건수                         4
#  사상자수                         4
#  경도                  127.017438
#  위도                   37.565814
#  Name: 513, dtype: object,
#  시도시군구명                  서울특별시 중구5
#  지점명       서울특별시 중구 충무로4가(진양상가 부근)
#  발생건수                            3
#  사상자수                            3
#  경도                     126.994859
#  위도                      37.561426
#  Name: 514, dtype: object,
#  시도시군구명                 서울특별시 중구6
#  지점명       서울특별시 중구 소공동(롯데명품관 부근)
#  발생건수                           3
#  사상자수                           3
#  경도                    126.980957
#  위도                     37.563987
#  Name: 515, dtype: object,
#  시도시군구명                   서울특별시 용산구1
#  지점명       서울특별시 용산구 원효로2가(원효아파트 부근)
#  발생건수                              5
#  사상자수                              5
#  경도                       126.961478
#  위도                        37.535575
#  Name: 516, dtype: object,
#  시도시군구명                서울특별시 성동구1
#  지점명       서울특별시 성동구 용답동(동부시장 부근)
#  발생건수                           8
#  사상자수                           8
#  경도                    127.053609
#  위도                     37.566119
#  Name: 517, dtype: object,
#  시도시군구명                서울특별시 성동구2
#  지점명       서울특별시 성동구 행당동(성수여중 부근)
#  발생건수                           5
#  사상자수                           5
#  경도                    127.049175
#  위도                     37.538416
#  Name: 518, dtype: object,
#  시도시군구명                 서울특별시 성동구3
#  지점명       서울특별시 성동구 행당동(응봉삼거리 부근)
#  발생건수                            3
#  사상자수                            3
#  경도                     127.034077
#  위도                      37.554674
#  Name: 519, dtype: object,
#  시도시군구명                  서울특별시 성동구4
#  지점명       서울특별시 성동구 금호동1가(정민빌딩 부근)
#  발생건수                             3
#  사상자수                             4
#  경도                      127.025054
#  위도                       37.552826
#  Name: 520, dtype: object,
#  시도시군구명                     서울특별시 성동구5
#  지점명       서울특별시 성동구 금호동4가(국민은행금호동 부근)
#  발생건수                                3
#  사상자수                                3
#  경도                         127.022785
#  위도                          37.548238
#  Name: 521, dtype: object,
#  시도시군구명               서울특별시 광진구1
#  지점명       서울특별시 광진구 능동(아차산역 부근)
#  발생건수                          4
#  사상자수                          4
#  경도                   127.090321
#  위도                    37.551099
#  Name: 522, dtype: object,
#  시도시군구명                 서울특별시 광진구2
#  지점명       서울특별시 광진구 군자동(화양삼거리 부근)
#  발생건수                            3
#  사상자수                            3
#  경도                      127.07087
#  위도                      37.549613
#  Name: 523, dtype: object,
#  시도시군구명                 서울특별시 광진구3
#  지점명       서울특별시 광진구 구의동(구의사거리 부근)
#  발생건수                            3
#  사상자수                            3
#  경도                     127.085587
#  위도                      37.545149
#  Name: 524, dtype: object,
#  시도시군구명                   서울특별시 동대문구1
#  지점명       서울특별시 동대문구 용두동(성바오로병원앞 부근)
#  발생건수                              13
#  사상자수                              13
#  경도                        127.042432
#  위도                         37.579213
#  Name: 525, dtype: object,
#  시도시군구명                             서울특별시 동대문구2
#  지점명       서울특별시 동대문구 용두동(경동시장_일반국도6호선_진출_1 부근)
#  발생건수                                         9
#  사상자수                                         9
#  경도                                  127.037399
#  위도                                   37.578212
#  Name: 526, dtype: object,
#  시도시군구명                  서울특별시 동대문구3
#  지점명       서울특별시 동대문구 청량리동(옥치과의원 부근)
#  발생건수                              6
#  사상자수                              6
#  경도                       127.046833
#  위도                        37.581163
#  Name: 527, dtype: object,
#  시도시군구명                서울특별시 동대문구4
#  지점명       서울특별시 동대문구 휘경동(백합빌딩 부근)
#  발생건수                            5
#  사상자수                            5
#  경도                     127.060388
#  위도                      37.589585
#  Name: 528, dtype: object,
#  시도시군구명                        서울특별시 동대문구5
#  지점명       서울특별시 동대문구 이문동(외대앞역지하차도(서측) 부근)
#  발생건수                                    4
#  사상자수                                    4
#  경도                             127.061858
#  위도                              37.595715
#  Name: 529, dtype: object,
#  시도시군구명                  서울특별시 동대문구6
#  지점명       서울특별시 동대문구 전농동(전농파출소앞 부근)
#  발생건수                              4
#  사상자수                              4
#  경도                       127.047358
#  위도                         37.57577
#  Name: 530, dtype: object,
#  시도시군구명                   서울특별시 동대문구7
#  지점명       서울특별시 동대문구 답십리동(답십리사거리 부근)
#  발생건수                               3
#  사상자수                               3
#  경도                         127.05737
#  위도                         37.573187
#  Name: 531, dtype: object,
#  시도시군구명                         서울특별시 동대문구8
#  지점명       서울특별시 동대문구 회기동(회기역앞_이문로_진입_1 부근)
#  발생건수                                     3
#  사상자수                                     3
#  경도                              127.055031
#  위도                               37.589348
#  Name: 532, dtype: object,
#  시도시군구명                    서울특별시 동대문구9
#  지점명       서울특별시 동대문구 장안동(경찰수사연구소B 부근)
#  발생건수                                3
#  사상자수                                3
#  경도                         127.072327
#  위도                          37.581625
#  Name: 533, dtype: object,
#  시도시군구명                            서울특별시 동대문구10
#  지점명       서울특별시 동대문구 청량리동(떡전교사거리_일반국도6호선_진 부근)
#  발생건수                                         3
#  사상자수                                         3
#  경도                                  127.050137
#  위도                                   37.583832
#  Name: 534, dtype: object,
#  시도시군구명                서울특별시 중랑구1
#  지점명       서울특별시 중랑구 망우동(원동빌딩 부근)
#  발생건수                           6
#  사상자수                           7
#  경도                    127.099072
#  위도                     37.599484
#  Name: 535, dtype: object,
#  시도시군구명               서울특별시 중랑구2
#  지점명       서울특별시 중랑구 면목동(면목역 부근)
#  발생건수                          4
#  사상자수                          5
#  경도                   127.087816
#  위도                    37.588449
#  Name: 536, dtype: object,
#  시도시군구명                             서울특별시 중랑구3
#  지점명       서울특별시 중랑구 면목동(면목2동사거리_일반국도3호선_진 부근)
#  발생건수                                        4
#  사상자수                                        4
#  경도                                 127.078234
#  위도                                  37.587796
#  Name: 537, dtype: object,
#  시도시군구명                   서울특별시 중랑구4
#  지점명       서울특별시 중랑구 신내동(봉화환승주차장 부근)
#  발생건수                              3
#  사상자수                              3
#  경도                       127.093294
#  위도                        37.616383
#  Name: 538, dtype: object,
#  시도시군구명                서울특별시 중랑구5
#  지점명       서울특별시 중랑구 면목동(중화중교 부근)
#  발생건수                           3
#  사상자수                           3
#  경도                     127.09476
#  위도                     37.586355
#  Name: 539, dtype: object,
#  시도시군구명                      서울특별시 중랑구6
#  지점명       서울특별시 중랑구 상봉동(한일써너스빌리젠시2 부근)
#  발생건수                                 3
#  사상자수                                 3
#  경도                          127.093824
#  위도                           37.598365
#  Name: 540, dtype: object,
#  시도시군구명                 서울특별시 중랑구7
#  지점명       서울특별시 중랑구 면목동(상봉시장앞 부근)
#  발생건수                            3
#  사상자수                            3
#  경도                     127.086159
#  위도                      37.593283
#  Name: 541, dtype: object,
#  시도시군구명               서울특별시 중랑구8
#  지점명       서울특별시 중랑구 중화동(중화역 부근)
#  발생건수                          3
#  사상자수                          3
#  경도                   127.079511
#  위도                    37.600993
#  Name: 542, dtype: object,
#  시도시군구명                 서울특별시 중랑구9
#  지점명       서울특별시 중랑구 망우동(동원사거리 부근)
#  발생건수                            3
#  사상자수                            3
#  경도                     127.093691
#  위도                      37.590461
#  Name: 543, dtype: object,
#  시도시군구명                  서울특별시 성북구1
#  지점명       서울특별시 성북구 종암동(효성특수유리 부근)
#  발생건수                             5
#  사상자수                             6
#  경도                      127.033658
#  위도                       37.600362
#  Name: 544, dtype: object,
#  시도시군구명                      서울특별시 성북구2
#  지점명       서울특별시 성북구 장위동(신한은행(장위지점) 부근)
#  발생건수                                 5
#  사상자수                                 5
#  경도                          127.051598
#  위도                           37.609956
#  Name: 545, dtype: object,
#  시도시군구명                 서울특별시 성북구3
#  지점명       서울특별시 성북구 하월곡동(이삭교회 부근)
#  발생건수                            5
#  사상자수                            5
#  경도                     127.039554
#  위도                      37.602397
#  Name: 546, dtype: object,
#  시도시군구명                     서울특별시 성북구4
#  지점명       서울특별시 성북구 동선동1가(성신여대입구역 부근)
#  발생건수                                5
#  사상자수                                5
#  경도                         127.017422
#  위도                          37.592844
#  Name: 547, dtype: object,
#  시도시군구명                           서울특별시 성북구5
#  지점명       서울특별시 성북구 정릉동(아리랑로터리_정릉길_진출_1 부근)
#  발생건수                                      3
#  사상자수                                      4
#  경도                               127.012948
#  위도                                37.603856
#  Name: 548, dtype: object,
#  시도시군구명                서울특별시 성북구6
#  지점명       서울특별시 성북구 정릉동(미진미싱 부근)
#  발생건수                           3
#  사상자수                           3
#  경도                    127.018772
#  위도                     37.601924
#  Name: 549, dtype: object,
#  시도시군구명                    서울특별시 강북구1
#  지점명       서울특별시 강북구 미아동(국민은행수유지점 부근)
#  발생건수                               6
#  사상자수                               7
#  경도                        127.023936
#  위도                         37.632312
#  Name: 550, dtype: object,
#  시도시군구명                  서울특별시 강북구2
#  지점명       서울특별시 강북구 미아동(미아삼거리역 부근)
#  발생건수                             6
#  사상자수                             6
#  경도                      127.030048
#  위도                       37.613566
#  Name: 551, dtype: object,
#  시도시군구명                          서울특별시 강북구3
#  지점명       서울특별시 강북구 미아동(미아사거리_미아로_진출_1 부근)
#  발생건수                                     5
#  사상자수                                     6
#  경도                              127.030209
#  위도                               37.608806
#  Name: 552, dtype: object,
#  시도시군구명                서울특별시 강북구4
#  지점명       서울특별시 강북구 수유동(원일빌딩 부근)
#  발생건수                           4
#  사상자수                           4
#  경도                    127.019471
#  위도                     37.634365
#  Name: 553, dtype: object,
#  시도시군구명                 서울특별시 강북구5
#  지점명       서울특별시 강북구 수유동(백십자약국 부근)
#  발생건수                            4
#  사상자수                            4
#  경도                     127.012937
#  위도                      37.636809
#  Name: 554, dtype: object,
#  시도시군구명                서울특별시 강북구6
#  지점명       서울특별시 강북구 수유동(광산타워 부근)
#  발생건수                           3
#  사상자수                           3
#  경도                    127.022288
#  위도                     37.642153
#  Name: 555, dtype: object,
#  시도시군구명                  서울특별시 강북구7
#  지점명       서울특별시 강북구 수유동(우이초등교앞 부근)
#  발생건수                             3
#  사상자수                             3
#  경도                      127.016783
#  위도                        37.64144
#  Name: 556, dtype: object,
#  시도시군구명                  서울특별시 강북구8
#  지점명       서울특별시 강북구 수유동(삼각산지구대 부근)
#  발생건수                             3
#  사상자수                             3
#  경도                      127.017808
#  위도                       37.630743
#  Name: 557, dtype: object,
#  시도시군구명                   서울특별시 강북구9
#  지점명       서울특별시 강북구 미아동(미아동소방소앞 부근)
#  발생건수                              3
#  사상자수                              3
#  경도                       127.015886
#  위도                        37.620125
#  Name: 558, dtype: object,
#  시도시군구명                  서울특별시 강북구10
#  지점명       서울특별시 강북구 번동(강북유니온빌딩앞 부근)
#  발생건수                              2
#  사상자수                              2
#  경도                       127.042741
#  위도                        37.628322
#  Name: 559, dtype: object,
#  시도시군구명                  서울특별시 도봉구1
#  지점명       서울특별시 도봉구 쌍문동(만복중앙교회 부근)
#  발생건수                             4
#  사상자수                             4
#  경도                      127.023249
#  위도                       37.649533
#  Name: 560, dtype: object,
#  시도시군구명                서울특별시 도봉구2
#  지점명       서울특별시 도봉구 창동(창동역서측 부근)
#  발생건수                           4
#  사상자수                           5
#  경도                    127.046164
#  위도                     37.652472
#  Name: 561, dtype: object,
#  시도시군구명                 서울특별시 도봉구3
#  지점명       서울특별시 도봉구 쌍문동(연세한의원 부근)
#  발생건수                            4
#  사상자수                            4
#  경도                     127.034164
#  위도                      37.658073
#  Name: 562, dtype: object,
#  시도시군구명                서울특별시 도봉구4
#  지점명       서울특별시 도봉구 도봉동(이화창고 부근)
#  발생건수                           3
#  사상자수                           3
#  경도                     127.04627
#  위도                      37.68346
#  Name: 563, dtype: object,
#  시도시군구명                 서울특별시 도봉구5
#  지점명       서울특별시 도봉구 방학동(도봉소방서 부근)
#  발생건수                            3
#  사상자수                            3
#  경도                     127.042416
#  위도                      37.664706
#  Name: 564, dtype: object,
#  시도시군구명               서울특별시 노원구1
#  지점명       서울특별시 노원구 중계동(당현교 부근)
#  발생건수                          4
#  사상자수                          5
#  경도                   127.063088
#  위도                    37.647198
#  Name: 565, dtype: object,
#  시도시군구명                   서울특별시 노원구2
#  지점명       서울특별시 노원구 상계동(노원롯데백화점 부근)
#  발생건수                              4
#  사상자수                              4
#  경도                        127.06088
#  위도                        37.655352
#  Name: 566, dtype: object,
#  시도시군구명                   서울특별시 노원구3
#  지점명       서울특별시 노원구 월계동(염상국치과의원 부근)
#  발생건수                              4
#  사상자수                              5
#  경도                       127.064318
#  위도                        37.616811
#  Name: 567, dtype: object,
# ...
#  경도                    127.062347
#  위도                     37.657132
#  Name: 3443, dtype: object,
#  시도시군구명                서울특별시 노원구4
#  지점명       서울특별시 노원구 상계동(수락산역 부근)
#  발생건수                           3
#  사상자수                           3
#  경도                    127.055033
#  위도                     37.678419
#  Name: 3444, dtype: object,
#  시도시군구명                 서울특별시 노원구5
#  지점명       서울특별시 노원구 상계동(대성한의원 부근)
#  발생건수                            3
#  사상자수                            3
#  경도                     127.078371
#  위도                      37.666481
#  Name: 3445, dtype: object,
#  시도시군구명                  서울특별시 노원구6
#  지점명       서울특별시 노원구 월계동(석계로11길 부근)
#  발생건수                             2
#  사상자수                             2
#  경도                      127.063587
#  위도                       37.617416
#  Name: 3446, dtype: object,
#  시도시군구명                    서울특별시 은평구1
#  지점명       서울특별시 은평구 대조동(보스톤탑치과의원 부근)
#  발생건수                               5
#  사상자수                               5
#  경도                        126.922186
#  위도                         37.617715
#  Name: 3447, dtype: object,
#  시도시군구명               서울특별시 은평구2
#  지점명       서울특별시 은평구 응암동(와산교 부근)
#  발생건수                          5
#  사상자수                          5
#  경도                   126.913382
#  위도                    37.588825
#  Name: 3448, dtype: object,
#  시도시군구명                    서울특별시 은평구3
#  지점명       서울특별시 은평구 갈현동(갈현1동주민센터 부근)
#  발생건수                               4
#  사상자수                               4
#  경도                        126.917051
#  위도                          37.62372
#  Name: 3449, dtype: object,
#  시도시군구명                서울특별시 은평구4
#  지점명       서울특별시 은평구 대조동(서울병원 부근)
#  발생건수                           4
#  사상자수                           4
#  경도                    126.929192
#  위도                     37.608568
#  Name: 3450, dtype: object,
#  시도시군구명                서울특별시 은평구5
#  지점명       서울특별시 은평구 갈현동(호남식당 부근)
#  발생건수                           3
#  사상자수                           3
#  경도                    126.916481
#  위도                     37.614638
#  Name: 3451, dtype: object,
#  시도시군구명                 서울특별시 서대문구1
#  지점명       서울특별시 서대문구 홍제동(홍은사거리 부근)
#  발생건수                             9
#  사상자수                            10
#  경도                      126.941934
#  위도                       37.591418
#  Name: 3452, dtype: object,
#  시도시군구명                          서울특별시 서대문구2
#  지점명       서울특별시 서대문구 북가좌동(KEB하나은행 북가좌지점 부근)
#  발생건수                                      5
#  사상자수                                      6
#  경도                               126.911778
#  위도                                37.580622
#  Name: 3453, dtype: object,
#  시도시군구명                      서울특별시 서대문구3
#  지점명       서울특별시 서대문구 홍제동(사랑나눔사회복지센터 부근)
#  발생건수                                  3
#  사상자수                                  3
#  경도                           126.948139
#  위도                            37.594035
#  Name: 3454, dtype: object,
#  시도시군구명                서울특별시 서대문구4
#  지점명       서울특별시 서대문구 홍은동(홍연2교 부근)
#  발생건수                            3
#  사상자수                            3
#  경도                     126.930058
#  위도                      37.577932
#  Name: 3455, dtype: object,
#  시도시군구명                     서울특별시 서대문구5
#  지점명       서울특별시 서대문구 대현동(CGV신촌아트레온 부근)
#  발생건수                                 2
#  사상자수                                 2
#  경도                          126.941911
#  위도                           37.556546
#  Name: 3456, dtype: object,
#  시도시군구명               서울특별시 양천구1
#  지점명       서울특별시 양천구 목동(한독빌딩 부근)
#  발생건수                          6
#  사상자수                          6
#  경도                   126.863432
#  위도                    37.535137
#  Name: 3457, dtype: object,
#  시도시군구명                서울특별시 양천구2
#  지점명       서울특별시 양천구 신월동(중앙빌딩 부근)
#  발생건수                           5
#  사상자수                           5
#  경도                    126.834943
#  위도                     37.520951
#  Name: 3458, dtype: object,
#  시도시군구명                  서울특별시 양천구3
#  지점명       서울특별시 양천구 신월동(신월제일교회 부근)
#  발생건수                             4
#  사상자수                             4
#  경도                      126.839048
#  위도                       37.517083
#  Name: 3459, dtype: object,
#  시도시군구명                    서울특별시 양천구4
#  지점명       서울특별시 양천구 신정동(은혜재가요양센터 부근)
#  발생건수                               3
#  사상자수                               3
#  경도                        126.851131
#  위도                         37.523482
#  Name: 3460, dtype: object,
#  시도시군구명                     서울특별시 강서구1
#  지점명       서울특별시 강서구 등촌동(신한이모르젠아파트 부근)
#  발생건수                                7
#  사상자수                               10
#  경도                          126.86395
#  위도                           37.54986
#  Name: 3461, dtype: object,
#  시도시군구명                  서울특별시 강서구2
#  지점명       서울특별시 강서구 염창동(강서구보건소 부근)
#  발생건수                             5
#  사상자수                             5
#  경도                      126.868213
#  위도                       37.549137
#  Name: 3462, dtype: object,
#  시도시군구명                서울특별시 강서구3
#  지점명       서울특별시 강서구 화곡동(바울빌딩 부근)
#  발생건수                           4
#  사상자수                           4
#  경도                    126.849145
#  위도                     37.530833
#  Name: 3463, dtype: object,
#  시도시군구명                         서울특별시 구로구1
#  지점명       서울특별시 구로구 오류동(IBK기업은행 오류동지점 부근)
#  발생건수                                    5
#  사상자수                                    5
#  경도                             126.844087
#  위도                               37.49643
#  Name: 3464, dtype: object,
#  시도시군구명                  서울특별시 구로구2
#  지점명       서울특별시 구로구 개봉동(늘푸른한의원 부근)
#  발생건수                             4
#  사상자수                             4
#  경도                       126.85623
#  위도                       37.492348
#  Name: 3465, dtype: object,
#  시도시군구명               서울특별시 구로구3
#  지점명       서울특별시 구로구 궁동(우진빌딩 부근)
#  발생건수                          4
#  사상자수                          4
#  경도                   126.829158
#  위도                    37.497669
#  Name: 3466, dtype: object,
#  시도시군구명                서울특별시 구로구4
#  지점명       서울특별시 구로구 오류동(만호빌딩 부근)
#  발생건수                           4
#  사상자수                           4
#  경도                    126.844867
#  위도                     37.494005
#  Name: 3467, dtype: object,
#  시도시군구명                서울특별시 구로구5
#  지점명       서울특별시 구로구 구로동(고려빌딩 부근)
#  발생건수                           3
#  사상자수                           3
#  경도                    126.885012
#  위도                     37.502939
#  Name: 3468, dtype: object,
#  시도시군구명                 서울특별시 금천구1
#  지점명       서울특별시 금천구 시흥동(시흥사거리 부근)
#  발생건수                            9
#  사상자수                            9
#  경도                     126.900386
#  위도                       37.45476
#  Name: 3469, dtype: object,
#  시도시군구명                  서울특별시 금천구2
#  지점명       서울특별시 금천구 시흥동(은행나무시장 부근)
#  발생건수                             5
#  사상자수                             5
#  경도                      126.908042
#  위도                       37.451046
#  Name: 3470, dtype: object,
#  시도시군구명                    서울특별시 금천구3
#  지점명       서울특별시 금천구 독산동(금천우체국사거리 부근)
#  발생건수                               3
#  사상자수                               3
#  경도                        126.898086
#  위도                         37.469629
#  Name: 3471, dtype: object,
#  시도시군구명                  서울특별시 영등포구1
#  지점명       서울특별시 영등포구 영등포동(월드맨파워 부근)
#  발생건수                              5
#  사상자수                              5
#  경도                        126.90811
#  위도                        37.514991
#  Name: 3472, dtype: object,
#  시도시군구명                       서울특별시 영등포구2
#  지점명       서울특별시 영등포구 문래동6가(e편한세상문래상가 부근)
#  발생건수                                   5
#  사상자수                                   5
#  경도                            126.886016
#  위도                               37.5198
#  Name: 3473, dtype: object,
#  시도시군구명                  서울특별시 영등포구3
#  지점명       서울특별시 영등포구 신길동(영신치과의원 부근)
#  발생건수                              4
#  사상자수                              4
#  경도                       126.916816
#  위도                        37.512138
#  Name: 3474, dtype: object,
#  시도시군구명                  서울특별시 영등포구4
#  지점명       서울특별시 영등포구 대림동(도림로31길 부근)
#  발생건수                              3
#  사상자수                              4
#  경도                       126.895362
#  위도                        37.493551
#  Name: 3475, dtype: object,
#  시도시군구명                       서울특별시 영등포구5
#  지점명       서울특별시 영등포구 영등포동5가(비즈성형외과의원 부근)
#  발생건수                                   2
#  사상자수                                   4
#  경도                            126.905338
#  위도                             37.521302
#  Name: 3476, dtype: object,
#  시도시군구명                      서울특별시 영등포구6
#  지점명       서울특별시 영등포구 문래동3가(문래근린공원입구 부근)
#  발생건수                                  2
#  사상자수                                  2
#  경도                           126.894522
#  위도                            37.517113
#  Name: 3477, dtype: object,
#  시도시군구명                    서울특별시 동작구1
#  지점명       서울특별시 동작구 신대방동(해태보라매타워 부근)
#  발생건수                               5
#  사상자수                               5
#  경도                        126.924208
#  위도                          37.49184
#  Name: 3478, dtype: object,
#  시도시군구명                       서울특별시 동작구2
#  지점명       서울특별시 동작구 대방동(신대방삼거리역2번출구 부근)
#  발생건수                                  5
#  사상자수                                  5
#  경도                           126.928096
#  위도                            37.498959
#  Name: 3479, dtype: object,
#  시도시군구명                      서울특별시 동작구3
#  지점명       서울특별시 동작구 상도동(이니스프리 숭실대점 부근)
#  발생건수                                 5
#  사상자수                                 9
#  경도                          126.952503
#  위도                           37.497683
#  Name: 3480, dtype: object,
#  시도시군구명                  서울특별시 동작구4
#  지점명       서울특별시 동작구 신대방동(대림사거리 부근)
#  발생건수                             4
#  사상자수                             4
#  경도                      126.906824
#  위도                       37.488757
#  Name: 3481, dtype: object,
#  시도시군구명                 서울특별시 동작구5
#  지점명       서울특별시 동작구 대방동(보라매빌딩 부근)
#  발생건수                            3
#  사상자수                            3
#  경도                     126.921579
#  위도                      37.499791
#  Name: 3482, dtype: object,
#  시도시군구명                서울특별시 관악구1
#  지점명       서울특별시 관악구 신림동(뿌리약국 부근)
#  발생건수                           7
#  사상자수                           7
#  경도                    126.918601
#  위도                     37.474469
#  Name: 3483, dtype: object,
#  시도시군구명                서울특별시 관악구2
#  지점명       서울특별시 관악구 신림동(신일자원 부근)
#  발생건수                           5
#  사상자수                           5
#  경도                    126.913823
#  위도                     37.477487
#  Name: 3484, dtype: object,
#  시도시군구명                     서울특별시 관악구3
#  지점명       서울특별시 관악구 봉천동(쿠우쿠우 서울대점 부근)
#  발생건수                                4
#  사상자수                                4
#  경도                         126.950336
#  위도                          37.481394
#  Name: 3485, dtype: object,
#  시도시군구명                 서울특별시 관악구4
#  지점명       서울특별시 관악구 봉천동(당곡사거리 부근)
#  발생건수                            4
#  사상자수                            5
#  경도                     126.928211
#  위도                      37.489212
#  Name: 3486, dtype: object,
#  시도시군구명                서울특별시 서초구1
#  지점명       서울특별시 서초구 서초동(서울고교 부근)
#  발생건수                           4
#  사상자수                           4
#  경도                     127.00373
#  위도                     37.482484
#  Name: 3487, dtype: object,
#  시도시군구명                서울특별시 서초구2
#  지점명       서울특별시 서초구 서초동(서이초교 부근)
#  발생건수                           3
#  사상자수                           3
#  경도                    127.026628
#  위도                     37.491982
#  Name: 3488, dtype: object,
#  시도시군구명                     서울특별시 강남구1
#  지점명       서울특별시 강남구 도곡동(삼성타워펠리스1차 부근)
#  발생건수                                4
#  사상자수                                4
#  경도                         127.053959
#  위도                          37.488764
#  Name: 3489, dtype: object,
#  시도시군구명                     서울특별시 강남구2
#  지점명       서울특별시 강남구 논현동(임피리얼팰리스호텔 부근)
#  발생건수                                3
#  사상자수                                4
#  경도                         127.035727
#  위도                          37.513236
#  Name: 3490, dtype: object,
#  시도시군구명                          서울특별시 강남구3
#  지점명       서울특별시 강남구 역삼동(스타벅스 아크로힐스 논현점 부근)
#  발생건수                                     3
#  사상자수                                     3
#  경도                              127.040206
#  위도                               37.509174
#  Name: 3491, dtype: object,
#  시도시군구명                  서울특별시 강남구4
#  지점명       서울특별시 강남구 신사동(현대종합상가 부근)
#  발생건수                             3
#  사상자수                             3
#  경도                      127.030758
#  위도                       37.527945
#  Name: 3492, dtype: object,
#  시도시군구명                 서울특별시 강남구5
#  지점명       서울특별시 강남구 역삼동(한라클래식 부근)
#  발생건수                            3
#  사상자수                            3
#  경도                      127.03024
#  위도                      37.496855
#  Name: 3493, dtype: object,
#  시도시군구명                서울특별시 송파구1
#  지점명       서울특별시 송파구 마천동(구본빌딩 부근)
#  발생건수                           7
#  사상자수                           7
#  경도                    127.154113
#  위도                      37.49708
#  Name: 3494, dtype: object,
#  시도시군구명                      서울특별시 송파구2
#  지점명       서울특별시 송파구 거여동(세븐일레븐 거여본점 부근)
#  발생건수                                 5
#  사상자수                                 5
#  경도                          127.145922
#  위도                           37.496759
#  Name: 3495, dtype: object,
#  시도시군구명                 서울특별시 송파구3
#  지점명       서울특별시 송파구 거여동(효재한의원 부근)
#  발생건수                            5
#  사상자수                            5
#  경도                      127.14591
#  위도                      37.492986
#  Name: 3496, dtype: object,
#  시도시군구명                 서울특별시 송파구4
#  지점명       서울특별시 송파구 잠실동(잠실지구대 부근)
#  발생건수                            4
#  사상자수                            5
#  경도                     127.082064
#  위도                      37.511703
#  Name: 3497, dtype: object,
#  시도시군구명                  서울특별시 송파구5
#  지점명       서울특별시 송파구 방이동(송파태양약국 부근)
#  발생건수                             4
#  사상자수                             4
#  경도                       127.11536
#  위도                       37.510977
#  Name: 3498, dtype: object,
#  시도시군구명                       서울특별시 송파구6
#  지점명       서울특별시 송파구 송파동(송파한양1차아파트정문 부근)
#  발생건수                                  3
#  사상자수                                  3
#  경도                           127.114507
#  위도                            37.504772
#  Name: 3499, dtype: object,
#  시도시군구명                서울특별시 송파구7
#  지점명       서울특별시 송파구 가락동(태인일식 부근)
#  발생건수                           3
#  사상자수                           4
#  경도                    127.119119
#  위도                     37.493759
#  Name: 3500, dtype: object,
#  시도시군구명                서울특별시 강동구1
#  지점명       서울특별시 강동구 천호동(성록빌딩 부근)
#  발생건수                           6
#  사상자수                           6
#  경도                    127.133964
#  위도                     37.546487
#  Name: 3501, dtype: object,
#  시도시군구명                    서울특별시 강동구2
#  지점명       서울특별시 강동구 천호동(고분다리전통시장 부근)
#  발생건수                               5
#  사상자수                               5
#  경도                        127.131394
#  위도                         37.542431
#  Name: 3502, dtype: object,
#  시도시군구명                서울특별시 강동구3
#  지점명       서울특별시 강동구 성내동(SJ빌딩 부근)
#  발생건수                           3
#  사상자수                           3
#  경도                    127.133227
#  위도                     37.532778
#  Name: 3503, dtype: object,
#  시도시군구명                   서울특별시 강동구4
#  지점명       서울특별시 강동구 천호동(천호역2번출구 부근)
#  발생건수                              3
#  사상자수                              3
#  경도                       127.123596
#  위도                        37.539237
#  Name: 3504, dtype: object,
#  시도시군구명                서울특별시 강동구5
#  지점명       서울특별시 강동구 천호동(성덕약국 부근)
#  발생건수                           3
#  사상자수                           3
#  경도                    127.140362
#  위도                     37.550791
#  Name: 3505, dtype: object,
#  시도시군구명                서울특별시 종로구1
#  지점명       서울특별시 종로구 낙원동(기업은행 부근)
#  발생건수                           7
#  사상자수                           7
#  경도                    126.989062
#  위도                     37.570203
#  Name: 3919, dtype: object,
#  시도시군구명                 서울특별시 종로구2
#  지점명       서울특별시 종로구 숭인동(영도교남단 부근)
#  발생건수                            5
#  사상자수                            5
#  경도                     127.018823
#  위도                      37.571432
#  Name: 3920, dtype: object,
#  ...]

# %%
df_acc = pd.DataFrame(acc)

# %%
df_acc
# Out:
#           시도시군구명                             지점명  발생건수  사상자수          경도  \
# 0     서울특별시 종로구1  서울특별시 종로구 교북동(독립문_의주로_진출_1 부근)     3     3  126.960630
# 1     서울특별시 종로구2         서울특별시 종로구 충신동(이화사거리 부근)     5     5  127.004402
# 2     서울특별시 종로구3          서울특별시 종로구 장사동(종묘공원 부근)     6     6  126.993647
# 3     서울특별시 종로구4   서울특별시 종로구 창신동(동묘앞역_다산로_진입 부근)     6     6  127.016856
# 4      서울특별시 중구1        서울특별시 중구 인현동1가(대림상가앞 부근)     3     3  126.995341
# ...          ...                             ...   ...   ...         ...
# 4581  서울특별시 강동구1          서울특별시 강동구 암사동(암사시장 부근)     5     5  127.128676
# 4582  서울특별시 강동구2         서울특별시 강동구 천호동(천호사거리 부근)     4     4  127.123545
# 4583  서울특별시 강동구3       서울특별시 강동구 천호동(천호시장사거리 부근)     4     4  127.127767
# 4584  서울특별시 강동구4    서울특별시 강동구 암사동(장치봉의맵꼬만명태찜 부근)     3     3  127.134524
# 4585  서울특별시 강동구5        서울특별시 강동구 천호동(강동구민회관 부근)     3     3  127.141572
#
#              위도
# 0     37.571937
# 1     37.576104
# 2     37.570706
# 3     37.572359
# 4     37.566380
# ...         ...
# 4581  37.551215
# 4582  37.538955
# 4583  37.540450
# 4584  37.551891
# 4585  37.546180
#
# [1245 rows x 6 columns]

# %%
df_acc.columns = ['구','지점','발생건수','사상자수','경도','위도']

# %%
df_acc.head()
# Out:
#             구                              지점  발생건수  사상자수          경도  \
# 0  서울특별시 종로구1  서울특별시 종로구 교북동(독립문_의주로_진출_1 부근)     3     3  126.960630
# 1  서울특별시 종로구2         서울특별시 종로구 충신동(이화사거리 부근)     5     5  127.004402
# 2  서울특별시 종로구3          서울특별시 종로구 장사동(종묘공원 부근)     6     6  126.993647
# 3  서울특별시 종로구4   서울특별시 종로구 창신동(동묘앞역_다산로_진입 부근)     6     6  127.016856
# 4   서울특별시 중구1        서울특별시 중구 인현동1가(대림상가앞 부근)     3     3  126.995341
#
#           위도
# 0  37.571937
# 1  37.576104
# 2  37.570706
# 3  37.572359
# 4  37.566380

# %%
df_acc['구'] = df_acc['구'].str.replace('서울특별시 ','')

# %%
df_acc.head()
# Out:
#       구                              지점  발생건수  사상자수          경도         위도
# 0  종로구1  서울특별시 종로구 교북동(독립문_의주로_진출_1 부근)     3     3  126.960630  37.571937
# 1  종로구2         서울특별시 종로구 충신동(이화사거리 부근)     5     5  127.004402  37.576104
# 2  종로구3          서울특별시 종로구 장사동(종묘공원 부근)     6     6  126.993647  37.570706
# 3  종로구4   서울특별시 종로구 창신동(동묘앞역_다산로_진입 부근)     6     6  127.016856  37.572359
# 4   중구1        서울특별시 중구 인현동1가(대림상가앞 부근)     3     3  126.995341  37.566380

# %%
import re
gu = []
for i in df_acc['구']:
    tmp = re.sub(r'[0-9]+','',i)
    gu.append(tmp)
gu
# Out:
# ['종로구',
#  '종로구',
#  '종로구',
#  '종로구',
#  '중구',
#  '중구',
#  '중구',
#  '용산구',
#  '용산구',
#  '용산구',
#  '성동구',
#  '성동구',
#  '광진구',
#  '광진구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '마포구',
#  '마포구',
#  '양천구',
#  '양천구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '서초구',
#  '서초구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '종로구',
#  '종로구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '용산구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '금천구',
#  '금천구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '서초구',
#  '서초구',
#  '서초구',
#  '서초구',
#  '강남구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '종로구',
#  '종로구',
#  '종로구',
#  '종로구',
#  '종로구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '용산구',
#  '용산구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '서초구',
#  '서초구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '종로구',
#  '종로구',
#  '종로구',
#  '종로구',
#  '종로구',
#  '종로구',
#  '종로구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '용산구',
#  '용산구',
#  '용산구',
#  '용산구',
#  '용산구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '광진구',
#  '광진구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '금천구',
#  '금천구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '서초구',
#  '서초구',
#  '강남구',
#  '강남구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '강동구',
#  '강동구',
#  '종로구',
#  '종로구',
#  '종로구',
#  '종로구',
#  '종로구',
#  '종로구',
#  '중구',
#  '중구',
#  '중구',
#  '용산구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '광진구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '서초구',
#  '서초구',
#  '서초구',
#  '서초구',
#  '서초구',
#  '서초구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '종로구',
#  '종로구',
#  '종로구',
#  '종로구',
#  '종로구',
#  '종로구',
#  '종로구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '용산구',
#  '용산구',
#  '용산구',
#  '용산구',
#  '용산구',
#  '성동구',
#  '성동구',
#  '성동구',
#  '광진구',
#  '광진구',
#  '광진구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '마포구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '서초구',
#  '서초구',
#  '강남구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '종로구',
#  '종로구',
#  '종로구',
#  '중구',
#  '중구',
#  '중구',
#  '중구',
#  '용산구',
#  '용산구',
#  '용산구',
#  '용산구',
#  '성동구',
#  '성동구',
#  '광진구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '양천구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '동작구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '관악구',
#  '서초구',
#  '서초구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '강남구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '송파구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '강동구',
#  '종로구',
#  '종로구',
#  ...]

# %%
df_acc['구'] = gu

# %%
df_acc
# Out:
#         구                              지점  발생건수  사상자수          경도         위도
# 0     종로구  서울특별시 종로구 교북동(독립문_의주로_진출_1 부근)     3     3  126.960630  37.571937
# 1     종로구         서울특별시 종로구 충신동(이화사거리 부근)     5     5  127.004402  37.576104
# 2     종로구          서울특별시 종로구 장사동(종묘공원 부근)     6     6  126.993647  37.570706
# 3     종로구   서울특별시 종로구 창신동(동묘앞역_다산로_진입 부근)     6     6  127.016856  37.572359
# 4      중구        서울특별시 중구 인현동1가(대림상가앞 부근)     3     3  126.995341  37.566380
# ...   ...                             ...   ...   ...         ...        ...
# 4581  강동구          서울특별시 강동구 암사동(암사시장 부근)     5     5  127.128676  37.551215
# 4582  강동구         서울특별시 강동구 천호동(천호사거리 부근)     4     4  127.123545  37.538955
# 4583  강동구       서울특별시 강동구 천호동(천호시장사거리 부근)     4     4  127.127767  37.540450
# 4584  강동구    서울특별시 강동구 암사동(장치봉의맵꼬만명태찜 부근)     3     3  127.134524  37.551891
# 4585  강동구        서울특별시 강동구 천호동(강동구민회관 부근)     3     3  127.141572  37.546180
#
# [1245 rows x 6 columns]

# %%
df_acc['지점'] = df_acc['지점'].str.replace('서울특별시 ','')

# %%
df_acc.head()
# Out:
#      구                        지점  발생건수  사상자수          경도         위도
# 0  종로구  종로구 교북동(독립문_의주로_진출_1 부근)     3     3  126.960630  37.571937
# 1  종로구         종로구 충신동(이화사거리 부근)     5     5  127.004402  37.576104
# 2  종로구          종로구 장사동(종묘공원 부근)     6     6  126.993647  37.570706
# 3  종로구   종로구 창신동(동묘앞역_다산로_진입 부근)     6     6  127.016856  37.572359
# 4   중구        중구 인현동1가(대림상가앞 부근)     3     3  126.995341  37.566380

# %%
df_acc.reset_index(inplace=True)

# %%
df_acc.head()
# Out:
#    index    구                        지점  발생건수  사상자수          경도         위도
# 0      0  종로구  종로구 교북동(독립문_의주로_진출_1 부근)     3     3  126.960630  37.571937
# 1      1  종로구         종로구 충신동(이화사거리 부근)     5     5  127.004402  37.576104
# 2      2  종로구          종로구 장사동(종묘공원 부근)     6     6  126.993647  37.570706
# 3      3  종로구   종로구 창신동(동묘앞역_다산로_진입 부근)     6     6  127.016856  37.572359
# 4      4   중구        중구 인현동1가(대림상가앞 부근)     3     3  126.995341  37.566380

# %%
df_acc.drop('index',axis=1,inplace=True)

# %%
df_acc.to_csv('../data/보행고령자 사고다발/서울 고령자사고다발지역.txt')

# %%
df_acc.head()
# Out:
#      구                        지점  발생건수  사상자수          경도         위도
# 0  종로구  종로구 교북동(독립문_의주로_진출_1 부근)     3     3  126.960630  37.571937
# 1  종로구         종로구 충신동(이화사거리 부근)     5     5  127.004402  37.576104
# 2  종로구          종로구 장사동(종묘공원 부근)     6     6  126.993647  37.570706
# 3  종로구   종로구 창신동(동묘앞역_다산로_진입 부근)     6     6  127.016856  37.572359
# 4   중구        중구 인현동1가(대림상가앞 부근)     3     3  126.995341  37.566380

# %%
j = df_acc[df_acc['구']=='동대문구']

# %%
j
# Out:
#          구                          지점  발생건수  사상자수          경도         위도
# 14    동대문구        동대문구 답십리동(답십리사거리 부근)     4     5  127.057404  37.571831
# 15    동대문구       동대문구 제기동(식당재료유통할인 부근)     4     4  127.039980  37.582779
# 16    동대문구  동대문구 회기동(회기역앞_회기로_진출_1 부근)     4     5  127.054378  37.589948
# 17    동대문구  동대문구 신설동(신설동역_난정로_진입_1 부근)     4     4  127.022965  37.575074
# 18    동대문구         동대문구 제기동(홍파초교후문 부근)     4     5  127.040452  37.586327
# ...    ...                         ...   ...   ...         ...        ...
# 1155  동대문구            동대문구 회기동(경희대 부근)     6    11  127.053115  37.593541
# 1156  동대문구       동대문구 제기동(식당재료유통할인 부근)     5     5  127.040413  37.583010
# 1157  동대문구         동대문구 장안동(장안동삼거리 부근)     4     4  127.071973  37.578930
# 1158  동대문구         동대문구 용두동(서울시설공단 부근)     3     3  127.038110  37.572681
# 1159  동대문구       동대문구 휘경동(위생병원앞교차로 부근)     3     3  127.063803  37.590517
#
# [98 rows x 6 columns]

# %%
import folium

center = [37.541 , 126.986]
mapdata = folium.Map(location=center, zoom_start = 12)

for temp in df_acc.index:
    folium.Circle(
    [df_acc['위도'][temp], df_acc['경도'][temp]],
    radius = int(df_acc.loc[temp, ['발생건수']].values[0] * 3), color='#3185cc', fill_color='#3185cc'
    
    ).add_to(mapdata)
mapdata
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_5100d3ffb67947b7b44dc661439e8450%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_5100d3ffb67947b7b44dc661439e8450%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_5100d3ffb67947b7b44dc661439e8450%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_5100d3ffb67947b7b44dc661439e8450%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.541%2C%20126.986%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
import folium

center = [37.541 , 126.986]
mapdata = folium.Map(location=center, zoom_start = 12)

for temp in j.index:
    folium.Circle(
    [j['위도'][temp], j['경도'][temp]],
    radius = int(j.loc[temp, ['발생건수']].values[0] / 5), color='#3185cc', fill_color='#3185cc'
    
    ).add_to(mapdata)
mapdata
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_f34890c63a9c4d4e8617c3f2691020a1%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f34890c63a9c4d4e8617c3f2691020a1%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f34890c63a9c4d4e8617c3f2691020a1%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_f34890c63a9c4d4e8617c3f2691020a1%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.541%2C%20126.986%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
df_2 = df_acc.groupby('구')['발생건수'].sum()
df_2 = pd.DataFrame(df_2)
df_2.sort_values('발생건수',ascending=False,inplace=True)
df_2
# Out:
#       발생건수
# 구
# 동대문구   561
# 성북구    366
# 관악구    322
# 강북구    317
# 은평구    291
# 중랑구    287
# 영등포구   260
# 동작구    243
# 서대문구   238
# 강동구    203
# 종로구    202
# 구로구    199
# 중구     185
# 강서구    184
# 송파구    183
# 도봉구    179
# 양천구    171
# 노원구    167
# 성동구    151
# 금천구    138
# 마포구    105
# 서초구     96
# 강남구     94
# 용산구     85
# 광진구     70

# %%
import folium

center = [37.579 , 127.045]
mapdata = folium.Map(location=center, zoom_start = 15)

for temp in j.index:
    folium.Circle(
    [j['위도'][temp], j['경도'][temp]],
    radius = 8, color='#000000', fill='crimson'
    
    ).add_to(mapdata)
mapdata
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_893c3c763f3e4de08a5cc4fbf783f69f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_893c3c763f3e4de08a5cc4fbf783f69f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_893c3c763f3e4de08a5cc4fbf783f69f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_893c3c763f3e4de08a5cc4fbf783f69f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.579%2C%20127.045%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...
