# %%
import os
import sys
import urllib.request
import json
import re
import konlpy
from konlpy.tag import Okt
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import konlpy
from konlpy.tag import Okt
from collections import Counter
import pandas as pd
import konlpy.tag

def get_blog():
    keyword = input('검색어를 입력하세요:')
    client_id = "OKQPTGKiQf0V3yitzK6o"
    client_secret = "uIGSvzveCB"

    encText = urllib.parse.quote(keyword)

    tlist = []
    llist = []
    dlist = []



    for pagenum in range(1,1000,100):

        try:

            url = "https://openapi.naver.com/v1/search/blog?query=" + encText +"&display=100&sort=sim&start="+str(pagenum)# json 결과   블로그 1~100  101~200
            # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
            request = urllib.request.Request(url)
            request.add_header("X-Naver-Client-Id",client_id)
            request.add_header("X-Naver-Client-Secret",client_secret)
            response = urllib.request.urlopen(request)
            rescode = response.getcode()
            if(rescode==200):
                response_body = response.read()
                print(response_body.decode('utf-8'))
                jtemp = response_body.decode('utf-8')
                jdata = json.loads(jtemp)
                jdata['items']
                
                for temp in jdata['items']:  
                    hangul = re.compile('[^ ㄱ-ㅎ|가-힣]+')
                    tdata = temp['title']
                    ldata = temp['link']
                    ddata = hangul.sub(r'',temp['description'])

                    tlist.append(tdata)
                    llist.append(ldata)
                    dlist.append(ddata)
                

            else:
                print("Error Code:" + rescode)

        except:
            print('Error')



    result = []
    for temp in range(len(tlist)):
        temp1 = []
        temp1.append(tlist[temp])
        temp1.append(llist[temp])
        temp1.append(dlist[temp])

        result.append(temp1)


    f = open('{0} - 네이버API 블로그검색.csv'.format(keyword) , 'w', encoding='utf-8')
    f.write('제목'+',' + '링크' + ',' + '내용' + '\n')
    for temp in result:    
        f.write(temp[0] + ',' + temp[1] + ',' + temp[2] +'\n')
    f.close()
    
    #여기서 결과를 리턴해줘야 쓸수있음
    return result

# %%
def clean_str(s):
    hangul = re.compile('[^ㄱ-ㅎ|가-힣]+')
    s = hangul.sub(r' ',s)
    
    cp = re.compile("["
                     u"\U00010000-\U0010FFFF"
                     "]+", flags=re.UNICODE)
    s = cp.sub(r' ',s)
    
    return s.strip()


def get_text(data):
    result_text = ''
    for temp in data:
        result_text = result_text +' ' +  temp[2]

    return result_text


def Wordcloud(data , savename , maskname=''):
    noun_text = ''
    for word in data:
        noun_text = noun_text +' ' + word
    
    if maskname == '':
        wc = WordCloud( font_path='../data/WordCloud/font/BMEULJIROTTF.ttf' , background_color='white', max_font_size=60, colormap='PuOr_r').generate(noun_text)
    else:
        maskimg = np.array(Image.open(maskname))
        wc = WordCloud(font_path='../data/WordCloud/font/BMEULJIROTTF.ttf' , background_color='white', mask=maskimg, max_font_size=60, colormap='PuOr_r').generate(noun_text)
        
#     wc.generate_from_frequencies(data)
    plt.figure(figsize=(20,10))
    plt.imshow(wc)
    plt.tight_layout(pad=0)
    plt.axis('off')
    plt.show()
    wc.to_file('../data/크롤링/savename' + '.png')

# %%
bdata = get_blog()# 여기를 블로그 대신 뉴스나 카페로 고치면 뉴스나 카페로 크롤링 가능
rtext = get_text(bdata)
# Out:
# 검색어를 입력하세요:노인보호구역
# {
# "lastBuildDate": "Thu, 30 Sep 2021 13:55:42 +0900",
# "total": 44045,
# "start": 1,
# "display": 100,
# "items": [
# {
# "title": "<b>노인보호구역</b> ‘실버존’ 제대로 알고 지켜주세요!",
# "link": "https:\/\/blog.naver.com\/safeppy?Redirect=Log&logNo=222008845357",
# "description": "어린이 보호구역처럼 노인들 역시 많은 보호와 관심이 필요합니다. 복지관을 이용하며 <b>노인보호구역</b>을 매일 지난다는 81세 김 할머니는 “내 앞을 씽 지나가는 차량 때문에 놀라 넘어질 뻔한 적이 있다. 우리는... ",
# "bloggername": "대한민국 119_소방청 공식 블로그",
# "bloggerlink": "https://blog.naver.com/safeppy",
# "postdate": "20200622"
#
# },
# {
# "title": "어린이,장애인,<b>노인 보호구역</b> 벌점 범칙금 과태료",
# "link": "https:\/\/blog.naver.com\/lky94312?Redirect=Log&logNo=222076100907",
# "description": "도로에서 운전을 하다 보면 어린이보호구역, <b>노인보호구역</b>, 장애인보호구역이라는 표시를 보게 된다.... 교통약자 보호구역 및 관련시설 교통약자보호구역은 어린이, 노인, 장애인 등과 같이 신체적으로... ",
# "bloggername": "알뜰한 잡학",
# "bloggerlink": "https://blog.naver.com/lky94312",
# "postdate": "20200831"
#
# },
# {
# "title": "<b>노인보호구역</b>, 실버존(Silver Zone)",
# "link": "https:\/\/blog.naver.com\/12sunrise703?Redirect=Log&logNo=222324946366",
# "description": "지방자치단체는 노인을 교통사고 위험에서 보호하기 위해 <b>노인보호구역</b>을 지정하여 운영하고 있는데요. 하지만, 어린이 보호구역에 비해 많이 알려지지 않았습니다. 노인복지시설이나 의료시설... ",
# "bloggername": "다함께 잘사는 세상을 위하여",
# "bloggerlink": "https://blog.naver.com/12sunrise703",
# "postdate": "20210604"
#
# },
# {
# "title": "어린이 보호 구역과 비슷한 ‘<b>노인보호구역</b>(실버존)’은... ",
# "link": "https:\/\/blog.naver.com\/troyflow?Redirect=Log&logNo=221970087350",
# "description": "또한 <b>노인보호구역</b>에 횡단보도가 설치된 경우 걸음이 느린 노인분들을 위해 일반 보행자 신호에 비해 긴 시간이 주어집니다. 보호구역에서는 범칙금과 과태료가 2배! 실버존은 어린이보호구역인 스쿨존과... ",
# "bloggername": "디파츠",
# "bloggerlink": "https://blog.naver.com/troyflow",
# "postdate": "20200519"
#
# },
# {
# "title": "건강걷기 29 <b>노인보호구역</b>",
# "link": "https:\/\/blog.naver.com\/n0289?Redirect=Log&logNo=222516769659",
# "description": "그렇게 노인이 될테지요 <b>노인보호구역</b>에서는 조금이라도 속도를 늦춰주시면 좋겠습니다 사진은 마을입구 <b>노인보호구역</b> 표시 영상입니다 시작시간 오전 10시 06분 운동시간 1시간 35분 운동거리 7.8km 칼로리... ",
# "bloggername": "유일종벌꿀",
# "bloggerlink": "https://blog.naver.com/n0289",
# "postdate": "20210925"
#
# },
# {
# "title": "<b>노인 보호구역</b> 실버존을 아시나요!",
# "link": "https:\/\/blog.naver.com\/dolcejian?Redirect=Log&logNo=222395543062",
# "description": "- 노인들을 위한 시설 이외에도 공원 또는 문화 센터 시설에도 실버존으로 지정했다고 합니다. <b>노인 보호구역</b>은 스쿨존인 어린이보호구역이랑 똑같이 시속 30km로 주행해야 하고 주정차는 금지입니다.... ",
# "bloggername": "차프로모션 : 자동차 프로모션 맛집",
# "bloggerlink": "https://blog.naver.com/dolcejian",
# "postdate": "20210612"
#
# },
# {
# "title": "강동구, 어린이·<b>노인</b> 등 교통약자 <b>보호구역</b> 확대",
# "link": "https:\/\/blog.naver.com\/tynews?Redirect=Log&logNo=222166516211",
# "description": "- 어린이보호구역 3개소·<b>노인보호구역</b> 1개소 신규 지정 - 태양광 LED 표지판, 노면 도색 등... 어린이보호구역 시작점에 설치된 태양광 LED 표지판 강동구(구청장 이정훈)가 어린이, 노인 등 교통약자에게 안전한... ",
# "bloggername": "토요저널",
# "bloggerlink": "https://blog.naver.com/tynews",
# "postdate": "20201208"
#
# },
# {
# "title": "어린이 보호구역과 <b>노인 보호구역</b> 및 장애인 보호구역에서... ",
# "link": "https:\/\/blog.naver.com\/9191bok?Redirect=Log&logNo=222482544083",
# "description": "어린이 보호구역과 <b>노인 보호구역</b> 및 장애인 보호구역에서 시속 20km를 초과하는 과속에 대해 1회 위반 시 보험료 5% 할증 2회 이상 위반 시 보험료 10% 할증이 적용됩니다. 횡단보도에서 보행자 보호 의무를... ",
# "bloggername": "좋은 인연",
# "bloggerlink": "https://blog.naver.com/9191bok",
# "postdate": "20210824"
#
# },
# {
# "title": "송아량 의원 “막무가내식 전통시장 <b>노인보호구역</b> 지정 안돼”",
# "link": "https:\/\/blog.naver.com\/gbnews?Redirect=Log&logNo=222403946254",
# "description": "서울시는 지난 4월 전통시장 주변에 노인보행사고 발생률이 높아 전통시장 주변을 <b>노인보호구역</b>으로 서울시장이 직권으로 지정하겠다고 발표했다. <b>노인보호구역</b>으로 지정되면 차량속도가 시속 30㎞로... ",
# "bloggername": "서울강북신문",
# "bloggerlink": "https://blog.naver.com/gbnews",
# "postdate": "20210620"
#
# },
# {
# "title": "&lt;보도&gt; 장위전통시장 '<b>노인보호구역</b>' 지정",
# "link": "https:\/\/blog.naver.com\/newsb21?Redirect=Log&logNo=222334363004",
# "description": "시는 작년에 교통사고로 사망한 보행자 115명 중 60명이 노인이었으며, 전통시장에서 노인 보행자 사고가 잦다고 설명했다. <b>노인보호구역</b>으로 지정되면 차량 속도가 시속 30㎞로 제한되고, 불법 주정차... ",
# "bloggername": "새성북신문",
# "bloggerlink": "https://blog.naver.com/newsb21",
# "postdate": "20210503"
#
# },
# {
# "title": "범칙금 안내(어린이 보호구역, <b>노인 보호구역</b>, 장애인 보호구역)",
# "link": "https:\/\/blog.naver.com\/kwrentcar?Redirect=Log&logNo=222491332066",
# "description": "<b>노인 보호구역</b>은 교통약자인 노인을 보호하기 위해 경로당, 양로원, 노인 복지시설과 같이 노인들의 통행량이 많은 구역에 설치되며 실버존(Silver Zone)이라고도 불립니다. 방금 안내해드린 어린이 보호구역... ",
# "bloggername": "견우렌트카",
# "bloggerlink": "https://blog.naver.com/kwrentcar",
# "postdate": "20210901"
#
# },
# {
# "title": "계양구의 실버존! '<b>노인 보호구역</b>'에 대해 알아보자!",
# "link": "https:\/\/blog.naver.com\/gyeyang_gu?Redirect=Log&logNo=221813772748",
# "description": "놓기에 '효성노인문화센터'도 <b>노인 보호구역</b>에 해당하고 있습니다. <b>노인 보호구역</b>에서의 속도제한은 어린이보호구역과 마찬가지로 30인데, 큰 길가로 접어들 때쯤 되니 속도제한을 해제한다는 안내판도 함께... ",
# "bloggername": "계양구청 공식 블로그",
# "bloggerlink": "https://blog.naver.com/gyeyang_gu",
# "postdate": "20200218"
#
# },
# {
# "title": "[별별친구들 최종욱] <b>노인 보호구역</b>과 노인 보행권",
# "link": "https:\/\/blog.naver.com\/nhrck?Redirect=Log&logNo=221736360692",
# "description": "선정, 노인들의 안전한 통행을 보장하고자 지정된 교통약자보호구역입니다. (서울 <b>노인보호구역</b> 출처=서울시) 해당 법령은 도로교통법 제12조 2항인데요. “시장 등은 교통사고의 위험으로부터 노인을... ",
# "bloggername": "인권 속, 별별 이야기",
# "bloggerlink": "https://blog.naver.com/nhrck",
# "postdate": "20191213"
#
# },
# {
# "title": "춘천 <b>노인보호구역</b> 안전사각지대···과속단속카메라 “전무”",
# "link": "https:\/\/blog.naver.com\/mstoday10?Redirect=Log&logNo=222483149541",
# "description": "어린이·노인·장애인 보호구역 통합지침에 따르면 <b>노인보호구역</b>은 노인복지시설 등을 설립·운영하는 자가 지정 신청하도록 명시했다. 이에 노인들의 주 방문지역인 전통시장, 실내 광장 등은 사각지대로... ",
# "bloggername": "ms투데이(엠에스투데이) 공식블로그",
# "bloggerlink": "https://blog.naver.com/mstoday10",
# "postdate": "20210825"
#
# },
# {
# "title": "노인의 보행안전 보장을 위한 제도, &quot;<b>노인보호구역</b>&quot;",
# "link": "https:\/\/blog.naver.com\/peysu?Redirect=Log&logNo=222369820646",
# "description": "♣ 사진 출처: https://content.v.kakao.com/v/5e28f6fabc6d9b20e0b9cf61 2018년 우리나라는 65세이상 노인인구... <b>노인보호구역</b>은 어린이보호구역과 동일하게 법규 위반시 과태료, 범칙금, 벌점이 기존에 비해 2배... ",
# "bloggername": "세종시 가정재가복지센터",
# "bloggerlink": "https://blog.naver.com/peysu",
# "postdate": "20210527"
#
# },
# {
# "title": "<b>노인보호구역</b> 미끄럼방지포장재 시공",
# "link": "https:\/\/blog.naver.com\/indesign24?Redirect=Log&logNo=222214822863",
# "description": "이렇게 드림인디자인 미끄럼방지 포장재는 경사로나 어린이보호구역 또는 <b>노인보호구역</b> 등에 미끄럼방지 기능과 운전자의 시인성 확보를 목적으로 하는 기능성 도로포장재입니다. 미끄럼방지포장재 자재 및... ",
# "bloggername": "(주)드림인디자인 미끄럼방지포장",
# "bloggerlink": "https://blog.naver.com/indesign24",
# "postdate": "20210121"
#
# },
# {
# "title": "안전을 위한 어린이·<b>노인</b>·장애인 <b>보호구역</b> 지정 신청하세요!",
# "link": "https:\/\/blog.naver.com\/gjcityi?Redirect=Log&logNo=222167040477",
# "description": "각 보호구역의 지정대상 및 절차를 알려드릴게요~ 어린이·노인·장애인 보호구역 지정대상 1)... 2) <b>노인 보호구역</b> - 「노인복지법」제31조에 따른 노인복지시설 중 노인주거복지시설, 노인의료복지시설 및... ",
# "bloggername": "너른고을 광주시 공식 블로그",
# "bloggerlink": "https://blog.naver.com/gjcityi",
# "postdate": "20201208"
#
# },
# {
# "title": "강동구, 어린이·<b>노인보호구역</b> 확대 지정",
# "link": "https:\/\/blog.naver.com\/inhoo0182?Redirect=Log&logNo=222162967658",
# "description": "어린이보호구역으로, 구립강암경로당을 <b>노인보호구역</b>으로 지정하고 교통안전 시설물 설치·정비에... 이정훈 강동구청장은 “우리 구는 어린이·노인·장애인 등 교통약자 보호구역 97개소를 운영하고 있다.... ",
# "bloggername": "더불어 행복한 강동",
# "bloggerlink": "https://blog.naver.com/inhoo0182",
# "postdate": "20201204"
#
# },
# {
# "title": "진산면 두지리, 지방리 <b>노인보호구역</b> 정비 완료",
# "link": "https:\/\/blog.naver.com\/jss7166?Redirect=Log&logNo=221936835075",
# "description": "도로 <b>노인보호구역</b> 정비를 완료했다. 군은 두지리와 지방리 1.8km 구간에 보행자의 안전을 위한... 8km 구간에 인도설치 등 <b>노인보호구역</b> 정비사업을 완료함에 따라 마을 어르신들이 교통사고 위험에서 안전하게... ",
# "bloggername": "장성수 열린세상-금산중앙신문",
# "bloggerlink": "https://blog.naver.com/jss7166",
# "postdate": "20200429"
#
# },
# {
# "title": "<b>노인보호구역</b> 스쿨존교통사고 처벌수위와 감경위한 조치는?",
# "link": "https:\/\/blog.naver.com\/godotaxlaw?Redirect=Log&logNo=222275764926",
# "description": "해당 구역에서 규정을 잘 지키지도 않곤 합니다. <b>노인보호구역</b> <b>노인 보호구역</b>이란, 교통약자인 노인을 교통사고의 위험에서 보호하기 위해 양로원, 경로당, 노인 주거·의료·여가 복지시설 등 노인들의... ",
# "bloggername": "승소로 가는 지름길",
# "bloggerlink": "https://blog.naver.com/godotaxlaw",
# "postdate": "20210317"
#
# },
# {
# "title": "어린이 보호구역 및 <b>노인 보호구역</b>에서 지켜야 할 안전수칙!",
# "link": "https:\/\/blog.naver.com\/ynk-global?Redirect=Log&logNo=222455595075",
# "description": "지정된 보호구역을 의미합니다 <b>노인 보호구역</b>(=실버존)은 양로원, 경로당, 노인복지시설 등 노인들의 통행량이 많은 구역을 선정하여 노인들의 안전한 통행을 보장하고자 하는 지정된 교통약자 보호구역을... ",
# "bloggername": "YNK global",
# "bloggerlink": "https://blog.naver.com/ynk-global",
# "postdate": "20210803"
#
# },
# {
# "title": "[안전뉴스] <b>노인보호구역</b>, 실버존을 아시나요?",
# "link": "https:\/\/blog.naver.com\/cooolbusan?Redirect=Log&logNo=221678152640",
# "description": "<b>노인보호구역</b>(Silver Zone)은 시장, 경로당, 노인복지시설 등 노인들의 통행량이 많은 구역을 선정해... 교통안전 구역입니다. 노인 보호 표지판, 과속방지턱, 미끄럼 방지시설을 갖추고 있습니다. 전국에 1,457개소... ",
# "bloggername": "부산광역시 대표 블로그",
# "bloggerlink": "https://blog.naver.com/cooolbusan",
# "postdate": "20191015"
#
# },
# {
# "title": "아산시, 어린이·<b>노인 보호구역</b> 개선 '우수 기관' 선정",
# "link": "https:\/\/blog.naver.com\/satleceo?Redirect=Log&logNo=222195555913",
# "description": "어린이·<b>노인 보호구역</b> 개선사업 분야 전국 '우수 기관'으로 선정됐다. 4일 시에 따르면 이번 평가는... 도로를 보호구역으로 신규 지정하고 개선사업을 추진했으며 노인들이 새벽 및 야간에 주로... ",
# "bloggername": "아산사랑 소식",
# "bloggerlink": "https://blog.naver.com/satleceo",
# "postdate": "20210104"
#
# },
# {
# "title": "전통시장 보행 안전 강화 '<b>노인보호구역</b>' 지정",
# "link": "https:\/\/blog.naver.com\/hcnnewswide?Redirect=Log&logNo=222320085146",
# "description": "기본 설계를 6월까지 완료하고 7월부터 공사에 들어가서 빠르면 8월에서 9월에 주민에게 <b>노인보호구역</b>이 지정됐다는 걸 알 수 있게 하겠습니다. 최근 3년간 일어난 노인 보행 사고 사망자는 230여 명. 서울시는... ",
# "bloggername": "현대HCN 뉴스와이드 지역채널 Ch1 블로그",
# "bloggerlink": "https://blog.naver.com/hcnnewswide",
# "postdate": "20210423"
#
# },
# {
# "title": "<b>노인보호구역</b>(실버존)의 정의와 주의할점",
# "link": "https:\/\/blog.naver.com\/dusonmoa100?Redirect=Log&logNo=222233140736",
# "description": "보호구역으로 지정되면 표지판, 도로표지 등 도로부속물을 설치할 수 있고 보호구역 내 교통안전시설 설치가 가능하다. 지정대상 <b>노인보호구역</b>의 지정대상은 양로원, 경로당, 노인복지시설, 자연공원... ",
# "bloggername": "노인 활동지원 서비스 - 두손모아",
# "bloggerlink": "https://blog.naver.com/dusonmoa100",
# "postdate": "20210208"
#
# },
# {
# "title": "'<b>노인 보호구역</b>' 을 아시나요?",
# "link": "https:\/\/blog.naver.com\/rldjr05?Redirect=Log&logNo=222200739656",
# "description": "도로에는 '<b>노인보호구역</b>' 이른바 '실버 존'이 있습니다. <b>노인보호구역</b>이란 교통약자인 노인을 교통사고 위험에서 보호하기 위해 양로원, 경로당, 노인복지시설 등 노인들의 통행량이 많은 구역을 선정하여... ",
# "bloggername": "즐거운주간보호센터",
# "bloggerlink": "https://blog.naver.com/rldjr05",
# "postdate": "20210108"
#
# },
# {
# "title": "고령자의 안전을 위한 '<b>노인보호구역</b>'이 확대됩니다!",
# "link": "https:\/\/blog.naver.com\/futurehope2017?Redirect=Log&logNo=222312303253",
# "description": "노인을 보호하는 구역, '<b>노인보호구역</b>'을 알고 계시나요? '어린이보호구역'은 익숙한데, <b>노인보호구역</b>은 생소하게 느껴지는 분들이 많으실 것 같아요. <b>노인보호구역</b>은 교통사고 위험에 취약한 노인을... ",
# "bloggername": "저출산고령사회위원회",
# "bloggerlink": "https://blog.naver.com/futurehope2017",
# "postdate": "20210416"
#
# },
# {
# "title": "<b>노인보호구역</b> 미끄럼방지포장재 시공",
# "link": "https:\/\/blog.naver.com\/indesign24?Redirect=Log&logNo=222252187543",
# "description": "완공 스샷들 보시죠~ 이렇게 해서 노인복지관, 체육공원 주변 <b>노인보호구역</b> 미끄럼방지포장재 시공을 완료했습니다. 이렇게 드림인디자인 미끄럼방지 포장재는 경사로나 어린이보호구역 또는 <b>노인보호구역</b>... ",
# "bloggername": "(주)드림인디자인 미끄럼방지포장",
# "bloggerlink": "https://blog.naver.com/indesign24",
# "postdate": "20210222"
#
# },
# {
# "title": "종로구 <b>노인보호구역</b>의 실태",
# "link": "https:\/\/blog.naver.com\/cis5308?Redirect=Log&logNo=222158018525",
# "description": "등 노인들의 통행량이 많은 구역을 선정하여 교통약자 보호구역으로 지정하는 것을 말한다. 도로가 <b>노인보호구역</b>으로 지정되면 그 구간에서 운전자는 시속 30 이하로 서행운전 해야한다. 또 지자체에서는... ",
# "bloggername": "bofull lover๑'ڡ'๑",
# "bloggerlink": "https://blog.naver.com/cis5308",
# "postdate": "20201130"
#
# },
# {
# "title": "<b>노인보호구역</b> '실버존'의 필요성과 실효성에 대하여",
# "link": "https:\/\/blog.naver.com\/100news_?Redirect=Log&logNo=222310620508",
# "description": "‘실버존’이란 △양로원 △경로당 △노인복지시설 등 고령자들의 통행량이 많은 구역을 선정하여... 어린이보호구역만큼 관리가 수월하지 못하다. 국토부는 <b>노인보호구역</b> ‘실버존’ 확대 설치 방안과... ",
# "bloggername": "백뉴스 블로그",
# "bloggerlink": "https://blog.naver.com/100news_",
# "postdate": "20210415"
#
# },
# {
# "title": "전통시장 주변, '<b>노인보호구역</b>' 지정  (서울경기케이블TV)",
# "link": "https:\/\/blog.naver.com\/cnmnews2015?Redirect=Log&logNo=222350689166",
# "description": "노인 보행 사고가 가장 빈번한 곳이 전통시장이었습니다. 서울시가 전통시장 주변을 <b>노인보호 구역</b>으로 지정했는데 어떤 부분이 개선되는지 박선화 기자가 알아봤습니다. 【 리포트 】 성북구... ",
# "bloggername": "딜라이브 서울경기케이블TV NEWS",
# "bloggerlink": "https://blog.naver.com/cnmnews2015",
# "postdate": "20210514"
#
# },
# {
# "title": "<b>노인보호구역</b>에서는 무조건 서행운행하세요",
# "link": "https:\/\/blog.naver.com\/vb_korea?Redirect=Log&logNo=222400710065",
# "description": "실버존은 주로 노인들이 많이 다니는 길에 곳에 지정하여 운영되고 있으며 <b>노인보호구역</b>은 어린이보호구역과 동일하게 벌금도 벌점도 스쿨존과 동일하게 운영하고 있다는 점 알아두세요 실버존 실행보다 제일... ",
# "bloggername": "내일을 즐기는 남자",
# "bloggerlink": "https://blog.naver.com/vb_korea",
# "postdate": "20210617"
#
# },
# {
# "title": "서울시, 전통시장 주변 '<b>노인보호구역</b>' 전국 최초 지정",
# "link": "https:\/\/blog.naver.com\/kk6031kk?Redirect=Log&logNo=222315434811",
# "description": "성대시장 노인보행사고 40% 전통시장서 발생하지만 ｢도로교통법｣ 상 구역 지정대상엔 미포함 1월... 시는 이 구간을 <b>노인보호구역</b>으로 지정해 운전자들이 노인 보행자들을 확실하게 보호하면서 운전토록 해... ",
# "bloggername": "코리아방송.신문",
# "bloggerlink": "https://blog.naver.com/kk6031kk",
# "postdate": "20210419"
#
# },
# {
# "title": "가평관내 <b>노인보호구역</b> 6개소 국비 지원",
# "link": "https:\/\/blog.naver.com\/gpjn2011?Redirect=Log&logNo=221812439726",
# "description": "한편 <b>노인보호구역</b> 신청은 「어린이·노인 및 장애인 보호구역의 지정 및 관리에 관한 규칙」에 따라 노인복지시설 등을 설립해 운영하는 사람은 시장이나 군수에게 노인복지시설 등의 주변 도로를 노인... ",
# "bloggername": "가평저널",
# "bloggerlink": "https://blog.naver.com/gpjn2011",
# "postdate": "20200217"
#
# },
# {
# "title": "서울시 전통시장 4곳주변도로 (시속 30Km <b>노인보호구역</b> 지정)",
# "link": "https:\/\/blog.naver.com\/jkgosicokr?Redirect=Log&logNo=222315376050",
# "description": "서울시가 오는 6월 중 전통시장 주변도로를 '<b>노인보호구역</b>'으로 지정 전통시장 주변도로가 <b>노인보호구역</b>으로 지정되는 건 처음 노인보행사고의 40%를 차지하는 전통시장 발생사고를 줄이기 위한 안전대책을... ",
# "bloggername": "믿고 맡길수 있는 수익형투자분석 상담",
# "bloggerlink": "https://blog.naver.com/jkgosicokr",
# "postdate": "20210419"
#
# },
# {
# "title": "<b>노인보호구역</b>도 내비게이션 음성안내",
# "link": "https:\/\/blog.naver.com\/spen123?Redirect=Log&logNo=222413739871",
# "description": "통해 노인 및 장애인 보호구역 안전운전 음성안내를 실시한다고 29일 밝혔다. 국내 모든 내비게이션... 그러나 <b>노인보호구역</b>(실버존)이나 장애인보호구역은 이 같은 음성안내 기능이 없어 표지판을 보지 못한... ",
# "bloggername": "아산뉴스(www.asannews.co.kr)- 지방시대의 참 언론",
# "bloggerlink": "https://blog.naver.com/spen123",
# "postdate": "20210629"
#
# },
# {
# "title": "<b>노인보호구역</b> 지정을 위한 행정예고",
# "link": "https:\/\/blog.naver.com\/ms711771?Redirect=Log&logNo=222449618570",
# "description": "점점 고령화가 되다보니 교통사고위험으로부터 노인을 보호하기 위한 <b>노인보호구역</b> 지정을 하네요. 구역 지정관련해서 <b>노인보호구역</b>이 생소해서 포스팅해 봅니다. 교통사고의 위험으로부터 노인을 보호하기... ",
# "bloggername": "군위탑부동산",
# "bloggerlink": "https://blog.naver.com/ms711771",
# "postdate": "20210729"
#
# },
# {
# "title": "<b>노인보호구역</b>(老人保護區域)   Silver Zone과 범칙금?",
# "link": "https:\/\/blog.naver.com\/nongae1000?Redirect=Log&logNo=222168807494",
# "description": "<b>노인보호구역</b>(老人保護區域) Silver Zone은 노인이 많은 시설 등의 주변 도로를 <b>노인 보호구역</b>으로 지정한 것입니다. 「어린이·노인 및 장애인 보호구역의 지정 및 관리에 관한 규칙」에 따라 노인복지시설 등을... ",
# "bloggername": "에나 '우물안 개구리'의 유유자적悠悠自適 Since2019",
# "bloggerlink": "https://blog.naver.com/nongae1000",
# "postdate": "20201210"
#
# },
# {
# "title": "<b>노인보호구역</b> 말뿐, 단속카메라 고작 2%",
# "link": "https:\/\/blog.naver.com\/cg5art?Redirect=Log&logNo=222068568681",
# "description": "현행법은 교통약자인 <b>노인</b>의 통행이 잦은 시설 주변 도로를 <b>노인</b> 교통<b>보호구역</b>으로 지정해 관리하고 있다. 하지만 <b>보호구역</b> 내 교통 단속 카메라가 제대로 설치된 사례는 2%에 불과했다. 전국 <b>노인</b>... ",
# "bloggername": "채권채무.사건사고",
# "bloggerlink": "https://blog.naver.com/cg5art",
# "postdate": "20200823"
#
# },
# {
# "title": "<b>노인보호구역</b>",
# "link": "https:\/\/blog.naver.com\/tsp5454?Redirect=Log&logNo=222301130582",
# "description": "<b>노인보호구역</b>도 어린이보호구역처럼 벌점, 벌칙금이 2배란 사실!! 심지어 집 앞에 바로 <b>노인보호구역</b>이더라구요.. 카드뉴스 만들고 알아씀.. 마음다리 활동을 통해 <b>노인보호구역</b>에서 안전속도를 지키는 베스트... ",
# "bloggername": "Garaming’",
# "bloggerlink": "https://blog.naver.com/tsp5454",
# "postdate": "20210406"
#
# },
# {
# "title": "<b>노인보호구역</b> 미끄럼방지포장 시공 - 스텐실",
# "link": "https:\/\/blog.naver.com\/indesign24?Redirect=Log&logNo=222224168041",
# "description": "#드림인디자인 #미끄럼방지포장 #스텐실 #미끄럼방지포장재 #도로미끄럼방지 #MMA #<b>노인보호구역</b>... 서울시 성북구 미끄럼방지포장재 시공 - 스텐실공법 실버복지센터 앞 <b>노인보호구역</b> 도로에요 이동주차... ",
# "bloggername": "(주)드림인디자인 미끄럼방지포장",
# "bloggerlink": "https://blog.naver.com/indesign24",
# "postdate": "20210129"
#
# },
# {
# "title": "<b>노인보호구역</b> 속도제한/단속/과태료",
# "link": "https:\/\/blog.naver.com\/daegu5077?Redirect=Log&logNo=222295330932",
# "description": "어린이 보호구역은 30km이내로 운전해야한다는거 많은 분들이 알고 계신것 같습니다. 하지만 <b>노인보호구역</b>은 제한속도가 얼마인지 잘 모르는 분들이 많은데요, <b>노인보호구역</b> 역시 30km이내로 제한해서... ",
# "bloggername": "Venture",
# "bloggerlink": "https://blog.naver.com/daegu5077",
# "postdate": "20210401"
#
# },
# {
# "title": "서울시, 노인보행사고 최다 전통시장 주변 '<b>노인보호구역</b>' 전국... ",
# "link": "https:\/\/blog.naver.com\/silveritv?Redirect=Log&logNo=222315583928",
# "description": "서울시가 물건과 시장 이용객, 불법주정차 차량 등으로 복잡하게 뒤엉켜 노인 보행사고의 가장 많은 40%가 발생하고 있는 전통시장 주변 도로를 전국 최초로 ‘<b>노인보호구역</b>’으로 지정한다. ｢도로교통법｣ 상... ",
# "bloggername": "100세시대를 위한      TV & NEWS",
# "bloggerlink": "https://blog.naver.com/silveritv",
# "postdate": "20210419"
#
# },
# {
# "title": "어린이 보호구역 아닌 <b>노인 보호구역</b>",
# "link": "https:\/\/blog.naver.com\/haboss1?Redirect=Log&logNo=222342620714",
# "description": "어린이 보호구역은 도시의 학교 등 주변에서 흔하게 볼 수 있는 도로 표시입니다. 출처 : 서울시 노원구청 블로그 그런데 <b>노인 보호구역</b>이 있다는 사실은 조금 생소합니다. 사실 도시를 벗어나면 아이들을 보기... ",
# "bloggername": "쌍둥이 아빠",
# "bloggerlink": "https://blog.naver.com/haboss1",
# "postdate": "20210508"
#
# },
# {
# "title": "<b>노인보호구역</b> 보행로 불법주차 - 과태료 부과 대상일까?",
# "link": "https:\/\/blog.naver.com\/jungenius77?Redirect=Log&logNo=222304253916",
# "description": "집 근처에 #<b>노인보호구역</b> #보행로 가 있다. 출근길 또는 주말에 이쪽 길을 가다 보면 꼭 한 차량이 있다. 이 차량 때문에 보행로 옆으로 가야 했다. 안전에도 문제가 생기게 된 것이다. 특히, 출근길에 지나갈때... ",
# "bloggername": "천진난만 스마일",
# "bloggerlink": "https://blog.naver.com/jungenius77",
# "postdate": "20210409"
#
# },
# {
# "title": "'<b>노인보호구역</b>'이라고 있다.",
# "link": "https:\/\/blog.naver.com\/khandole?Redirect=Log&logNo=222497265397",
# "description": "괜한 것들에 신경쓸 일이 아니다 <b>노인보호구역</b>, 공원 입구 도로에 표시된 도로 표시 하나, 처음 본다. 어린이보호구역이 아니다. 밥벌이로 매일 해야했던 일들과 경험한 일들 조차 바뀌고 희미한데 내가 아는... ",
# "bloggername": "如蓮花不染塵, 진흙에 물들지 않는 연꽃과 같이",
# "bloggerlink": "https://blog.naver.com/khandole",
# "postdate": "20210906"
#
# },
# {
# "title": "<b>노인보호구역</b> 서울시 강남구 자곡동",
# "link": "https:\/\/blog.naver.com\/pys3167?Redirect=Log&logNo=222102907675",
# "description": "서울 강남구 자곡동 &quot;<b>노인보호구역</b>&quot; 서울 강남 <b>노인보호구역</b> 서울강남부동산 관련해서 주변을 둘러보다가 교통 안전을 위해 어린이 보호구역 뿐만이 아니라 &quot;<b>노인보호구역</b>&quot;이 서울 강남구 자곡동에도 지정되어... ",
# "bloggername": "강릉부동산 황금나무 공인중개사",
# "bloggerlink": "https://blog.naver.com/pys3167",
# "postdate": "20200929"
#
# },
# {
# "title": "가평 <b>노인보호구역</b> 6개소 지정, 국비 3억원 확보",
# "link": "https:\/\/blog.naver.com\/gpjn2011?Redirect=Log&logNo=221822142092",
# "description": "한편 <b>노인보호구역</b>을 신청하기 위해서는 「어린이·노인 및 장애인 보호구역의 지정 및 관리에 관한 규칙」에 따라 노인복지시설 등을 설립해 운영하는 사람이 시장이나 군수에게 노인복지시설 등의 주변... ",
# "bloggername": "가평저널",
# "bloggerlink": "https://blog.naver.com/gpjn2011",
# "postdate": "20200224"
#
# },
# {
# "title": "노인 보행사고 많았던 경동시장, <b>노인보호구역</b> 운영 후 벌어진... ",
# "link": "https:\/\/blog.naver.com\/mltmkr?Redirect=Log&logNo=221968533287",
# "description": "서울에서 노인 보행사고가 가장 많았던 경동시장 <b>노인보호구역</b> 운영 후 어떻게 달라졌을까요?  #보행사고 #<b>노인보호구역</b> #교통사고 #교통안전 #안전속도5030",
# "bloggername": "국토교통부",
# "bloggerlink": "https://blog.naver.com/mltmkr",
# "postdate": "20200518"
#
# },
# {
# "title": "어린이<b>보호구역</b>, 장애인 주차<b>구역</b> 위반 과태료 총정리",
# "link": "https:\/\/blog.naver.com\/koroadblog?Redirect=Log&logNo=222480883393",
# "description": "아울러, 장애인 및 <b>노인 보호구역</b>에서는 승용차 8만 원, 승합차 9만 원으로 일반 구역에 2배의 과태료가 부과됩니다. 이처럼, 어린이보호구역과 노인 및 장애인 보호구역은 성인에 비해 사고 발생 시 대처능력이... ",
# "bloggername": "도로교통공단",
# "bloggerlink": "https://blog.naver.com/koroadblog",
# "postdate": "20210824"
#
# },
# {
# "title": "9월부터 자동차보험료할증 적용! 어린이<b>보호구역</b>, 과속벌금 내용",
# "link": "https:\/\/blog.naver.com\/canonkoreabs?Redirect=Log&logNo=222492812976",
# "description": "어린이, 노인, 장애인 보호구역(스쿨존) 등 20km 속도위반 1회 : 5% 할증 2. 어린이, 노인, 장애인... 일반 구역/교통약자 보호구역 범칙금 및 벌점 일반도로 외에 어린이, 장애인, <b>노인 보호구역</b> 등... ",
# "bloggername": "캐논코리아 비즈니스 솔루션 공식 블로그",
# "bloggerlink": "https://blog.naver.com/canonkoreabs",
# "postdate": "20210903"
#
# },
# {
# "title": "<b>노인 보호구역</b>",
# "link": "https:\/\/blog.naver.com\/ginny1021?Redirect=Log&logNo=222309073860",
# "description": "아이러니하게도 <b>노인 보호구역</b>에서 노인분들을 한 분도 못 만났다. 아주아주 조용한 동네, 오조리. 나 오, 비칠 조, 나를 비추다, 오조리... 참 예쁜 이름.",
# "bloggername": "낯익은 타인",
# "bloggerlink": "https://blog.naver.com/ginny1021",
# "postdate": "20210414"
#
# },
# {
# "title": "<b>노인보호구역</b> 미끄럼방지포장 - SP공법",
# "link": "https:\/\/blog.naver.com\/indesign24?Redirect=Log&logNo=222204661066",
# "description": "압인공법 #<b>노인보호구역</b> 안녕하세요 여러분^^ 드림인디자인 인사드립니다. 추운 날씨가 계속되고 있습니다. 이번 한 주의 시작 화이팅하시자구요~! 월요병없는 한 주 되시기를~ 오늘은 <b>노인보호구역</b>... ",
# "bloggername": "(주)드림인디자인 미끄럼방지포장",
# "bloggerlink": "https://blog.naver.com/indesign24",
# "postdate": "20210112"
#
# },
# {
# "title": "울산 남구 ‘2021년도 어린이 <b>보호구역</b> 개선사업’을... ",
# "link": "https:\/\/blog.naver.com\/ulsan-namgu?Redirect=Log&logNo=222490378779",
# "description": "어린이, <b>노인 보호구역</b>을 보행하는 중 발생한 사고입니다. 이처럼 교통약자를 위한 교통안전 준수가 매우 시급한 상황입니다. 이에 정부에서는 어린이보호구역에서의 교통 법규 위반 시 과태료를 상향하여... ",
# "bloggername": "울산광역시 남구",
# "bloggerlink": "https://blog.naver.com/ulsan-namgu",
# "postdate": "20210901"
#
# },
# {
# "title": "<b>노인보호구역</b> 확대 등 사람이 중심 되는 「교통안전 선진국」... ",
# "link": "https:\/\/blog.naver.com\/silveritv?Redirect=Log&logNo=221906165747",
# "description": "<b>노인보호구역</b> 확대 등 사람이 중심 되는 「교통안전 선진국」 추진- 2022년까지 교통사고 사망자 2,000명대 감축 위한 합동대책 발표 - 정부가 2022년까지 교통사고 사망자 2,000명대 감축을 위해 보행자... ",
# "bloggername": "100세시대를 위한      TV & NEWS",
# "bloggerlink": "https://blog.naver.com/silveritv",
# "postdate": "20200413"
#
# },
# {
# "title": "달라진 어린이<b>보호구역</b> 교통안전망 - 옐로 그늘막과... ",
# "link": "https:\/\/blog.naver.com\/yangju619?Redirect=Log&logNo=222424429054",
# "description": "그리고 양주시 어린이보호구역 현황을 살펴보면 보호구역 지정현황은 관내 초등학교, 유치원, 어린이집, <b>노인보호구역</b> 등 총괄 113개소가 지정되어있습니다. - 2020. 01. 03 기준 - ↓↓↓↓↓↓↓ 첨부파일... ",
# "bloggername": "양주시 공식블로그 [클릭양주]",
# "bloggerlink": "https://blog.naver.com/yangju619",
# "postdate": "20210708"
#
# },
# {
# "title": "강동구, 어린이·<b>노인</b> 등 交通弱者 <b>보호구역</b> 擴大",
# "link": "https://blog.daum.net/gumin/11286881",
# "description": "강동구 , 어린이 · 노인 등 交通弱者 보호구역 擴大 - 어린이보호구역 3 개소 · <b>노인보호구역</b> 1 개소 신규 지정 강동구 ( 구청장 이정훈 ) 가 어린이 , 노인 등 교통약자에게 안전한 보행환경을 만들기 위해... ",
# "bloggername": "권경호 기자의 강동-송파이야기",
# "bloggerlink": "https://blog.daum.net/gumin",
# "postdate": "20201208"
#
# },
# {
# "title": "<b>노인보호구역</b>을 아시나요?",
# "link": "https://www.driveind.com/1410",
# "description": "( ▲ 이미지 출처 : 키즈 현대 ) 어린이보호구역에 비해 상대적으로 덜 알려진 <b>노인보호구역</b> , 일명 ‘ 실버존 ’. <b>노인보호구역</b>은 교통약자인 노인을 교통사고의 위험으로부터 보호하기 위해 지난 2008 년... ",
# "bloggername": "DB손해보험 내차사랑 블로그 In:D",
# "bloggerlink": "https://www.driveind.com/",
# "postdate": "20170911"
#
# },
# {
# "title": "[교통문화] 안전 보행로 '<b>노인보호구역</b>' 대폭 확대한다",
# "link": "https://blog.daum.net/kcs9222/17202095",
# "description": "노인보구역 11개소 늘려, 교통안전시설물 설치 기사등록 2020-01-15 16:10:26 기사수정 [라이프타임즈 = 김가은 기자] 아산시가 지속적으로 늘어가는 노인들의 안전한 보행로 확보를 위해 <b>노인보호구역</b>을... ",
# "bloggername": "라이프타임즈",
# "bloggerlink": "https://blog.daum.net/kcs9222",
# "postdate": "20200115"
#
# },
# {
# "title": "미끄럼방지포장재 스텐실 - <b>노인보호구역</b>",
# "link": "https:\/\/blog.naver.com\/indesign24?Redirect=Log&logNo=222247691941",
# "description": "#드림인디자인 #미끄럼방지포장 #스텐실 #<b>노인보호구역</b> #도로미끄럼방지 #MMA #미끄럼방지효과... 오늘 보여드릴 현장은 스텐실 공법 <b>노인보호구역</b> 미끄럼방지포장재 시공현장입니다. 함께 보러 가시죠~ 서울시... ",
# "bloggername": "(주)드림인디자인 미끄럼방지포장",
# "bloggerlink": "https://blog.naver.com/indesign24",
# "postdate": "20210218"
#
# },
# {
# "title": "어린이보호구역과 <b>노인보호구역</b> 지정 기준은?",
# "link": "https:\/\/blog.naver.com\/koroadblog?Redirect=Log&logNo=221422379718",
# "description": "이렇게 어린이와 노인을 보호하기 위하여 도로엔 어린이보호구역과 <b>노인보호구역</b>을 지정해 놓고 있습니다. 그렇다면 어린이보호구역과 <b>노인보호구역</b>은 어떻게 정해지는 걸까요? 지금부터 그 기준을... ",
# "bloggername": "도로교통공단",
# "bloggerlink": "https://blog.naver.com/koroadblog",
# "postdate": "20181219"
#
# },
# {
# "title": "[인디:D의 사소한 궁금증] <b>노인보호구역</b>, 실버존이 궁금해!",
# "link": "https://www.driveind.com/1666",
# "description": "(▲출처 : Wikimedia ) ‘실버존’이란, 2008년부터 도입되어 시행하고 있는 <b>노인보호구역</b>을 의미하는데요. 교통 약자인 어린이, 장애인과 함께 노인도 별도의 보호구역이 필요하다는 의미에서 선정된 교통안전... ",
# "bloggername": "DB손해보험 내차사랑 블로그 In:D",
# "bloggerlink": "https://www.driveind.com/",
# "postdate": "20180911"
#
# },
# {
# "title": "<b>노인보호구역</b>, 실버존을 아시나요?",
# "link": "https:\/\/blog.naver.com\/ajsellcar11?Redirect=Log&logNo=221383386252",
# "description": "실버존은 2008년부터 우리나라에 도입되어 시행되고 있는 <b>노인보호구역</b>입니다. 어린이 보호구역과... 그렇기 때문에 어린이와 마찬가지로 노인분들 역시 보호를 받아야 하는 것이죠. 또한 교통 법규에 대한... ",
# "bloggername": "에이제이셀카공식블로그",
# "bloggerlink": "https://blog.naver.com/ajsellcar11",
# "postdate": "20181025"
#
# },
# {
# "title": "<b>노인보호구역</b>, 속도를 줄여주세요",
# "link": "https:\/\/blog.naver.com\/poldaejeon?Redirect=Log&logNo=221298523528",
# "description": "<b>노인보호구역</b>에서는 필요시 - 대상시설의 출입문을 중심으로 반경 300m 이내 도로 중 일정 구간을 보호구역으로 설정- 주출입문과 가까운 간선도로의 횡단보도에는 노인들의 보행속도를 감않해 점등시간이... ",
# "bloggername": "대전경찰 현장스토리",
# "bloggerlink": "https://blog.naver.com/poldaejeon",
# "postdate": "20180614"
#
# },
# {
# "title": "<b>노인보호구역</b>",
# "link": "https:\/\/blog.naver.com\/mhhappy75?Redirect=Log&logNo=221556028804",
# "description": "아이들이 오가던 시절에는 '어린이보호구역'으로 사용되었을 표지판이... '<b>노인보호구역</b>'으로 둔갑해있었다. 현재 이 폐교는 마을교육을 연구하고 실천하는 공간으로 활용되고 있다고 들었다. 폐교건물이 노인분... ",
# "bloggername": "행복바라기",
# "bloggerlink": "https://blog.naver.com/mhhappy75",
# "postdate": "20190606"
#
# },
# {
# "title": "<b>노인보호구역</b> 고령화시대 시골마을",
# "link": "https:\/\/blog.naver.com\/ok00124?Redirect=Log&logNo=221219866416",
# "description": "백세시대라지요 <b>노인보호구역</b> 학교근처에 어린이보호구역 시골한적한 동네앞를 지나다보면 눈에 띄는 이색 표지판이예요 할머니 할아버지가 손잡고 건널목건너는 표지판입니다 저만치 마을이보지요 아이는... ",
# "bloggername": "은자골전통된장",
# "bloggerlink": "https://blog.naver.com/ok00124",
# "postdate": "20180302"
#
# },
# {
# "title": "<b>노인보호구역</b>에 대해서 들어보셨습니까?",
# "link": "https:\/\/blog.naver.com\/mltmkr?Redirect=Log&logNo=220884691359",
# "description": "늘어나고 있는 노인의 수 <b>노인보호구역</b>은 어린이 보호구역의 약 5%수준으로 총 670곳에 불과하다고 합니다. 또한 <b>노인보호구역</b>은 예산문제 때문에도 많이 생기지 못한다고 합니다. 어린이보호구역 같은... ",
# "bloggername": "국토교통부",
# "bloggerlink": "https://blog.naver.com/mltmkr",
# "postdate": "20161213"
#
# },
# {
# "title": "<b>노인보호구역</b>에서 만난 배려의 한 수!",
# "link": "https:\/\/blog.naver.com\/ktv520?Redirect=Log&logNo=220977457530",
# "description": "어린이 보호구역처럼 교통약자인 노인을 보호하기 위해 2008년부터 시행 된 <b>노인보호구역</b> 하지만 <b>노인보호구역</b>을 아는 사람은 생각보다 매우 적습니다. 2014년 6월 기준 678개가 지정되어 이 곳에서 규정속도인... ",
# "bloggername": "KTV국민방송",
# "bloggerlink": "https://blog.naver.com/ktv520",
# "postdate": "20170407"
#
# },
# {
# "title": "<b>노인 보호구역</b>, 실버존을 얼마나 알고 계시나요?",
# "link": "https:\/\/blog.naver.com\/incheonmoo?Redirect=Log&logNo=221389086502",
# "description": "동대문구에 있는 경동시장이 전국 최악의 노인 교통사고 지역이었지만 <b>노인 보호구역</b>으로 지정하여 보호구역을 알리는 빨간색 도색, 중앙분리대 설치를 하는 등 노인 교통사고를 줄이기 위해 노력한 결과... ",
# "bloggername": "청소년웹진 MOO",
# "bloggerlink": "https://blog.naver.com/incheonmoo",
# "postdate": "20181031"
#
# },
# {
# "title": "<b>노인보호구역</b> · 장애인보호구역 적용범위 확대 및 범칙금 안내",
# "link": "https://www.driveind.com/795",
# "description": "<b>노인보호구역</b> · 장애인보호구역에 해당하는 곳은 노인복지법 제31조에 따른 노인복지시설 중 행정안전부령으로 정하는 시설, 자연공원법 제2조 제1호에 따른 자연공원 또는, 도시공원 및 녹지 등에 관한... ",
# "bloggername": "DB손해보험 내차사랑 블로그 In:D",
# "bloggerlink": "https://www.driveind.com/",
# "postdate": "20150414"
#
# },
# {
# "title": "어린이<b>보호구역</b> 말고 <b>노인</b>·장애인<b>보호구역</b>도 있어요!",
# "link": "https:\/\/blog.naver.com\/120seoulcall?Redirect=Log&logNo=221352812566",
# "description": "어린이 보호구역이 대부분 학교 근처에 지정되는데 비해, <b>노인보호구역</b>은 노인주거복지시설, 노인의료복지시설, 노인여가복지시설 앞에 지정된다. 쉽게 말해 우리가 흔히 알고 있는 노인복지관이나 요양원... ",
# "bloggername": "서울시 120다산콜센터 공식 블로그",
# "bloggerlink": "https://blog.naver.com/120seoulcall",
# "postdate": "20180905"
#
# },
# {
# "title": "이름뿐인 어린이·<b>노인 보호구역</b>, 이대로 괜찮을까?",
# "link": "https:\/\/blog.naver.com\/jdind1233?Redirect=Log&logNo=221080162516",
# "description": "도로교통법에 어린이 보호구역 내 사고는 11대 중과실 사고에 포함되지만 <b>노인보호구역</b>은 정해진 조치를 준수하고 노인 안전에 유의하면서 운행할 것을 짧게 명시하고 있을 뿐이지 규정 위반에 대한 특별한... ",
# "bloggername": "신도산업 공식블로그",
# "bloggerlink": "https://blog.naver.com/jdind1233",
# "postdate": "20170823"
#
# },
# {
# "title": "<b>노인 보호 구역</b> ''실버 존'' 확대",
# "link": "https://blog.daum.net/logosds/11603105",
# "description": "‘ <b>노인보호구역</b> ’이다. 실버존으로 지정되면 노인복지시설 주 출입문을 중심으로 반경 300m 이내의 도로 중 일정구간을 보호구역으로 정하고, 보호구역 안에서 구간별·시간대별로 자동차의 통행을... ",
# "bloggername": "진리가 너희를 자유케 하리라",
# "bloggerlink": "https://blog.daum.net/logosds",
# "postdate": "20071126"
#
# },
# {
# "title": "말 뿐인 '<b>노인보호구역</b>'",
# "link": "https:\/\/blog.naver.com\/abn_co_kr?Redirect=Log&logNo=220297584716",
# "description": "어디서부터 어디까지가 보호구역인지 경계도 확실히 해주고 아스팔트에 색을 다르게 입혀주거나 하면 좋지 않겠어요? 운전자가 지킬 수 있게 해줘야지….&quot; 다른 <b>노인보호구역</b>은 사정이 더 심각합니다.... ",
# "bloggername": "성남 시민과 함께하는 아름방송",
# "bloggerlink": "https://blog.naver.com/abn_co_kr",
# "postdate": "20150312"
#
# },
# {
# "title": "'<b>노인 보호구역</b>' 과태료·범칙금 2배 부과",
# "link": "https:\/\/blog.naver.com\/120seoulcall?Redirect=Log&logNo=220281552067",
# "description": "노인·장애인 보호구역 내 법규위반 처벌규정(클릭) 서울시는 3월말까지 <b>노인 보호구역</b>의 강화된 법령에 대해 옥외전광판, 지하철·버스 홍보매체 등을 이용하여 대시민 홍보를 할 예정이며, 경찰은... ",
# "bloggername": "서울시 120다산콜센터 공식 블로그",
# "bloggerlink": "https://blog.naver.com/120seoulcall",
# "postdate": "20150224"
#
# },
# {
# "title": "[TS기자단] 실버존, <b>노인보호구역</b>에 대해 알고 계시나요?",
# "link": "https:\/\/blog.naver.com\/dahong24?Redirect=Log&logNo=220182412256",
# "description": "&lt;개정 2013.3.23.&gt; ③ 차마의 운전자는 <b>노인 보호구역</b> 또는 장애인 보호구역에서 제1항에 따른 조치를 준수하고 노인 또는 장애인의 안전에 유의하면서 운행하여야 한다. [전문개정 2011.6.8.] 그러나 많은 사람들이... ",
# "bloggername": "얼굴 빨개지는 아이의 새빨간 날",
# "bloggerlink": "https://blog.naver.com/dahong24",
# "postdate": "20141115"
#
# },
# {
# "title": "<b>노인 보호구역</b>",
# "link": "http://blog.moneta.co.kr/blog.log.view.screen?blogId=yoonk1211&logId=8382554",
# "description": "어린이 보호구역이란 말은 예전부터 있어 왔으나 <b>노인보호구역</b>이란 말은 신조어에 가깝다. 노인도 우대받아야 할 세상. 나는 언제쯤 노인의 경지에 이를 수 있을까. 어린 사람으로부터 한번 들어보기는... ",
# "bloggername": "자작의 오픈일기",
# "bloggerlink": "http://blog.moneta.co.kr/blog.screen?blogId=yoonk1211",
# "postdate": "20200723"
#
# },
# {
# "title": "[11. 27] 실버존(<b>노인보호구역</b>)의 효율적 운영방안 토론회” 개최",
# "link": "https:\/\/blog.naver.com\/joo350?Redirect=Log&logNo=220193680926",
# "description": "그러나 가장 기본적인 노인보호 교통정책이라고 할 수 있는 <b>노인보호구역</b>의 경우 현재 전국에 626개소에 불과해 어린이보호구역의 4% 수준에 그치고 있고, 통행속도 제한규정도 없으며, 예산지원도 전무한... ",
# "bloggername": "주승용과 함께 만드는 희망세상입니다.",
# "bloggerlink": "https://blog.naver.com/joo350",
# "postdate": "20141127"
#
# },
# {
# "title": "‘<b>노인보호구역</b> 실버존(Silver Zone)’ 들어 보셨나요.",
# "link": "https:\/\/blog.naver.com\/yeonsoonseo?Redirect=Log&logNo=221391749349",
# "description": "아마 대부분의 사람들은 ‘어린이보호구역은 알고 있지만 <b>노인보호구역</b>은 처음 들어본다’는 반응이다. <b>노인보호구역</b>이란 어린이와 같이 노인도 교통사고의 위험으로부터 보호하기 위해 지정된... ",
# "bloggername": "웰컴시니어",
# "bloggerlink": "https://blog.naver.com/yeonsoonseo",
# "postdate": "20181109"
#
# },
# {
# "title": "진산면 두지리, 지방리 <b>노인보호구역</b> 정비 완료",
# "link": "https://blog.daum.net/gmb777/7090718",
# "description": "진산면 두지리, 지방리 <b>노인보호구역</b> 정비 완료 댓글 0 금산중앙신문 2020. 4. 29. 진산면 두지리, 지방리 <b>노인보호구역</b> 정비 완료 1.8km 구간 인도설치, 길어깨 확장, 교통안전시설 등 지역주민 교통사고 위험 해소... ",
# "bloggername": "장성수열린세상 - 금산중앙신문",
# "bloggerlink": "https://blog.daum.net/gmb777",
# "postdate": "20200429"
#
# },
# {
# "title": "교통범칙금 대폭인상-<b>노인</b> 장애인<b>보호구역</b> 교통위반시... ",
# "link": "https:\/\/blog.naver.com\/dyj20055?Redirect=Log&logNo=220296935623",
# "description": "(95년),<b>노인보호구역</b>(06년),장애인보호구역(10년)순으로 법제화 이미 지난 2010년12월부터 어린이보호구역에서 주간시간대(08~20시) 법규위반시 일반도로에 비해최대 2배 가중처벌 하고 있으며, 이와 유사한 노인... ",
# "bloggername": "거북이 님의 블로그^*^",
# "bloggerlink": "https://blog.naver.com/dyj20055",
# "postdate": "20150311"
#
# },
# {
# "title": "어린이·<b>노인보호구역</b> 개선사업 '본격 착수'",
# "link": "https:\/\/blog.naver.com\/first_seogu?Redirect=Log&logNo=80178777164",
# "description": "어린이와 노인의 교통사고 예방을 위해 어린이·<b>노인보호구역</b>에 대한 교통안전시설 개선사업을 이번... 어린이보호구역 111개소 중 93개소, <b>노인보호구역</b> 8개소 중 5개소에 대한 정비사업을 완료하였으며... ",
# "bloggername": "대전광역시 서구청 블로그입니다.",
# "bloggerlink": "https://blog.naver.com/first_seogu",
# "postdate": "20130117"
#
# },
# {
# "title": "<b>노인보호구역</b>_충무로인쇄골목에 나타나다!",
# "link": "https:\/\/blog.naver.com\/tntwkrpdla?Redirect=Log&logNo=221577749643",
# "description": "<b>노인보호구역</b>?? 이게 뭐얌?? '어린이보호구역'은 익히 들어 알고 있지만... '<b>노인보호구역</b>'은 처음 듣는 인쇄쟁이. 심지어 도로 바닥에 커다랗게 <b>노인보호구역</b>이라 적혀 있는 것도 처음 본 인쇄쟁이입니다. 오호.... ",
# "bloggername": "주식회사 우정피앤피",
# "bloggerlink": "https://blog.naver.com/tntwkrpdla",
# "postdate": "20190705"
#
# },
# {
# "title": "[강동구] 어린이, <b>노인보호구역</b> 주변 교차점 표시 안내",
# "link": "https:\/\/blog.naver.com\/gangdongpr?Redirect=Log&logNo=220710102628",
# "description": "9%를 하는데요~ 우리 구는 폭 12m 미만 생활도로 중 보행안전 취약지점인 어린이·<b>노인 보호구역</b>... 강동노인회관 주변 등 보행안전 취약지점을 대상으로 70개 지점을 선정해 교차점을 표시했습니다~ 그리고... ",
# "bloggername": "강동구 공식블로그",
# "bloggerlink": "https://blog.naver.com/gangdongpr",
# "postdate": "20160516"
#
# },
# {
# "title": "<b>노인보호구역</b>, 실버존(Silver zone)도 지켜주세요!!",
# "link": "https:\/\/blog.naver.com\/polinlove2?Redirect=Log&logNo=221411927909",
# "description": "구간을 <b>노인보호구역</b>으로 지정하여 차마의 통행을 제한하거나 금지하는 등 필요한 조치를 할 수 있다.”라고 규정하고 있습니다. 이처럼 교통 약자인 어린이, 장애인과 마찬가지로 노인도 별도의 보호구역이... ",
# "bloggername": "대한민국 경찰청",
# "bloggerlink": "https://blog.naver.com/polinlove2",
# "postdate": "20181204"
#
# },
# {
# "title": "동대문구 <b>노인보호구역</b>",
# "link": "https:\/\/blog.naver.com\/ddm4you?Redirect=Log&logNo=221411930300",
# "description": "동대문구의 패기넘치는 청년들이 <b>노인 보호구역</b>과 보행권 및 교통문제에 대해 고민하고 연구해 자료를 만들어 보내주었어요^^ 경희대학교 시민교육 수업 DOAR(Declaration of Old Age Rights)조 입니다. 직접... ",
# "bloggername": "동대문구청 공식 블로그",
# "bloggerlink": "https://blog.naver.com/ddm4you",
# "postdate": "20181204"
#
# },
# {
# "title": "도로 위 <b>노인 보호 구역</b>, '실버존'이란?",
# "link": "https://blog.kumhotire.co.kr/1404?category=651778",
# "description": "'실버존(Silver Zone)'은 노인들을 교통사고 위험에서 보호하기 위해 노인복지시설, 경로당 등 어르신들의 통행량이 많은 구역에 설치한 <b>노인 보호 구역</b>이에요. 실버존은 교통약자인 노인들의 안전한... ",
# "bloggername": "금호타이어",
# "bloggerlink": "https://blog.kumhotire.co.kr/",
# "postdate": "20190311"
#
# },
# {
# "title": "<b>노인보호구역</b>(실버존)이란?",
# "link": "https://smartsmpa.tistory.com/4571",
# "description": "교통사고의 위험으로부터 노인을 보호하기 위하여 필요하다고 인정될 때 <b>노인 보호구역</b>으로 지정하여 운영 - 어린이/노인/장애인 보호구역의 지정 및 관리에 관한 규칙 <b>노인보호구역</b>에서 교통법규 위반시... ",
# "bloggername": "스마트 서울경찰",
# "bloggerlink": "https://smartsmpa.tistory.com/",
# "postdate": "20181102"
#
# },
# {
# "title": "실버 존(silver zone, <b>노인보호구역</b>), 우리는 얼마나 알고... ",
# "link": "https:\/\/blog.naver.com\/yeonsoonseo?Redirect=Log&logNo=221001290851",
# "description": "실버 존(silver zone, <b>노인보호구역</b>), 우리는 얼마나 알고 있을까?기사입력 : 2017-05-08 13:52 [ 김종호 순경... 선정하여 노인들의 안전한 통행을 보장하고자 하는 지정된 교통약자보호구역을 말한다. 실버 존은... ",
# "bloggername": "웰컴시니어",
# "bloggerlink": "https://blog.naver.com/yeonsoonseo",
# "postdate": "20170509"
#
# },
# {
# "title": "<b>노인보호구역</b> 실버존?",
# "link": "https:\/\/blog.naver.com\/e_mobis?Redirect=Log&logNo=20192758074",
# "description": "<b>노인 보호구역</b> 지정 대상은 다음과 같다. ① ‘노인복지법’ 제31조에 따른 노인복지시설 ②... 또한 노인보호에 대한 인지강화를 위해 관련 캠페인 등 다양한 방법을 통해 홍보를 강화해야 한다. 노인복지관... ",
# "bloggername": "현대모비스 공식 블로그",
# "bloggerlink": "https://blog.naver.com/e_mobis",
# "postdate": "20130730"
#
# },
# {
# "title": "06] <b>노인보호구역</b> 내 속도제한 규정을 신설 위한... ",
# "link": "https:\/\/blog.naver.com\/joo350?Redirect=Log&logNo=220173448348",
# "description": "이러한 무관심을 더 이상 지켜볼 수 없어 저는 오늘 도로교통법 개정안을 대표 발의 했고, 앞으로 이 법안의 조속한 국회통과와 함께 <b>노인보호구역</b> 확대 지정 등 노인교통사고 감소를 위해 더욱 노력하겠습니다.",
# "bloggername": "주승용과 함께 만드는 희망세상입니다.",
# "bloggerlink": "https://blog.naver.com/joo350",
# "postdate": "20141106"
#
# },
# {
# "title": "교통사고 예방을 위한 <b>노인보호구역</b> 확대",
# "link": "https:\/\/blog.naver.com\/cjcityblog?Redirect=Log&logNo=221291310888",
# "description": "노인 통행량이 많은 흥덕시니어클럽 주변, 옥산 가락2ㆍ3리 경로당 주변, 우암노인정 주변 등 8곳을 <b>노인 보호구역</b>으로 추가 지정했습니다. 노인 보후구역으로 지정되면 노인보호표지판을 비롯해 과속방지턱... ",
# "bloggername": "청주시청 공식 블로그",
# "bloggerlink": "https://blog.naver.com/cjcityblog",
# "postdate": "20180611"
#
# },
# {
# "title": "[소요산/동두천]<b>노인보호구역</b>",
# "link": "https:\/\/blog.naver.com\/ijun4u?Redirect=Log&logNo=70120720169",
# "description": "자재가 많을 것같은 자재암 주지는 비에 무너진 길은 소중하여 현수막까지 내걸어 고마워 하면서 그 길에 앉은 수백명의 노인들은 눈에 들어오지 않는가보다. 소요산! 여기는 진정 <b>노인보호구역</b>인가? Silver Zone... ",
# "bloggername": "광야의 산행기 \"올라[Hola]~\"",
# "bloggerlink": "https://blog.naver.com/ijun4u",
# "postdate": "20111008"
#
# },
# {
# "title": "<b>노인보호구역</b>,상주시의회 시장질의,상주경찰,야생동물... ",
# "link": "https:\/\/blog.naver.com\/hcnnewser?Redirect=Log&logNo=220262914059",
# "description": "4월부터 노인, 장애인보호구역 등지에서 통행금지와 주정차, 신호위반을 할 경우 범칙금이 2배로 늘어납니다. 민병희 / 상주경찰서 교통관리계장 <b>노인보호구역</b> 등지에서 주요 법규 위반 시 가중처벌 시행에... ",
# "bloggername": "HCN뉴스와이드",
# "bloggerlink": "https://blog.naver.com/hcnnewser",
# "postdate": "20150204"
#
# },
# {
# "title": "충남경찰, 어린이·<b>노인 보호구역</b> 교통안전 확보 나서",
# "link": "https:\/\/blog.naver.com\/dragon48?Redirect=Log&logNo=120154769315",
# "description": "및 <b>노인보호구역</b>에서의 서행 유도로 운전자들의 경각심을 높일 계획이다. 경찰 관계자는 “12세 이하 어린이의 경우 작은키, 주의력·자기방어력 미흡, 노인의 경우 평균 보행속도가 늦고 좌우를 확인하지... ",
# "bloggername": "신아일보 대전·충남취재본부",
# "bloggerlink": "https://blog.naver.com/dragon48",
# "postdate": "20120311"
#
# },
# {
# "title": "지방도624호 인주~염치 선형개선 ,염치 염성리 <b>노인보호구역</b>... ",
# "link": "https:\/\/blog.naver.com\/vsbok?Redirect=Log&logNo=40208297617",
# "description": "또한, 지방도 624호선 아산시 염치읍 염성리 지내 <b>노인보호구역</b>으로 지정된 염치읍 소재 노인회관 앞 도로 사고 다발지역에 인도설치(300m)를 위해 도지사 시책추진보전금 3억원을 아산시에 배정해 사업을... ",
# "bloggername": "[복기왕] 충남아산갑 더불어민주당 국회의원후보",
# "bloggerlink": "https://blog.naver.com/vsbok",
# "postdate": "20140313"
#
# },
# {
# "title": "주승용, <b>노인보호구역</b> 내 속도제한 규정 신설",
# "link": "https:\/\/blog.naver.com\/manohjun?Redirect=Log&logNo=220173556851",
# "description": "반면에 <b>노인보호구역</b>의 경우 현재 전국에 626개소에 불과해 어린이보호구역의 4%에 그치고... 이 때문에 2005년에 1만9천66건에 사망자 1천700명, 부상자 1만9천832명이 발생한 노인교통사고는 매년... ",
# "bloggername": "중도일보 전만오기자의 블로그",
# "bloggerlink": "https://blog.naver.com/manohjun",
# "postdate": "20141106"
#
# },
# {
# "title": "동구, 어린이·<b>노인 보호구역</b> 개선사업 추진",
# "link": "https:\/\/blog.naver.com\/dragon48?Redirect=Log&logNo=120207197600",
# "description": "어린이와 노인의 교통안전 확보를 위해 어린이·<b>노인 보호구역</b> 개선사업을 추진한다. 8일 구에 따르면 오는 6월까지 대별동 토토어린이집과 가양동 제1 남녀경로당 인근 보호구역내 도로정비, 보호구역 표지판... ",
# "bloggername": "신아일보 대전·충남취재본부",
# "bloggerlink": "https://blog.naver.com/dragon48",
# "postdate": "20140208"
#
# },
# {
# "title": "<b>노인 보호구역</b> '실버존(Silver Zone)' 을 아시나요??",
# "link": "https:\/\/blog.naver.com\/whddn9579?Redirect=Log&logNo=222121935953",
# "description": "어린이 보호구역에 비해 <b>노인 보호구역</b>은 생소할텐데요 <b>노인 보호구역</b>은 교통약자인 노인을 교통사고 위험에서 보호하기 위해 양료원이나 경로당, 노인복지시설 등 노인들의 통행량이 많은 구역을 선정하여... ",
# "bloggername": "(주)청춘어람",
# "bloggerlink": "https://blog.naver.com/whddn9579",
# "postdate": "20201021"
#
# },
# {
# "title": "<b>노인보호구역</b>에 대해 알려드립니다.",
# "link": "https:\/\/blog.naver.com\/ondine0521?Redirect=Log&logNo=221851455478",
# "description": "<b>노인보호구역</b> 지정 방법은? 위 1의 어린이ㆍ노인 및 장애인 보호구역의 지정 및 관리의 규칙 조항에 따르면 제3조 보호구역의 지정 노인복지시설등을 설립ㆍ운영하는 자는 별지 제2호서식의 노인... ",
# "bloggername": "천사의 방문 재가노인복지센터 입니다.",
# "bloggerlink": "https://blog.naver.com/ondine0521",
# "postdate": "20200313"
#
# }
# ]
# }
# {
# "lastBuildDate": "Thu, 30 Sep 2021 13:55:42 +0900",
# "total": 44045,
# "start": 101,
# "display": 100,
# "items": [
# {
# "title": "지정하면 뭐하나…'있으나마나' <b>노인보호구역</b>[MBC뉴스데스크]",
# "link": "https:\/\/blog.naver.com\/impear?Redirect=Log&logNo=222236028094",
# "description": "앵커 어린이 보호 구역 처럼 어르신들 많이 오가는 지역에 '<b>노인 보호 구역</b>'이 있습니다. 얼마 전... &quot; <b>노인보호구역</b> 지정은 늘고 있지만 정작 노인들은 보호받지 못한 채 불안한 보행을 하고 있습니다. MBC뉴스... ",
# "bloggername": "곰바이보험하늘",
# "bloggerlink": "https://blog.naver.com/impear",
# "postdate": "20210208"
#
# },
# {
# "title": "스쿨존·횡단보도 등 <b>보호구역</b>에서 교통법규 위반 시... ",
# "link": "https:\/\/blog.naver.com\/sexysbkang?Redirect=Log&logNo=222449289071",
# "description": "② <b>노인 보호구역</b> 및 장애인 보호구역에서의 속도 위반에 대해서도 어린이 보호구역과 같은 규정이 적용됩니다. ①, ② 규정은 2021년 9월 개시되는 자동차 보험부터 적용될 예정입니다. ③ 보행자가... ",
# "bloggername": "직장생활백서",
# "bloggerlink": "https://blog.naver.com/sexysbkang",
# "postdate": "20210729"
#
# },
# {
# "title": "<b>노인 보호구역</b>에 대해 들어보셨나요?",
# "link": "https:\/\/blog.naver.com\/ems8949?Redirect=Log&logNo=221979502901",
# "description": "<b>노인 보호구역</b>이란 어린이 보호구역처럼 교통 약자인 노인들을 보호하기 위해 도입된 구역인데요. 오늘은 이 <b>노인 보호구역</b>에 대해 알아보겠습니다. <b>노인 보호구역</b> 출처 - 카카오맵 <b>노인 보호구역</b>은 교통... ",
# "bloggername": "◐팀아우토대구◑",
# "bloggerlink": "https://blog.naver.com/ems8949",
# "postdate": "20200526"
#
# },
# {
# "title": "[카드뉴스 Ep.5] <b>노인 보호구역</b> '실버존'",
# "link": "https:\/\/blog.naver.com\/life-laon?Redirect=Log&logNo=222079063152",
# "description": "어린이 보호구역처럼 노인들 역시 많은 보호와 관심이 필요합니다. 노인은 누군가의 부모이자 가족이자 우리의 미래입니다. 모두의 관심이 필요합니다. 오늘 주제인 <b>노인 보호구역</b> '실버존'에 대한 궁금증이... ",
# "bloggername": "라온에듀스포테인먼트",
# "bloggerlink": "https://blog.naver.com/life-laon",
# "postdate": "20200903"
#
# },
# {
# "title": "<b>노인보호구역</b> 미끄럼방지포장재 MMA수지 시공",
# "link": "https:\/\/blog.naver.com\/coacam?Redirect=Log&logNo=222208290890",
# "description": "(주)코아캠 <b>노인보호구역</b> 사고위험구간 미끄럼방지포장재 시공 사례 입니다. <b>노인보호구역</b> 사고위험구간 미끄럼방지 포장 전 사진입니다. <b>노인보호구역</b> 사고위험구간 미끄럼방지포장... ",
# "bloggername": "coacam",
# "bloggerlink": "https://blog.naver.com/coacam",
# "postdate": "20210125"
#
# },
# {
# "title": "실버존(<b>노인보호구역</b>)의 의미와 범칙금 - 군포 산본 주간보호",
# "link": "https:\/\/blog.naver.com\/rehabplus3?Redirect=Log&logNo=222156169318",
# "description": "<b>노인보호구역</b>은 노인복지시설이나 요양병원, 시장 등, 어르신들이 주로 다니는 길목에 교통약자인... 속도위반 <b>노인보호구역</b>은 어린이보호구역과 장애인보호구역 등과 동일한 속도 규정 제한을 받고... ",
# "bloggername": "재활플러스 주간보호센터 군포산본점",
# "bloggerlink": "https://blog.naver.com/rehabplus3",
# "postdate": "20201127"
#
# },
# {
# "title": "[이영희 도의원] 백현동 판교노인종합복지관 <b>노인보호구역</b>... ",
# "link": "https:\/\/blog.naver.com\/02yhlee?Redirect=Log&logNo=221173426271",
# "description": "&quot;안전한 분당ᆞ판교를 만들겠습니다.&quot; 어르신들의 안전을 위해서 판교노인종합복지관의 <b>노인보호구역</b>지정 관련 시설물 정비를 완료하였습니다. 이 사업은 본 의원이 확보한 경기도 예산 2천만원으로 성남시... ",
# "bloggername": "이영희의 희망정치, 분당ㆍ판교, 성남시민과 함께 !",
# "bloggerlink": "https://blog.naver.com/02yhlee",
# "postdate": "20171229"
#
# },
# {
# "title": "<b>노인 보호구역</b> 실버존, 교통 약자들을 지켜요!",
# "link": "https:\/\/blog.naver.com\/showme9292?Redirect=Log&logNo=222154991132",
# "description": "그런데 간혹가다가 어린이가 아닌 '<b>노인 보호구역</b>'이 있는 걸 보셨나요? 이른바 실버존이라 불리는 이 구역은 2008년부터 교통약자인 노인들을 보호하기 위해 만들어졌습니다. 우리나라도 점점 고령화 사회로... ",
# "bloggername": "쇼미카showmecar",
# "bloggerlink": "https://blog.naver.com/showme9292",
# "postdate": "20201126"
#
# },
# {
# "title": "중구, 올해 6천만원 투자 <b>노인보호구역</b> 개선사업 착수",
# "link": "https:\/\/blog.naver.com\/dragon48?Redirect=Log&logNo=120167510022",
# "description": "구 관계자는 “<b>노인보호구역</b>에 교통안전시설물 설치를 완료해 노인의 안전 확보가 한층 강화될 것으로 보인다”며 “안전하고 쾌적한 환경을 조성하고, 안심하고 노인시설을 이용할 수 있는... ",
# "bloggername": "신아일보 대전·충남취재본부",
# "bloggerlink": "https://blog.naver.com/dragon48",
# "postdate": "20120829"
#
# },
# {
# "title": "&lt;행정사&gt; <b>노인보호구역</b>을 지정하려면?",
# "link": "https:\/\/blog.naver.com\/cg5art?Redirect=Log&logNo=221336096079",
# "description": "교통사고 위험으로부터 어린이, 노인 등을 보호하고자 시설 주변도로를 보호구역으로 지정하는 것이다. <b>노인보호구역</b>은 노인복지시설 등을 설립·운영하는 이가 시장·군수에게 주변도로를 <b>노인 보호구역</b>으로... ",
# "bloggername": "채권채무.사건사고",
# "bloggerlink": "https://blog.naver.com/cg5art",
# "postdate": "20180810"
#
# },
# {
# "title": "[라이프패킹] <b>노인보호구역</b>에 대해 아시나요?(교통약자보호구역)",
# "link": "https:\/\/blog.naver.com\/sh3571?Redirect=Log&logNo=222194609341",
# "description": "<b>노인보호구역</b>은 2019년 기준 1,932개소로 매년 증가하고 있지만 스쿨존(16,912개소)의 11% 수준입니다. 노인인구가 어린이 인구보다 많은데, 보호구역은 1/10 수준이죠. 보호구역지정을 늘리는 것이 능사는... ",
# "bloggername": "오늘의 슝",
# "bloggerlink": "https://blog.naver.com/sh3571",
# "postdate": "20210111"
#
# },
# {
# "title": "도로 위 표지판, 세종시 <b>노인보호구역</b>, 어린이보호구역과는... ",
# "link": "https:\/\/blog.naver.com\/trump3890?Redirect=Log&logNo=222222353245",
# "description": "평소 어린이보호구역에 익숙해 있던 차에 <b>노인보호구역</b>이라는 단어를 만나게 되어 꽤나 특이하게 느껴졌습니다. 농촌의 도로에는 차가 그리 많이 다니지는 않지만, 노인분들이 도로옆 길로만 다니기에는 좁기... ",
# "bloggername": "두나기 부족장",
# "bloggerlink": "https://blog.naver.com/trump3890",
# "postdate": "20210127"
#
# },
# {
# "title": "속도를 줄이세요 <b>노인보호 구역</b> 실버존",
# "link": "https:\/\/blog.naver.com\/minitkfkd0607?Redirect=Log&logNo=222096404134",
# "description": "있는데요 노인복지시설이나 도시 공원, 생활 체육시설 등에 <b>노인 보호 구역</b>으로 지정해 둔 곳에 설치되어 있습니다. 설치되어있다고 해서 거창하게 보호구역임을 특별히 규정해 놓은 것은 아니라 우리가 흔히... ",
# "bloggername": "자동차 정비 그것이 알고싶다",
# "bloggerlink": "https://blog.naver.com/minitkfkd0607",
# "postdate": "20200922"
#
# },
# {
# "title": "어린이<b>보호구역</b>, 횡단보도에서 교통법규 위반 시 보험료 할증 10%",
# "link": "https:\/\/blog.naver.com\/inmotion99?Redirect=Log&logNo=222485796496",
# "description": "어린이 보호 구역뿐만 아니라 <b>노인 보호구역</b>과 장애인 보호구역에서의 속도위반에 대해서도 동일하게 적용됩니다. 신호가 없는 횡단보도에서도 운전자가 일시 정지하지 않는 등 보행자 보호 의무를 위반하여... ",
# "bloggername": "(주)인모션렌터카 :: 보험사고대차 전문기업",
# "bloggerlink": "https://blog.naver.com/inmotion99",
# "postdate": "20210901"
#
# },
# {
# "title": "<b>노인보호구역</b> 설치",
# "link": "https:\/\/blog.naver.com\/gasiogapivil?Redirect=Log&logNo=221983123619",
# "description": "보호구역'을 쉽게 볼 수 있는데요, 시골은 점점 학교도 사라지고 아이들의 모습을 보기도 점점 어려워지고 있습니다. 더구나, 가시오가피마을 초입에는 노인분들을 보호하기 위한 '<b>노인 보호구역</b>'이 생겨나기... ",
# "bloggername": "삼척 가시오가피마을",
# "bloggerlink": "https://blog.naver.com/gasiogapivil",
# "postdate": "20200529"
#
# },
# {
# "title": "서울시, 전통시장 주변 '<b>노인보호구역</b>'으로 지정하다.",
# "link": "https:\/\/blog.naver.com\/dusonmoa100?Redirect=Log&logNo=222323346224",
# "description": "해마다 노인 보행사고가 10건 이상 발생하는 등 대표적 사고 다발지역으로 이번 신규 보호구역에 포함됐다. 이 밖에 시는 올해 말까지 전통시장 4곳 등 총 11곳을 신규 <b>노인보호구역</b>으로 지정할 계획이다.... ",
# "bloggername": "노인 활동지원 서비스 - 두손모아",
# "bloggerlink": "https://blog.naver.com/dusonmoa100",
# "postdate": "20210430"
#
# },
# {
# "title": "[1년 전 오늘] [시민의 지팡이]<b>노인보호구역</b> ‘실버존’알고... ",
# "link": "https:\/\/blog.naver.com\/minji952966?Redirect=Log&logNo=222431002500",
# "description": "1년 전 오늘 [시민의 지팡이]<b>노인보호구역</b> ‘실버존’알고 계시나요?범칙금2배 -울산제일일보... 갈수록 노령인구가 증가하면서 교통약자인 노인들의 교통사고 또한 점점 증가하고 있어 세심한 주의가... ",
# "bloggername": "사람과 사람사이 그녀가 웃다",
# "bloggerlink": "https://blog.naver.com/minji952966",
# "postdate": "20210714"
#
# },
# {
# "title": "<b>노인보호구역</b> 속도제한,해제 표지판 제작",
# "link": "https:\/\/blog.naver.com\/ainrf?Redirect=Log&logNo=222053726535",
# "description": "어제 작업한 내용 올려볼께요~~^^ 어제 작업은 <b>노인보호구역</b> 속도제한,해제 표지판 이예요~ 사이즈는 1000*1700 어린이보호구역 표지판과 같은 형식인데요, 형광노랑 초고휘도 바탕에 HIP고휘도 오각과 원형을... ",
# "bloggername": "아인알에프(반사시트&표지판제작)",
# "bloggerlink": "https://blog.naver.com/ainrf",
# "postdate": "20200807"
#
# },
# {
# "title": "어린이·<b>노인</b>·장애인<b>보호구역</b> 통합지침(2011.11)",
# "link": "https:\/\/blog.naver.com\/hnice83?Redirect=Log&logNo=221691226192",
# "description": "2011년 1월부로 ｢어린이·노인·장애인 보호구역의 지정 및 관리에 관한 규칙｣의 제정과 더불 어 기존의 ‘어린이보호구역의 지정 및 관리에 관한 규칙’ 및 ‘<b>노인보호구역</b>의 지정 및 관리에 관 한 규칙’... ",
# "bloggername": "그림의 I CAN MAKE IT BETTER",
# "bloggerlink": "https://blog.naver.com/hnice83",
# "postdate": "20191028"
#
# },
# {
# "title": "<b>노인보호구역</b>(실버존)이란?  -안양 의왕 군포 주간보호",
# "link": "https:\/\/blog.naver.com\/rehabplus2?Redirect=Log&logNo=222128122512",
# "description": "출처: 도로교통공단 <b>노인보호구역</b>은 노인복지시설이나 요양병원, 시장 등, 어르신들이 주로 다니는... 출처: 키즈 현대 <b>노인보호구역</b>은 어린이보호구역과 장애인보호구역 등과 동일한 속도 규정 제한을 받고... ",
# "bloggername": "재활플러스 주간보호센터",
# "bloggerlink": "https://blog.naver.com/rehabplus2",
# "postdate": "20201027"
#
# },
# {
# "title": "안동시, 어르신들의 보행안전을 위한 <b>노인보호구역</b> 대폭 확대",
# "link": "https:\/\/blog.naver.com\/silveritv?Redirect=Log&logNo=221997510158",
# "description": "‘실버존’으로 불리는 <b>노인보호구역</b>은 교통약자인 어르신들을 보호하기 위해 설치된 구역으로 시속 30㎞ 이하로 서행해야 한다. 시는 평소 경로당을 이용하기 위해 이동이 잦은 어르신들이 차량과속으로... ",
# "bloggername": "100세시대를 위한      TV & NEWS",
# "bloggerlink": "https://blog.naver.com/silveritv",
# "postdate": "20200611"
#
# },
# {
# "title": "<b>노인보호구역</b> 실버존 등장",
# "link": "https:\/\/blog.naver.com\/sukwha73?Redirect=Log&logNo=60035414783",
# "description": "지난 1995년도에 도입된 어린이보호구역 스쿨존에 이어 <b>노인보호구역</b>인 실버존이 도심에 들어설 예정이다. 경찰청은 14일 노인복지시설의 주요 출입문을 기준으로 지정된 300m 내 보호구역에서는 구간별... ",
# "bloggername": "조한종의 일상과 50+스토리 (More Than A 50+ Cafe)",
# "bloggerlink": "https://blog.naver.com/sukwha73",
# "postdate": "20070315"
#
# },
# {
# "title": "<b>노인보호구역</b>에서는 법규를 지켜주세요",
# "link": "https:\/\/blog.naver.com\/no1keyman?Redirect=Log&logNo=222065633581",
# "description": "위한 보호구역인 [실버존]은 그만큼 주의를 기울이지 않게 되지요. ‘실버존’도 ‘스쿨존’ 못지않게 교통법규를 지키지 않으면 훨씬 엄격한 행정처분이 기다리고 있는데요, 오늘은 <b>노인보호구역</b>... ",
# "bloggername": "수입자동차키 넘버원",
# "bloggerlink": "https://blog.naver.com/no1keyman",
# "postdate": "20200820"
#
# },
# {
# "title": "어린이ㆍ<b>노인</b> 및 장애인 <b>보호구역</b>의 지정 및 관리에 관한... ",
# "link": "https:\/\/blog.naver.com\/stto1004?Redirect=Log&logNo=222325899678",
# "description": "어린이 보호구역의 지정을 신청할 수 있다. &lt;개정 2011. 12. 8., 2016. 5. 2.&gt; ② 노인복지시설등을 설립ㆍ운영하는 자는 별지 제2호서식의 <b>노인 보호구역</b> 지정 신청서에 따라 시장등에게 노인복지시설등의... ",
# "bloggername": "녹색건축인증연구소",
# "bloggerlink": "https://blog.naver.com/stto1004",
# "postdate": "20210428"
#
# },
# {
# "title": "<b>노인보호구역</b>",
# "link": "https:\/\/blog.naver.com\/axon1400?Redirect=Log&logNo=222043164063",
# "description": "교통약자 보호구역 범칙금 출처 : 도로교통공단 블로그 교통약자 보호구역 위반 면허벌점 출처 : 도로교통공단 블로그 오늘은 <b>노인보호구역</b>에 대해서 살펴봤는데요, 노인 뿐만아니라 어린이, 장애인, 임산부... ",
# "bloggername": "에이다스원 공식블로그",
# "bloggerlink": "https://blog.naver.com/axon1400",
# "postdate": "20200806"
#
# },
# {
# "title": "<b>노인 보호 구역</b> 실버존을 지켜주세요!",
# "link": "https:\/\/blog.naver.com\/ahxh7581?Redirect=Log&logNo=221993170696",
# "description": "일반 보행자분들의 사고도 잦은 편이지만 노인분들에게는 더욱 더 치명타일 수 있어요. 고령자분들은 뼈도 약하고 회복도 힘들기 때문에 꼭 보호 구역에서는 안전을 지켜주세요! <b>노인 보호 구역</b>에 대해서... ",
# "bloggername": "케빠의 일상",
# "bloggerlink": "https://blog.naver.com/ahxh7581",
# "postdate": "20200608"
#
# },
# {
# "title": "<b>노인</b> 장애인<b>보호구역</b> 교통법규 위반시 가중처벌",
# "link": "https:\/\/blog.naver.com\/tkfkd041111?Redirect=Log&logNo=220243107597",
# ...
# "bloggername": "정보마당",
# "bloggerlink": "https://blog.naver.com/pyh2910",
# "postdate": "20210510"
#
# },
# {
# "title": "인천 남동구<b>노인</b>복지관, 어린이 교통안전 캠페인 진행",
# "link": "https:\/\/blog.naver.com\/ksg2028?Redirect=Log&logNo=221691382067",
# "description": "인천남동구<b>노인</b>복지관(관장 김용배)이 초등학교 인근 어린이 <b>보호구역</b> 내 아동 교통사고 예방을 위해 KB손해보험 다이렉트와 연계해 ‘옐로카드로 아껴주세요’ 캠페인을 진행했다. 이날 캠페인은... ",
# "bloggername": "365타임즈",
# "bloggerlink": "https://blog.naver.com/ksg2028",
# "postdate": "20191028"
#
# },
# {
# "title": "줄일수록 생명이 보인다! '안전속도 5030'",
# "link": "https:\/\/blog.naver.com\/mopaspr?Redirect=Log&logNo=222346659144",
# "description": "이면 도로에는 어린이보호구역, <b>노인 보호구역</b>, 주택가 주변이 해당됩니다. 안전속도 5030 위반 시 과태료 및 범칙금은 어떻게 되나요? (출처=삼성교통문화안전연구소) 범칙금은 최고 12만 원, 과태료는... ",
# "bloggername": "대한민국 행정안전부",
# "bloggerlink": "https://blog.naver.com/mopaspr",
# "postdate": "20210511"
#
# },
# {
# "title": "<b>노인</b>의료복지시설의 개발제한<b>구역</b>내 설치",
# "link": "https:\/\/blog.naver.com\/koreahuman1?Redirect=Log&logNo=90193653530",
# "description": "5) <b>노인보호</b>기관, 6) 제23조의2 제2호의 <b>노인</b>일자리지원기관 2. <b>노인</b>주거복지시설 ( <b>노인</b>복지법 제32조 )... ○ 개발제한<b>구역</b>내 <b>노인</b>의료복지시설 관련규정 1. 건축법 시행령 별표 1 ( 용도별 건축물의 종류 ) 제1호... ",
# "bloggername": "부동산과 세상 이야기 by OZ",
# "bloggerlink": "https://blog.naver.com/koreahuman1",
# "postdate": "20140408"
#
# },
# {
# "title": "인천시,내년부터 <b>노인</b>복지시설 주변도로 각종 안전시설물 설치",
# "link": "https:\/\/blog.naver.com\/odk1956?Redirect=Log&logNo=100042824316",
# "description": "노인복지시설 주변도로에 <b>노인보호구역</b>(Silver Zone)이 지정되는 교통안전개선사업이 추진된다.... 교통약자인 노인의 교통사고를 줄이는데 큰 도움을 주는 것은 물론 어린이보호구역과 함께 교통약자 보호에... ",
# "bloggername": "Next Generation Aircraft",
# "bloggerlink": "https://blog.naver.com/odk1956",
# "postdate": "20071009"
#
# },
# {
# "title": "내년 서울시에 장애인<b>보호구역</b> 지정된다",
# "link": "https:\/\/blog.naver.com\/kst3175?Redirect=Log&logNo=150107468866",
# "description": "이에 따라 교통약자 보호구역은 노인·어린이·장애인 복지시설의 장이 자치구나 서울시에 해당... 장애인보호구역 지정 사업을 본격 시행할 계획이다. 한편, 시는 오는 하반기까지 <b>노인보호구역</b> 13개소... ",
# "bloggername": "지구촌다문화 뉴스",
# "bloggerlink": "https://blog.naver.com/kst3175",
# "postdate": "20110426"
#
# },
# {
# "title": "양산 <b>노인</b>복지센터  울타리 대문, 디자인휀스 담장 출입문설치",
# "link": "https:\/\/blog.naver.com\/kk3677355?Redirect=Log&logNo=222464174634",
# "description": "경남 양산 <b>노인</b>복지센터에 디자인휀스(아트휀스)로 울타리와 대문을 시공하였습니다. 전원주택 주택 빌라 아파트 유치원 공원 농장 텃밭 택지 공장 주차장 어린이<b>보호구역</b> 애견카페 애견운동장... ",
# "bloggername": "금강휀스",
# "bloggerlink": "https://blog.naver.com/kk3677355",
# "postdate": "20210810"
#
# },
# {
# "title": "<b>노인보호</b>} 실버존에선 서행해 주세요![수원방문요양]",
# "link": "https:\/\/blog.naver.com\/ariacareseodun?Redirect=Log&logNo=221717649824",
# "description": "도로교통법 제12조의 2 (노인 및 장애인 보호구역의 지정 및 관리) ① 시장등은 교통사고의... 구간을 <b>노인 보호구역</b>으로, 제4호에 따른 시설의 주변도로 가운데 일정 구간을 장애인 보호구역으로 각각 지정하여... ",
# "bloggername": "아리아케어 방문요양 수원권선센터",
# "bloggerlink": "https://blog.naver.com/ariacareseodun",
# "postdate": "20191125"
#
# },
# {
# "title": "[건축사사무소 서로가]자인<b>노인</b>복지관-당선작",
# "link": "https:\/\/blog.naver.com\/seoroga1?Redirect=Log&logNo=222492573674",
# "description": "대지위치 : 경산시 자인면 동부리 396번지 일원 지역지구 : 자연녹지지역, 준보전산지, 농업<b>보호구역</b>... 21% (100% 이하) 구 조 : 철근콘크리트 구조 층 수 : 지하 1층, 지상 3층 ■ 대지주변현황 자인<b>노인</b>복지관은... ",
# "bloggername": "Seoroga Architects",
# "bloggerlink": "https://blog.naver.com/seoroga1",
# "postdate": "20210902"
#
# },
# {
# "title": "2020년 &quot;어린이<b>보호구역</b>, 더안전하게~! 이렇게 달라집니다... ",
# "link": "https:\/\/blog.naver.com\/lyd0916?Redirect=Log&logNo=221765040622",
# "description": "버스정류장, 4횡단보도에서--&gt;어린이<b>보호구역</b> 추가 노상주차장 폐지 등에 따른 주차난 해소를 위해서는 공영주차장 공급을 확대할 예정입니다 3. 어린이를 우선하는 교통 문화 정착 <b>노인</b> 일자리 사업을 활용한... ",
# "bloggername": "이채명 경기도 안양시의회 의원",
# "bloggerlink": "https://blog.naver.com/lyd0916",
# "postdate": "20200109"
#
# },
# {
# "title": "Part 5 상수원관리지역 - 제23장 상수원<b>보호구역</b>",
# "link": "https://blog.daum.net/moduuri1004/11832001",
# "description": "제23장 상수원<b>보호구역</b> 1 상수원<b>보호구역</b> 지정 1-1 관련법령 1) 수도법 ; 환경부장관은 상수원의 확보와 수질 보전을 위하여 필요하다고 인정되는 지역을 &quot;상수원 <b>보호구역</b>&quot;으로 지정 변경할 수 있다. 2) 상수원... ",
# "bloggername": "DaSarang(다사랑-부동산정보)",
# "bloggerlink": "https://blog.daum.net/moduuri1004",
# "postdate": "20201001"
#
# },
# {
# "title": "<b>노인</b>주간<b>보호</b>센터인테리어 편안함의 중요성",
# "link": "https:\/\/blog.naver.com\/santa1618?Redirect=Log&logNo=222158477002",
# "description": "이렇게 수요가 많아진 시점이라면 센터를 운영하는 입장에서도 <b>노인</b>주간<b>보호</b>센터인테리어에 더 많은... 각 <b>구역</b>의 목적과 컨셉에 맞게끔, 그리고 의뢰인이 생각하는 바에 맞게끔 차근차근 컨셉을 채워 나가게... ",
# "bloggername": "채움과비움 (인테리어디자인)",
# "bloggerlink": "https://blog.naver.com/santa1618",
# "postdate": "20201130"
#
# },
# {
# "title": "초보운전일기 / 난코스로 다녀온 동두천 수제버거 맛집",
# "link": "https:\/\/blog.naver.com\/ehloveu?Redirect=Log&logNo=222422702304",
# "description": "보이는 <b>노인보호구역</b> 지시표시까지! 왕복2차로인 좁은 길이라 혹시 노인 분들이 튀어나오지 않을까... 주차구역 어쩐지 작고 귀엽게 나온 우리 돼지 모하비  기름을 10만원 어치나 먹는 돼지ㅣㅣㅣㅣㅣ... ",
# "bloggername": "- be simple ☺︎ ♥️",
# "bloggerlink": "https://blog.naver.com/ehloveu",
# "postdate": "20210706"
#
# },
# {
# "title": "나만 몰랐나? 9월부터 시행되는 교통법규",
# "link": "https:\/\/blog.naver.com\/clftns0305?Redirect=Log&logNo=222520353159",
# "description": "이 규정은 오는 9월 개시되는 자동차 보험부터 적용되며 <b>노인 보호구역</b>과 장애인 보호구역에서의 속도위반에 대해서도 동일하게 적용됩니다. 횡단보도에서 운전자가 일시 정지하지 않는 등 보행자 보호... ",
# "bloggername": "국민메디칼컨설팅(kmc의료컨설팅)이영우",
# "bloggerlink": "https://blog.naver.com/clftns0305",
# "postdate": "20210929"
#
# },
# {
# "title": "위례/성남/송파/강남 최대규모,최고시설 <b>노인</b>주간<b>보호</b>... ",
# "link": "https:\/\/blog.naver.com\/happycare7812?Redirect=Log&logNo=222167656325",
# "description": "검사는 3개의 <b>구역</b>으로 나누어 어르신별 검사 준비를 하며, 검사키트를 분류하여 어르신들의 상황을... 요양<b>보호</b> #<b>노인</b>유치원 #<b>노인</b>대학 #치매센터 #치매<b>노인</b> #치매어르신 #<b>노인</b>돌봄 어르신이 더 행복한 프리미엄... ",
# "bloggername": "어르신의 건강한 노후, 주야간보호 제대로 운영하기!",
# "bloggerlink": "https://blog.naver.com/happycare7812",
# "postdate": "20201209"
#
# },
# {
# "title": "어린이 <b>보호구역</b> 통학버스 신고대상 교통안전 강화대책... ",
# "link": "https:\/\/blog.naver.com\/sk4948?Redirect=Log&logNo=221763275982",
# "description": "어린이 <b>보호구역</b>을 추가 셋째 어린이 우선교통안전문화 정착 <b>노인</b>일자리사업을 활용한 어린이 등.하교 교통안전 계도활동을 2022년까지 전국 초등학교로 확대할 계획 내비게이션 안내음성과 표출화면을... ",
# "bloggername": "나라를 갖다",
# "bloggerlink": "https://blog.naver.com/sk4948",
# "postdate": "20200107"
#
# },
# {
# "title": "어린이,<b>노인보호구역</b> 개선 - 주원통신(주) 어린이보호구역... ",
# "link": "https:\/\/blog.naver.com\/juwontelecom?Redirect=Log&logNo=220713937718",
# "description": "",
# "bloggername": "주원통신(주) CCTV, 통신공사 전문업체",
# "bloggerlink": "https://blog.naver.com/juwontelecom",
# "postdate": "20160519"
#
# },
# {
# "title": "자동차도로정보 생활도로<b>구역</b>? 어린이<b>보호구역</b>이 아닌 어떤곳?",
# "link": "https:\/\/blog.naver.com\/jwh0572?Redirect=Log&logNo=221582580932",
# "description": "<b>노인보호구역</b>도 아니고 어린이보호구역도 아닌 생활도로구역! 생활도로구역은 보행자들이 주로 많은 주택가지역 상가가 많은 지역을 생활권도로를 보행자를 우선구역으로 지정하여 차량속도를 30km/h이하도... ",
# "bloggername": "KB 렌트카",
# "bloggerlink": "https://blog.naver.com/jwh0572",
# "postdate": "20190710"
#
# },
# {
# "title": "#울산<b>노인</b>주간<b>보호</b>센터 #남구주간<b>보호</b>센터 #치매전담실... ",
# "link": "https:\/\/blog.naver.com\/dwnl2012?Redirect=Log&logNo=221912838002",
# "description": "통장만들기 #사회적응 #노치원 #<b>노인</b>복지관#만들기 #미술프로그램 #은행놀이 #도우누리<b>노인</b>주간<b>보호</b>센터 #허달호 #미술도안 #색칠놀이도안 #코로나19 #코로나안전<b>구역</b> #청정인증마크 #청정인증센터",
# "bloggername": "도우누리 노인주간보호센터",
# "bloggerlink": "https://blog.naver.com/dwnl2012",
# "postdate": "20200417"
#
# },
# {
# "title": "[부동산] 부천 소사역 주변, 재개발 및 대곡소사선 23년 개통",
# "link": "https:\/\/blog.naver.com\/hxn1?Redirect=Log&logNo=222467313729",
# "description": "그리고 네이버 거리뷰로만 봐도 어르신들 요양 병원들 같은 게 많고 <b>노인보호 구역</b>이 보이기도... (참고로 소사역 위쪽에 있는 재개발 구역 중 소사1-1구역의 경우에는 재개발 반대하는 주민들에... ",
# "bloggername": "Shoner Anthology",
# "bloggerlink": "https://blog.naver.com/hxn1",
# "postdate": "20210812"
#
# },
# {
# "title": "부산방역업체, 코로나 긴급소독으로 안심<b>구역</b>제공.",
# "link": "https:\/\/blog.naver.com\/bmxrider?Redirect=Log&logNo=222160478716",
# "description": "사람이 많은 곳이나 유동인구가 꾸준한 곳은 부산방역업체를 통해서 청정<b>구역</b>을 만들수가 있답니다.... 취약계층이 있는곳이나 <b>노인</b>/아동 <b>보호</b> 시설같은 경우는 꾸준히 방역 봉사활동을 통해서 도움을 드리고... ",
# "bloggername": "(주)조인호프",
# "bloggerlink": "https://blog.naver.com/bmxrider",
# "postdate": "20201202"
#
# },
# {
# "title": "주간<b>보호</b>센타맞춤형프로그램 인지건강놀이 <b>노인</b>건강체조",
# "link": "https:\/\/blog.naver.com\/smk1345?Redirect=Log&logNo=222426792358",
# "description": "기분좋은힐링연구원 청춘디자이너손미경강사입니다 칠월 둘째 주 목요일 강의가 없는날~ 햇살탄생봉사단(회장김세영) 단장으로 회원님들과 참편한<b>노인</b>주간<b>보호</b>센터를 찾았어요. 나눔은 곧 섬 김이라고... ",
# "bloggername": "기분좋은힐링연구원 웃음.웰니스.SNS.강사양성",
# "bloggerlink": "https://blog.naver.com/smk1345",
# "postdate": "20210710"
#
# },
# {
# "title": "화성시, ‘어린이<b>보호구역</b>’ 5월까지 총 99개소 현장점검 실시",
# "link": "https://blog.daum.net/kbr2hys/8480551",
# "description": "화성시, ‘어린이<b>보호구역</b>’ 5월까지 총 99개소 현장점검 실시 댓글 0 사회 2021. 2. 23. 위험요인 및... 23 오산<b>노인</b>종합복지관-오산시 지역자율방재단, <b>노인</b>사회활동 지원사업 업무협약 체결 (0) 2021.02.23... ",
# "bloggername": "화성뉴스 블로그",
# "bloggerlink": "https://blog.daum.net/kbr2hys",
# "postdate": "20210223"
#
# },
# {
# "title": "<b>노인</b>학대 발생에 대한 데이터 구축 및 연구가 필요해",
# "link": "https:\/\/blog.naver.com\/polinlove2?Redirect=Log&logNo=222107228524",
# "description": "하지만 행정안전부의 2021년도 <b>보호구역</b> 개선 예산은 어린이 1,983억 원, <b>노인</b> 60억 원 편성되어 어린이 대비 <b>노인</b> 관련 예산은 3%에 불과해 예산 편중이 심각해 보입니다. *UN에서는 매년 6월 15일을 ｢세계... ",
# "bloggername": "대한민국 경찰청",
# "bloggerlink": "https://blog.naver.com/polinlove2",
# "postdate": "20201005"
#
# },
# {
# "title": "충북경창, 내 <b>노인</b>배려 교통환경 개선계획 추진",
# "link": "https:\/\/blog.naver.com\/pcnorkr?Redirect=Log&logNo=222311994712",
# "description": "교통환경 개선은 ▲현장의견 청취·개선&lt;현장의견 제기 개별시설 대상&gt; ▲노인배려구간 운영&lt;단순시설 개선 가능 위험구간 대상&gt; ▲ <b>노인보호구역</b> 지정·개선&lt;예산수반 설계, 개선 필요구간 대상&gt; 순으로... ",
# "bloggername": "경찰기독신문",
# "bloggerlink": "https://blog.naver.com/pcnorkr",
# "postdate": "20210416"
#
# },
# {
# "title": "교통법규위반 운전자들이 잘 모르는 다섯 가지 과태료",
# "link": "https:\/\/blog.naver.com\/ruddnr1978?Redirect=Log&logNo=222347951723",
# "description": "<b>노인 보호구역</b> 신호 및 주정차 위반 고령자의 통행이 많은 양로원과 경로당, 노인복지시설 등은 <b>노인 보호구역</b>으로 지정되어 있습니다. 하지만 어린이 보호구역과 다르게 <b>노인 보호구역</b>은 많은 운전자에게... ",
# "bloggername": "수원중고차 원더풀카",
# "bloggerlink": "https://blog.naver.com/ruddnr1978",
# "postdate": "20210512"
#
# },
# {
# "title": "“어린이 <b>보호구역</b> 서행하세요”",
# "link": "https:\/\/blog.naver.com\/jnjaryosil?Redirect=Log&logNo=70104626087",
# "description": "“어린이 <b>보호구역</b> 서행하세요” 세계일보 사회 10면3단 2011.03.09 (수) 오후 7:13 속도로 고령사회에 진입하면서 <b>노인</b>복지에 대한 정부 대책마련이 시급하다는 지적이 일고 있다 9일 서울 종로3가에서 한... ",
# "bloggername": "종로사랑 문화사랑^^",
# "bloggerlink": "https://blog.naver.com/jnjaryosil",
# "postdate": "20110310"
#
# },
# {
# "title": "2019년 경기도 어린이<b>보호구역</b>개선사업 평택 선정",
# "link": "http://www.vision21.kr/news/article.html?no=65205",
# "description": "‘어린이·<b>노인</b>·장애인 <b>보호구역</b> 통합지침’에 따른 교통안전표지, 보행자방호울타리, 차선 도색 등 교통안전시설물 설치가 지원된다. ['br /'] ['br /'] 평소 어린이들의 안전에 남다른 관심을 가져왔던, 오명근... ",
# "bloggername": "비전21뉴스",
# "bloggerlink": "http://www.vision21.kr/",
# "postdate": "20190517"
#
# },
# {
# "title": "<b>노인</b>의료복지시설 감염병예방법에 따른 격리소 또는 요양소가... ",
# "link": "https:\/\/blog.naver.com\/hongik2523?Redirect=Log&logNo=222457898783",
# "description": "법제처는 <b>노인</b>의료복지시설이 &quot;교육환경 <b>보호</b>에 관한 법률&quot;(이하 &quot;교육환경법&quot;)에 따른 절대<b>보호구역</b>에 설치가 금지되는지에 대하여 &quot;<b>노인보호</b>법&quot; 제34조에 따른 <b>노인</b>의료복지시설은 교육환경법 제9조... ",
# "bloggername": "홍익프랜차이즈행정구제공인중개자문센터",
# "bloggerlink": "https://blog.naver.com/hongik2523",
# "postdate": "20210805"
#
# },
# {
# "title": "성남시 수정로 일대 상권활성화 <b>구역</b>으로 유치 성공 / <b>노인</b>요양... ",
# "link": "https:\/\/blog.naver.com\/chonchu?Redirect=Log&logNo=110109735171",
# "description": "활성화 <b>구역</b>으로 최종 선정됐다. (전건주기자) 성남시, <b>노인</b>요양시설 대민 서비스 질 높인다 시설... 이들 <b>노인</b>요양시설의 보험가입상황, 자동화재 속보설비 등 시설보완 대상 여부, 시설운영실태, 어르신<b>보호</b>... ",
# "bloggername": "京都日報 전건주 기자 (기사 보기)",
# "bloggerlink": "https://blog.naver.com/chonchu",
# "postdate": "20110526"
#
# },
# {
# "title": "[물금 주간 <b>노인 보호</b>센터/요양시설/시공현장/블로그계약현장]",
# "link": "https:\/\/blog.naver.com\/jangjea17?Redirect=Log&logNo=221443017638",
# "description": "주간<b>노인보호</b>센터 사장님 감사합니다. #병원LG시스템에어컨 #아파트LG시스템에어컨... 거제1<b>구역</b>자이 #명지사랑으로부영 #동래꿈에그린 #명륜자이 #구남역동원로얄듀크 #해운대더샵센텀그린 #정관행복주택... ",
# "bloggername": "[LG전자 시스템A/C] CPS공조B2B 우수파트너점",
# "bloggerlink": "https://blog.naver.com/jangjea17",
# "postdate": "20190115"
#
# },
# {
# "title": "스피드 디스플레이 (과속경보시스템)",
# "link": "https:\/\/blog.naver.com\/heemory?Redirect=Log&logNo=222407358163",
# "description": "과속경보 (스피드 디스플레이) 시스템은 접근하는 차량의 과속 여부를 실시간으로 표시하여, 운전자로 하여금 감속을 유도하는 시스템으로 어린이보호구역 , <b>노인보호구역</b> , 대규모 창고나 물류... ",
# "bloggername": "바람을 꿈꾸다...",
# "bloggerlink": "https://blog.naver.com/heemory",
# "postdate": "20210623"
#
# },
# {
# "title": "국민권익위원회, 시골길 교통사고 예방·소음 해결",
# "link": "https:\/\/blog.naver.com\/loveacrc?Redirect=Log&logNo=222145435284",
# "description": "오토바이와 경주용차 소음·교통사고 예방을 위해 대책을 마련해 달라는 주민 요구 해결 화천경찰서는 어린이보호구역, <b>노인보호구역</b> 등 30㎞ 이하로 지정된 속도제한구역이 아니라며 설치가 어렵다는... ",
# "bloggername": "국민권익위원회",
# "bloggerlink": "https://blog.naver.com/loveacrc",
# "postdate": "20201116"
#
# },
# {
# "title": "어린이<b>보호구역</b> 교통안전성 향상을 위한 교통안전시설 연구... ",
# "link": "https:\/\/blog.naver.com\/itszone?Redirect=Log&logNo=221252943294",
# "description": "이러한 어린이 보행 사고는 어린이<b>보호구역</b>내에서의 차량 통행속도와 밀접한 관련이 있는데, 국민안전처의 어린이･<b>노인</b> 및 장애인<b>보호구역</b> 통합지침에서는 주간선 도로 및... ",
# "bloggername": "만주뚜벅이",
# "bloggerlink": "https://blog.naver.com/itszone",
# "postdate": "20180414"
#
# },
# {
# "title": "횡단보도 안전사고 신기술로 예방한다 보행신호 음성안내... ",
# "link": "https:\/\/blog.naver.com\/copannews?Redirect=Log&logNo=222448561658",
# "description": "스쿨존이나 <b>노인보호구역</b> 등에서 보행자에게도 직접 경고 방송을 해 위험 상황을 인식할 수 있도록 할 수 있다. 횡단보도의 음성안내는 보행자는 한 번 듣고 지나가지만, 주변의 거주민은 하루 종일 듣게 되어... ",
# "bloggername": "ASIA문화경제신문",
# "bloggerlink": "https://blog.naver.com/copannews",
# "postdate": "20210729"
#
# },
# {
# "title": "어린이 <b>보호구역</b>",
# "link": "https:\/\/blog.naver.com\/dlackgus?Redirect=Log&logNo=221429411398",
# "description": "사고가 많은 구간에는 단속을 더 강화해 <b>노인</b> 일자리를 확대하는 효과를 가져 올 수도 있습니다. 이제는 어린이 <b>보호구역</b>에서 사고를 줄이기 위해 어떠한 방법을 쓰고 있는지를 알아보겠습니다. 스웨덴의... ",
# "bloggername": "정치•사회 평론 칼럼니스트 임차두리",
# "bloggerlink": "https://blog.naver.com/dlackgus",
# "postdate": "20181228"
#
# },
# {
# "title": "◆용두3.4<b>구역</b> 연립 매매◆",
# "link": "https:\/\/blog.naver.com\/qoop8989?Redirect=Log&logNo=222485080833",
# "description": "중요하겠죠~연로하신 <b>노인</b>분들의 새마을정신으로 참여하시면 ~우리도 한번 잘 살아보세~~기대가... 재정비촉진지구,절대<b>보호구역</b>,상대<b>보호구역</b> 준공년도/ 전체세대수 2002년/ 공동주택 공시가격 1억400... ",
# "bloggername": "qoop8989님의블로그",
# "bloggerlink": "https://blog.naver.com/qoop8989",
# "postdate": "20210827"
#
# },
# {
# "title": "보행자가 더 안전하도록, 궁동종합사회복지관과... ",
# "link": "https:\/\/blog.naver.com\/digital9ro?Redirect=Log&logNo=222168853928",
# "description": "대로에서 한길 안쪽으로 들어오면 붉은색으로 칠해진 도로와 <b>노인보호구역</b>, 시속 30km 구역 표시를 볼 수 있습니다. 특히 더 주의해야 하는 교차로는 노란색 원형 표시를 해 놓았습니다. 대로에서 한길 안쪽으로... ",
# "bloggername": "구로구청 공식블로그",
# "bloggerlink": "https://blog.naver.com/digital9ro",
# "postdate": "20201210"
#
# },
# {
# "title": "김해 <b>노인</b>주간<b>보호</b>센터 어르신들의 쉼터 온유한복지센터",
# "link": "https:\/\/blog.naver.com\/picogs?Redirect=Log&logNo=222132075717",
# "description": "김해 <b>노인</b>주간<b>보호</b>센터의 가장 큰 장점이에요. 소소하게 온유한복지관 코인으로 ^^ 게임도 하시고 말이지요 : ) 이<b>구역</b> 아귀는 누구일지 궁금해 지네요. 어르신들의 하루를 알차게 만들어드리는 운동... ",
# "bloggername": "취미가 리뷰",
# "bloggerlink": "https://blog.naver.com/picogs",
# "postdate": "20201101"
#
# },
# {
# "title": "성북구 <b>노인</b> 보행자 교통사고 다발지역 유의! 입원치료는... ",
# "link": "https:\/\/blog.naver.com\/broadhani?Redirect=Log&logNo=222413377671",
# "description": "성신여대입구역 근처 등 주로 노인들이 많이 통행하는 곳이었는데요. 이와 같이 노인보행사고가... 노인보행사고를 예방하기 위해 운전자분들께서는 <b>노인보호구역</b>에서 속도, 주정차 등 규정을 반드시... ",
# "bloggername": "365일/ 평일 매일 야간 진료하는 큰길한의원",
# "bloggerlink": "https://blog.naver.com/broadhani",
# "postdate": "20210628"
#
# },
# {
# "title": "로보스 주립자연<b>보호구역</b>(Point Lobos State Natural Reserve)",
# "link": "https:\/\/blog.naver.com\/myannelim?Redirect=Log&logNo=221650776477",
# "description": "주립자연<b>보호구역</b>(Point Lobos State Natural Reserve)이다. 여긴 지금껏 여러번 갔는데 갈 때마다 날씨는... 입구에 오니 자원봉사하시는 <b>노인</b>분들이 나와서 사람들을 안내하고 계신다. 너무나 친절하시다. 다람쥐가... ",
# "bloggername": "미국에서 가족과 즐기는 법",
# "bloggerlink": "https://blog.naver.com/myannelim",
# "postdate": "20190917"
#
# },
# {
# "title": "어린이 <b>보호구역</b>",
# "link": "https:\/\/blog.naver.com\/symg27?Redirect=Log&logNo=221379897087",
# "description": "이면도로를 일반통행로로 지정, 운영하는 것 관련용어 학교환경위생 정화<b>구역</b> 관련법규 「도로교통법」 제12조(어린이 <b>보호구역</b>의 지정 및 관리) 「어린이·<b>노인</b> 및 장애인 <b>보호구역</b>의 지정 및 관리에 관한... ",
# "bloggername": "큰부자 부동산",
# "bloggerlink": "https://blog.naver.com/symg27",
# "postdate": "20181018"
#
# }
# ]
# }

# %%
#부정어사전 추가
n = pd.read_csv('../data/크롤링/사전/neg_pol_word.csv',sep='\n')
nag = []
for i in n['0']:
    nag.append(i)

# %%
#부정어사전 추가
p = pd.read_csv('../data/크롤링/사전/neg_pol_word.csv',sep='\n')
pos = []
for i in p['0']:
    pos.append(i)

#불용리스트 만들기
stopwords = ['실버존','스쿨존','보호','구역','노인','어린이','등','교통','곳','지정','안전','사업','일','시설','위해','및','년','장애인','위','경로당','설치','주변',
            '교통사고','보행자','보행','환경','도로','시','유치원','이번','중','조례','복지','차량','올해','애인','개','개소','억','관내',
            '의원','전국','발생','추가','이','물','월','원','확대','내','현재','광주','리','지역','최근','대전','것','지난해','초등학교','관','인구',
            '존','완료','대한','투입','공단','기자','대해','지난','마을','로','수','총','시행','조성','추진','공원','경찰정','경찰','충남',
            '회','또','군','신규','계획','안','광주시','시스템','생활','활동','중구','어르신','윤','실버','서울시회관','경우','통행','기준','어린이집',
            '진행','구','경기도','만','윤','복지관','아산시','대책','기관','인근','행사','점검','부과','지원','대폭','도시','억원','횡단보도','전통','도',
            '서울시','시장','회관','운영','가운데','민주당','공사','제조','요양원','개정','이상','규칙','고','지자체','앞','억만원','운전','출처',
            '학교','일자리','만원','도로교통법','미끄럼','주간','주민','금','일반','표시','센터']

#불용어사전 추가
for i in stopwords:
    pos.append(i)

# %%
#분리
def get_tags(text, ntags=50):
    spliter = Okt()
    nouns = spliter.nouns(text)
    count = Counter(nouns)
    words = dict(count.most_common(ntags))
    
    #불용어 사전안에 있으면 삭제
    for i in pos:
        if i in words:
            del words[i]
    return words

# %%
rtags = get_tags(rtext, ntags=200)
# print(rtags)

Wordcloud(rtags, '노인보호구역','../data/WordCloud/mask/mask1.jpeg')
