# %%
import pandas as pd

# %%
df = pd.read_csv('../data/보행고령자 사고다발/보행고령자 사고다발지역.csv',)

# %%
df.head()
# Out:
#    사고다발지FID  사고다발지ID       법정동코드      지점코드      시도시군구명  \
# 0    145935  2013098  1111018000  11110001  서울특별시 종로구1
# 1    144334  2013098  1111016700  11110002  서울특별시 종로구2
# 2    151689  2013098  1111015400  11110003  서울특별시 종로구3
# 3    151688  2013098  1111017400  11110004  서울특별시 종로구4
# 4    144645  2013098  1114016000  11140001   서울특별시 중구1
#
#                               지점명  발생건수  사상자수  사망자수  중상자수  경상자수  부상신고자수  \
# 0  서울특별시 종로구 교북동(독립문_의주로_진출_1 부근)     3     3     0     3     0       0
# 1         서울특별시 종로구 충신동(이화사거리 부근)     5     5     0     5     0       0
# 2          서울특별시 종로구 장사동(종묘공원 부근)     6     6     0     4     1       1
# 3   서울특별시 종로구 창신동(동묘앞역_다산로_진입 부근)     6     6     1     5     0       0
# 4        서울특별시 중구 인현동1가(대림상가앞 부근)     3     3     0     1     2       0
#
#            경도         위도                                            다발지역폴리곤
# 0  126.960630  37.571937  {"type":"Polygon","coordinates":[[[126.9622309...
# ...

# %%
df_1 = df[['시도시군구명','지점명','발생건수','사상자수','경도','위도']]

# %%
df_1
# Out:
#              시도시군구명                             지점명  발생건수  사상자수          경도  \
# 0        서울특별시 종로구1  서울특별시 종로구 교북동(독립문_의주로_진출_1 부근)     3     3  126.960630
# 1        서울특별시 종로구2         서울특별시 종로구 충신동(이화사거리 부근)     5     5  127.004402
# 2        서울특별시 종로구3          서울특별시 종로구 장사동(종묘공원 부근)     6     6  126.993647
# 3        서울특별시 종로구4   서울특별시 종로구 창신동(동묘앞역_다산로_진입 부근)     6     6  127.016856
# 4         서울특별시 중구1        서울특별시 중구 인현동1가(대림상가앞 부근)     3     3  126.995341
# ...             ...                             ...   ...   ...         ...
# 4982   제주특별자치도 제주시2     제주특별자치도 제주시 노형동(제주노형우체국 부근)     3     3  126.477851
# 4983   제주특별자치도 제주시3     제주특별자치도 제주시 이도일동(KAL사거리 부근)     3     3  126.526879
# 4984  제주특별자치도 서귀포시1  제주특별자치도 서귀포시 서귀동(천지동사무소사거리 부근)     3     4  126.562089
# 4985  제주특별자치도 서귀포시2     제주특별자치도 서귀포시 성산읍(고성리교차로 부근)     2     2  126.915746
# 4986  제주특별자치도 서귀포시3  제주특별자치도 서귀포시 동홍동(천태종서귀포해운사 부근)     2     2  126.568175
#
#              위도
# 0     37.571937
# 1     37.576104
# ...

# %%
acc = []
for i in range(len(df_1)):
    if '서울' in df_1.loc[i,'시도시군구명']:
#         print(df_1.loc[i,'시도시군구명'])
        acc.append(df_1.loc[i])
acc
# Out:
# [시도시군구명                        서울특별시 종로구1
#  지점명       서울특별시 종로구 교북동(독립문_의주로_진출_1 부근)
#  발생건수                                   3
#  사상자수                                   3
#  경도                             126.96063
#  위도                             37.571937
#  Name: 0, dtype: object,
#  시도시군구명                 서울특별시 종로구2
#  지점명       서울특별시 종로구 충신동(이화사거리 부근)
#  발생건수                            5
#  사상자수                            5
#  경도                     127.004402
#  위도                      37.576104
#  Name: 1, dtype: object,
#  시도시군구명                서울특별시 종로구3
#  지점명       서울특별시 종로구 장사동(종묘공원 부근)
#  발생건수                           6
#  사상자수                           6
#  경도                    126.993647
#  위도                     37.570706
#  Name: 2, dtype: object,
#  시도시군구명                       서울특별시 종로구4
#  지점명       서울특별시 종로구 창신동(동묘앞역_다산로_진입 부근)
#  발생건수                                  6
#  사상자수                                  6
#  경도                           127.016856
# ...

# %%
df_acc = pd.DataFrame(acc)

# %%
df_acc
# Out:
#           시도시군구명                             지점명  발생건수  사상자수          경도  \
# 0     서울특별시 종로구1  서울특별시 종로구 교북동(독립문_의주로_진출_1 부근)     3     3  126.960630
# 1     서울특별시 종로구2         서울특별시 종로구 충신동(이화사거리 부근)     5     5  127.004402
# 2     서울특별시 종로구3          서울특별시 종로구 장사동(종묘공원 부근)     6     6  126.993647
# 3     서울특별시 종로구4   서울특별시 종로구 창신동(동묘앞역_다산로_진입 부근)     6     6  127.016856
# 4      서울특별시 중구1        서울특별시 중구 인현동1가(대림상가앞 부근)     3     3  126.995341
# ...          ...                             ...   ...   ...         ...
# 4581  서울특별시 강동구1          서울특별시 강동구 암사동(암사시장 부근)     5     5  127.128676
# 4582  서울특별시 강동구2         서울특별시 강동구 천호동(천호사거리 부근)     4     4  127.123545
# 4583  서울특별시 강동구3       서울특별시 강동구 천호동(천호시장사거리 부근)     4     4  127.127767
# 4584  서울특별시 강동구4    서울특별시 강동구 암사동(장치봉의맵꼬만명태찜 부근)     3     3  127.134524
# 4585  서울특별시 강동구5        서울특별시 강동구 천호동(강동구민회관 부근)     3     3  127.141572
#
#              위도
# 0     37.571937
# 1     37.576104
# 2     37.570706
# 3     37.572359
# ...

# %%
df_acc.columns = ['구','지점','발생건수','사상자수','경도','위도']

# %%
df_acc.head()
# Out:
#             구                              지점  발생건수  사상자수          경도  \
# 0  서울특별시 종로구1  서울특별시 종로구 교북동(독립문_의주로_진출_1 부근)     3     3  126.960630
# 1  서울특별시 종로구2         서울특별시 종로구 충신동(이화사거리 부근)     5     5  127.004402
# 2  서울특별시 종로구3          서울특별시 종로구 장사동(종묘공원 부근)     6     6  126.993647
# 3  서울특별시 종로구4   서울특별시 종로구 창신동(동묘앞역_다산로_진입 부근)     6     6  127.016856
# 4   서울특별시 중구1        서울특별시 중구 인현동1가(대림상가앞 부근)     3     3  126.995341
#
#           위도
# 0  37.571937
# 1  37.576104
# 2  37.570706
# 3  37.572359
# 4  37.566380

# %%
df_acc['구'] = df_acc['구'].str.replace('서울특별시 ','')

# %%
df_acc.head()
# Out:
#       구                              지점  발생건수  사상자수          경도         위도
# 0  종로구1  서울특별시 종로구 교북동(독립문_의주로_진출_1 부근)     3     3  126.960630  37.571937
# 1  종로구2         서울특별시 종로구 충신동(이화사거리 부근)     5     5  127.004402  37.576104
# 2  종로구3          서울특별시 종로구 장사동(종묘공원 부근)     6     6  126.993647  37.570706
# 3  종로구4   서울특별시 종로구 창신동(동묘앞역_다산로_진입 부근)     6     6  127.016856  37.572359
# 4   중구1        서울특별시 중구 인현동1가(대림상가앞 부근)     3     3  126.995341  37.566380

# %%
import re
gu = []
for i in df_acc['구']:
    tmp = re.sub(r'[0-9]+','',i)
    gu.append(tmp)
gu
# Out:
# ['종로구',
#  '종로구',
#  '종로구',
#  '종로구',
#  '중구',
#  '중구',
#  '중구',
#  '용산구',
#  '용산구',
#  '용산구',
#  '성동구',
#  '성동구',
#  '광진구',
#  '광진구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '동대문구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '중랑구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '성북구',
#  '강북구',
#  '강북구',
#  '강북구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '도봉구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '노원구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '은평구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '서대문구',
#  '마포구',
#  '마포구',
#  '양천구',
#  '양천구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '강서구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '구로구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '금천구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
#  '영등포구',
# ...

# %%
df_acc['구'] = gu

# %%
df_acc
# Out:
#         구                              지점  발생건수  사상자수          경도         위도
# 0     종로구  서울특별시 종로구 교북동(독립문_의주로_진출_1 부근)     3     3  126.960630  37.571937
# 1     종로구         서울특별시 종로구 충신동(이화사거리 부근)     5     5  127.004402  37.576104
# 2     종로구          서울특별시 종로구 장사동(종묘공원 부근)     6     6  126.993647  37.570706
# 3     종로구   서울특별시 종로구 창신동(동묘앞역_다산로_진입 부근)     6     6  127.016856  37.572359
# 4      중구        서울특별시 중구 인현동1가(대림상가앞 부근)     3     3  126.995341  37.566380
# ...   ...                             ...   ...   ...         ...        ...
# 4581  강동구          서울특별시 강동구 암사동(암사시장 부근)     5     5  127.128676  37.551215
# 4582  강동구         서울특별시 강동구 천호동(천호사거리 부근)     4     4  127.123545  37.538955
# 4583  강동구       서울특별시 강동구 천호동(천호시장사거리 부근)     4     4  127.127767  37.540450
# 4584  강동구    서울특별시 강동구 암사동(장치봉의맵꼬만명태찜 부근)     3     3  127.134524  37.551891
# 4585  강동구        서울특별시 강동구 천호동(강동구민회관 부근)     3     3  127.141572  37.546180
#
# [1245 rows x 6 columns]

# %%
df_acc['지점'] = df_acc['지점'].str.replace('서울특별시 ','')

# %%
df_acc.head()
# Out:
#      구                        지점  발생건수  사상자수          경도         위도
# 0  종로구  종로구 교북동(독립문_의주로_진출_1 부근)     3     3  126.960630  37.571937
# 1  종로구         종로구 충신동(이화사거리 부근)     5     5  127.004402  37.576104
# 2  종로구          종로구 장사동(종묘공원 부근)     6     6  126.993647  37.570706
# 3  종로구   종로구 창신동(동묘앞역_다산로_진입 부근)     6     6  127.016856  37.572359
# 4   중구        중구 인현동1가(대림상가앞 부근)     3     3  126.995341  37.566380

# %%
df_acc.reset_index(inplace=True)

# %%
df_acc.head()
# Out:
#    index    구                        지점  발생건수  사상자수          경도         위도
# 0      0  종로구  종로구 교북동(독립문_의주로_진출_1 부근)     3     3  126.960630  37.571937
# 1      1  종로구         종로구 충신동(이화사거리 부근)     5     5  127.004402  37.576104
# 2      2  종로구          종로구 장사동(종묘공원 부근)     6     6  126.993647  37.570706
# 3      3  종로구   종로구 창신동(동묘앞역_다산로_진입 부근)     6     6  127.016856  37.572359
# 4      4   중구        중구 인현동1가(대림상가앞 부근)     3     3  126.995341  37.566380

# %%
df_acc.drop('index',axis=1,inplace=True)

# %%
df_acc.to_csv('../data/보행고령자 사고다발/서울 고령자사고다발지역.txt')

# %%
df_acc.head()
# Out:
#      구                        지점  발생건수  사상자수          경도         위도
# 0  종로구  종로구 교북동(독립문_의주로_진출_1 부근)     3     3  126.960630  37.571937
# 1  종로구         종로구 충신동(이화사거리 부근)     5     5  127.004402  37.576104
# 2  종로구          종로구 장사동(종묘공원 부근)     6     6  126.993647  37.570706
# 3  종로구   종로구 창신동(동묘앞역_다산로_진입 부근)     6     6  127.016856  37.572359
# 4   중구        중구 인현동1가(대림상가앞 부근)     3     3  126.995341  37.566380

# %%
j = df_acc[df_acc['구']=='동대문구']

# %%
j.to_csv('../data/보행고령자 사고다발/동대문구 사고다발지역.csv')

# %%
k = df_acc.groupby('구')['발생건수'].sum()
k = pd.DataFrame(k)
k.sort_values('발생건수',inplace=True, ascending=False)

# %%
k = k.T

# %%
k.head(10)
# Out:
#       발생건수
# 구
# 동대문구   561
# 성북구    366
# 관악구    322
# 강북구    317
# 은평구    291
# 중랑구    287
# 영등포구   260
# 동작구    243
# 서대문구   238
# 강동구    203

# %%
k.to_csv('../data/보행고령자 사고다발/구별 사고 발생건수.csv')

# %%
n = pd.read_csv('../data/보행고령자 사고다발/동대문구 사고다발지역.csv')
n
# Out:
#     Unnamed: 0     구                          지점  발생건수  사상자수          경도  \
# 0           14  동대문구        동대문구 답십리동(답십리사거리 부근)     4     5  127.057404
# 1           15  동대문구       동대문구 제기동(식당재료유통할인 부근)     4     4  127.039980
# 2           16  동대문구  동대문구 회기동(회기역앞_회기로_진출_1 부근)     4     5  127.054378
# 3           17  동대문구  동대문구 신설동(신설동역_난정로_진입_1 부근)     4     4  127.022965
# 4           18  동대문구         동대문구 제기동(홍파초교후문 부근)     4     5  127.040452
# ..         ...   ...                         ...   ...   ...         ...
# 93        1155  동대문구            동대문구 회기동(경희대 부근)     6    11  127.053115
# 94        1156  동대문구       동대문구 제기동(식당재료유통할인 부근)     5     5  127.040413
# 95        1157  동대문구         동대문구 장안동(장안동삼거리 부근)     4     4  127.071973
# 96        1158  동대문구         동대문구 용두동(서울시설공단 부근)     3     3  127.038110
# 97        1159  동대문구       동대문구 휘경동(위생병원앞교차로 부근)     3     3  127.063803
#
#            위도
# 0   37.571831
# 1   37.582779
# 2   37.589948
# 3   37.575074
# ...

# %%
n.drop('Unnamed: 0',axis=1,inplace=True)

# %%
n.sort_values('발생건수',inplace=True,ascending=False)
n.reset_index(inplace=True)

# %%
n.drop('index',axis=1,inplace=True)

# %%
n.head(10)
# Out:
#       구                               지점  발생건수  사상자수          경도         위도
# 0  동대문구  동대문구 청량리동(청량리역_일반국도6호선_진입_1 부근)    16    16  127.044103  37.579895
# 1  동대문구                동대문구 용두동(동서시장 부근)    15    16  127.040928  37.579062
# 2  동대문구             동대문구 제기동(성바오로병원앞 부근)    15    16  127.041983  37.579994
# 3  동대문구             동대문구 용두동(성바오로병원앞 부근)    13    13  127.042432  37.579213
# 4  동대문구      동대문구 청량리동(청량리역_홍릉길_진입_1 부근)    13    13  127.045492  37.580900
# 5  동대문구         동대문구 제기동(우리은행청량리중앙지점 부근)    13    13  127.041455  37.579079
# 6  동대문구             동대문구 청량리동(청량리우체국 부근)    13    15  127.045333  37.580646
# 7  동대문구         동대문구 제기동(우리은행청량리중앙지점 부근)    13    13  127.041389  37.579064
# 8  동대문구                동대문구 제기동(경동시장 부근)    13    14  127.037837  37.578536
# 9  동대문구                동대문구 용두동(경동시장 부근)    12    14  127.038330  37.578243

# %%
import folium

center = [37.541 , 126.986]
mapdata = folium.Map(location=center, zoom_start = 12)

for temp in df_acc.index:
    folium.Circle(
    [df_acc['위도'][temp], df_acc['경도'][temp]],
    radius = int(df_acc.loc[temp, ['발생건수']].values[0] * 8), color='red', fill_color='red'
    
    ).add_to(mapdata)
mapdata
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
import folium

center = [37.541 , 126.986]
mapdata = folium.Map(location=center, zoom_start = 12)

for temp in j.index:
    folium.Circle(
    [j['위도'][temp], j['경도'][temp]],
    radius = int(j.loc[temp, ['발생건수']].values[0] * 8), color='red', fill_color='red'
    
    ).add_to(mapdata)
mapdata
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
import folium

center = [37.579 , 127.045]
mapdata = folium.Map(location=center, zoom_start = 15)

for temp in j.index:
    folium.Circle(
    [j['위도'][temp], j['경도'][temp]],
    radius = 8, color='red', fill='crimson'
    
    ).add_to(mapdata)
mapdata
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
five = pd.read_csv('../data/보행고령자 사고다발/5곳.csv')

# %%
five
# Out:
#                                지점  발생건수  사상자수          경도         위도
# 0           동대문구 제기동(롯데불로장생센터 부근)     7     8  127.036742  37.578547
# 1  동대문구 용두동(경동시장_일반국도6호선_진출_1 부근)     9     9  127.037399  37.578212
# 2               동대문구 용두동(경동시장 부근)    12    14  127.038330  37.578243
# 3           동대문구 용두동(경동시장앞교차로 부근)     9    12  127.038351  37.578527
# 4               동대문구 제기동(경동시장 부근)    13    14  127.037837  37.578536

# %%
# 127.037731 37.578413
import folium

center = [37.578413, 127.037731]
mapdata = folium.Map(location=center, zoom_start = 16.3)


folium.Circle(
[37.578413, 127.037731],
radius = 100,color='red', fill_color='red'

).add_to(mapdata)
mapdata
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# import folium

# center = [37.541 , 126.986]
# mapdata = folium.Map(location=center, zoom_start = 12)

# for temp in df_acc.index:
#     folium.Circle(
#     [df_acc['위도'][temp], df_acc['경도'][temp]],
#     radius = int(df_acc.loc[temp, ['발생건수']].values[0] * 8), color='red', fill_color='red'
    
#     ).add_to(mapdata)
# mapdata

# %%
all_a = pd.read_csv('../data/보행고령자 사고다발/동대문구 4개 비교.csv')
all_a
# Out:
#    구역  발생건수  사상자수          경도         위도
# 0   1    50    57  127.037732  37.578413
# 1   2    76    78  127.041646  37.579497
# 2   3    58    60  127.045520  37.580895
# 3   4    15    17  127.055322  37.589933

# %%
all_a.set_index('구역')
# Out:
#     발생건수  사상자수          경도         위도
# 구역
# 1     50    57  127.037732  37.578413
# 2     76    78  127.041646  37.579497
# 3     58    60  127.045520  37.580895
# 4     15    17  127.055322  37.589933

# %%
# 127.0377316,37.57841294
import folium

center = [37.57841294, 127.0377316]
mapdata = folium.Map(location=center, zoom_start = 16.3)


folium.Circle(
[37.57841294, 127.0377316],
radius = 150,color='red', fill_color='red'

).add_to(mapdata)
for temp in j.index:
    folium.Circle(
    [j['위도'][temp], j['경도'][temp]],
    radius = int(j.loc[temp, ['발생건수']].values[0] /2), color='red', fill_color='red'
    
    ).add_to(mapdata)
mapdata
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# 127.0416463,37.57949654
import folium

center = [37.57949654, 127.0416463]
mapdata = folium.Map(location=center, zoom_start = 16.3)


folium.Circle(
[37.57949654, 127.0416463],
radius = 150,color='red', fill_color='red'

).add_to(mapdata)
for temp in j.index:
    folium.Circle(
    [j['위도'][temp], j['경도'][temp]],
    radius = int(j.loc[temp, ['발생건수']].values[0] /2), color='red', fill_color='red'
    
    ).add_to(mapdata)
mapdata
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# 127.0455197,37.58089546
import folium

center = [37.58089546, 127.0455197]
mapdata = folium.Map(location=center, zoom_start = 16.3)


folium.Circle(
[37.58089546, 127.0455197],
radius = 150,color='red', fill_color='red'

).add_to(mapdata)
for temp in j.index:
    folium.Circle(
    [j['위도'][temp], j['경도'][temp]],
    radius = int(j.loc[temp, ['발생건수']].values[0] /2), color='red', fill_color='red'
    
    ).add_to(mapdata)
mapdata
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# 127.0553216,37.58993298
import folium

center = [37.58993298, 127.0553216]
mapdata = folium.Map(location=center, zoom_start = 16.3)


folium.Circle(
[37.58993298, 127.0553216],
radius = 150,color='red', fill_color='red'

).add_to(mapdata)
for temp in j.index:
    folium.Circle(
    [j['위도'][temp], j['경도'][temp]],
    radius = int(j.loc[temp, ['발생건수']].values[0] /1), color='red', fill_color='red'
    
    ).add_to(mapdata)
mapdata
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
