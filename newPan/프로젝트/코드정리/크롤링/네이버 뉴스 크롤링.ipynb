# %%
import os
import sys
import urllib.request
import json
import re
import konlpy
from konlpy.tag import Okt
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import konlpy
from konlpy.tag import Okt
from collections import Counter
import konlpy.tag
import pandas as pd

def get_news():
    client_id = "OKQPTGKiQf0V3yitzK6o"
    client_secret = "uIGSvzveCB"


    keyword = input('뉴스 검색어를 입력해주세요')

    encText = urllib.parse.quote(keyword)

    tlist = []
    llist = []
    dlist = []



    for pagenum in range(1,1000,100):

        try:

            url = "https://openapi.naver.com/v1/search/news?query=" + encText +"&display=100&sort=sim&start="+str(pagenum)# json 결과   블로그 1~100  101~200
            # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
            request = urllib.request.Request(url)
            request.add_header("X-Naver-Client-Id",client_id)
            request.add_header("X-Naver-Client-Secret",client_secret)
            response = urllib.request.urlopen(request)
            rescode = response.getcode()
            if(rescode==200):
                response_body = response.read()
                print(response_body.decode('utf-8'))
                jtemp = response_body.decode('utf-8')
                jdata = json.loads(jtemp)

                jdata['items']

                for temp in jdata['items']:  
                    hangul = re.compile('[^ ㄱ-ㅎ|가-힣]+')
                    tdata = temp['title']
                    ldata = temp['link']
                    ddata = hangul.sub(r'',temp['description'])

                    tlist.append(tdata)
                    llist.append(ldata)
                    dlist.append(ddata)

            else:
                print("Error Code:" + rescode)

        except:
            print('Error')



    result = []
    for temp in range(len(tlist)):
        temp1 = []
        temp1.append(tlist[temp])
        temp1.append(llist[temp])
        temp1.append(dlist[temp])

        result.append(temp1)

    f = open('{0} - 네이버API 뉴스검색.csv'.format(keyword) , 'w', encoding='utf-8')
    f.write('제목'+',' + '링크' + ',' + '내용' + '\n')
    for temp in result:    
            f.write(temp[0] + ',' + temp[1] + ',' + temp[2] +'\n')
    f.close()
    
    return result

# %%
def clean_str(s):
    hangul = re.compile('[^ㄱ-ㅎ|가-힣]+')
    s = hangul.sub(r' ',s)
    
    cp = re.compile("["
                     u"\U00010000-\U0010FFFF"
                     "]+", flags=re.UNICODE)
    s = cp.sub(r' ',s)
    
    return s.strip()

def get_text(data):
    result_text = ''
    for temp in data:
        result_text = result_text +' ' +  temp[2]

    return result_text


def Wordcloud(data , savename , maskname=''):
    noun_text = ''
    for word in data:
        noun_text = noun_text +' ' + word
    
    if maskname == '':
        wc = WordCloud( font_path='../data/WordCloud/font/BMEULJIROTTF.ttf' , background_color='white', max_font_size=60, colormap='Blues').generate(noun_text)
    else:
        maskimg = np.array(Image.open(maskname))
        wc = WordCloud(font_path='../data/WordCloud/font/BMEULJIROTTF.ttf' , background_color='white', mask=maskimg, max_font_size=60, colormap='Blues').generate(noun_text)
        
#     wc.generate_from_frequencies(data)
    plt.figure(figsize=(20,10))
    plt.imshow(wc)
    plt.tight_layout(pad=0)
    plt.axis('off')
    plt.show()
    wc.to_file('../data/크롤링/savename' + '.png')

# %%
bdata = get_news()
rtext = get_text(bdata)
# Out:
# 뉴스 검색어를 입력해주세요어린이보호구역
# {
# "lastBuildDate": "Thu, 30 Sep 2021 14:17:54 +0900",
# "total": 104777,
# "start": 1,
# "display": 100,
# "items": [
# {
# "title": "금호타이어, 전국 초등학생 대상 '<b>어린이</b> 교통안전교육' 실시",
# "originallink": "https://www.news1.kr/articles/?4447829",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=103&oid=421&aid=0005629159",
# "description": "금호타이어가 제작한 워크북에는 Δ안전한 보행법 Δ<b>어린이 보호구역</b>에서 지켜야 할 안전수칙 Δ교통안전 표지판 Δ바퀴 달린 놀이기구의 안전한 이용법 Δ도전! 안전 골든벨(퀴즈) Δ내가 만드는 안전한 학교 가는 길... ",
# "pubDate": "Thu, 30 Sep 2021 08:52:00 +0900"
#
# },
# {
# "title": "금호타이어, '<b>어린이</b> 교통안전교육' 진행",
# "originallink": "http://autotimes.hankyung.com/apps/news.sub_view?popup=0&nid=03&c1=03&c2=03&c3=00&nkey=202109301046191",
# "link": "http://autotimes.hankyung.com/apps/news.sub_view?popup=0&nid=03&c1=03&c2=03&c3=00&nkey=202109301046191",
# "description": "금호타이어에서 제작한 워크북에는 안전한 보행법, <b>어린이 보호구역</b>에서 지켜야 할 안전수칙, 교통안전 표지판, 바퀴 달린 놀이기구의 안전한 이용법, 도전! 안전 골든벨(퀴즈), 내가 만드는 안전한 학교 가는 길... ",
# "pubDate": "Thu, 30 Sep 2021 10:48:00 +0900"
#
# },
# {
# "title": "금호타이어, 전국 초등학생 대상 '<b>어린이</b> 교통안전교육'",
# "originallink": "http://www.fnnews.com/news/202109300906261883",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=014&aid=0004716100",
# "description": "금호타이어에서 제작한 워크북에는 안전한 보행법, <b>어린이 보호구역</b>에서 지켜야 할 안전수칙, 교통안전 표지판, 바퀴 달린 놀이기구의 안전한 이용법, 도전! 안전 골든벨(퀴즈), 내가 만드는 안전한 학교 가는 길... ",
# "pubDate": "Thu, 30 Sep 2021 09:09:00 +0900"
#
# },
# {
# "title": "CJ대한통운, 군포 30곳에 <b>어린이 보호</b> '노란발자국' 부착",
# "originallink": "http://www.newsis.com/view/?id=NISX20210928_0001595888&cID=13001&pID=13000",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=003&aid=0010740637",
# "description": "CJ대한통운은 굿네이버스와 함께 군포 지역 <b>어린이</b>집·초등학교 등 <b>어린이 보호구역</b> 횡단보도 30곳에 교통사고 예방을 돕는 '노란 발자국'을 설치한다고 28일 밝혔다. '노란 발자국' 설치 작업은 군포시청, 군포경찰서와의... ",
# "pubDate": "Tue, 28 Sep 2021 15:32:00 +0900"
#
# },
# {
# "title": "금호타이어, 초등학생 대상 '<b>어린이</b> 교통안전교육' 실시",
# "originallink": "http://www.inews24.com/view/1407981",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=031&aid=0000626474",
# "description": "금호타이어에서 제작한 워크북에는 안전한 보행법, <b>어린이 보호구역</b>에서 지켜야 할 안전수칙, 교통안전 표지판, 바퀴 달린 놀이기구의 안전한 이용법, 도전! 안전 골든벨(퀴즈), 내가 만드는 안전한 학교 가는 길... ",
# "pubDate": "Thu, 30 Sep 2021 10:50:00 +0900"
#
# },
# {
# "title": "금호타이어, 전국 초등학생 대상 '<b>어린이</b> 교통안전교육' 실시",
# "originallink": "https://sports.hankooki.com/lpage/economy/202109/sp20210930093453136980.htm?s_ref=nv",
# "link": "https://sports.hankooki.com/lpage/economy/202109/sp20210930093453136980.htm?s_ref=nv",
# "description": "금호타이어가 제작한 워크북에는 안전한 보행법, <b>어린이 보호구역</b>에서 지켜야 할 안전수칙, 교통안전 표지판, 바퀴 달린 놀이기구의 안전한 이용법, 도전! 안전 골든벨(퀴즈), 내가 만드는 안전한 학교 가는 길... ",
# "pubDate": "Thu, 30 Sep 2021 09:36:00 +0900"
#
# },
# {
# "title": "금호타이어 전국 초등생 대상 '<b>어린이</b> 교통안전교육' ",
# "originallink": "http://www.gjdream.com/news/articleView.html?idxno=610461",
# "link": "http://www.gjdream.com/news/articleView.html?idxno=610461",
# "description": "금호타이어에서 제작한 워크북에는 안전한 보행법, <b>어린이 보호구역</b>에서 지켜야 할 안전수칙, 교통안전 표지판, 바퀴 달린 놀이기구의 안전한 이용법, 도전! 안전 골든벨(퀴즈), 내가 만드는 안전한 학교 가는 길... ",
# "pubDate": "Thu, 30 Sep 2021 10:36:00 +0900"
#
# },
# {
# "title": "태백시, <b>어린이 보호구역</b> 노란색 신호등 교체",
# "originallink": "https://www.pressian.com/pages/articles/2021092915400121667?utm_source=naver&utm_medium=search",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=002&aid=0002212167",
# "description": "또한, 2018년 황지초 <b>어린이보호구역</b> 내 경보등 4개 설치한 것을 시작으로 2020년 노란색 신호등을 상장초등학교 1곳 12개, 중앙초등학교 1곳 6개를 설치했으며 올해에는 철암초등학교 1곳 5개를 설치 완료했다. 시... ",
# "pubDate": "Wed, 29 Sep 2021 17:15:00 +0900"
#
# },
# {
# "title": "[남해] 창선초교 앞 <b>어린이보호구역</b>에 '노란 발자국' 설치",
# "originallink": "http://www.ohmynews.com/NWS_Web/View/at_pg.aspx?CNTN_CD=A0002776430&CMPT_CD=P0010&utm_source=naver&utm_medium=newsearch&utm_campaign=naver_news",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=047&aid=0002327731",
# "description": "ⓒ 남해군청 경남 남해 창선초등학교 앞 도로인 <b>어린이보호구역</b>(스쿨존)에 '노란발자국'이 설치됐다. 남해군자원봉사센터는 창선면지역사회보장협의체 봉사자와 창선초등학교 학생·교사와 함께 노란발자국 설치 활동을... ",
# "pubDate": "Tue, 28 Sep 2021 09:15:00 +0900"
#
# },
# {
# "title": "금호타이어, 전국 초등학생 대상 ‘<b>어린이</b> 교통안전교육’ 실시",
# "originallink": "http://www.edaily.co.kr/news/newspath.asp?newsid=01626886629185368",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=103&oid=018&aid=0005047969",
# "description": "금호타이어에서 제작한 워크북에는 안전한 보행법, <b>어린이 보호구역</b>에서 지켜야 할 안전수칙, 교통안전 표지판, 바퀴 달린 놀이기구의 안전한 이용법, 도전! 안전 골든벨(퀴즈), 내가 만드는 안전한 학교 가는 길... ",
# "pubDate": "Thu, 30 Sep 2021 09:14:00 +0900"
#
# },
# {
# "title": "금호타이어, 전국 초등학생 대상 '<b>어린이</b> 교통안전교육' 실시",
# "originallink": "http://www.sisaweek.com/news/articleView.html?idxno=147657",
# "link": "http://www.sisaweek.com/news/articleView.html?idxno=147657",
# "description": "금호타이어에서 제작한 워크북에는 △안전한 보행법 △<b>어린이 보호구역</b>에서 지켜야 할 안전수칙 △교통안전 표지판 △바퀴 달린 놀이기구의 안전한 이용법 △도전! 안전 골든벨(퀴즈) △내가 만드는 안전한 학교... ",
# "pubDate": "Thu, 30 Sep 2021 10:54:00 +0900"
#
# },
# {
# "title": "CJ대한통운, <b>어린이</b> 등하굣길 ‘노란발자국’ 부착",
# "originallink": "https://view.asiae.co.kr/article/2021092809025561581",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=277&aid=0004974890",
# "description": "CJ대한통운은 굿네이버스와 함께 군포 지역 내 <b>어린이</b>집, 초등학교 등 <b>어린이 보호구역</b> 횡단보도 30개소에 교통사고 예방을 돕는 ‘노란 발자국’을 설치한다고 28일 밝혔다. ‘노란 발자국’ 설치 작업은 군포시청... ",
# "pubDate": "Tue, 28 Sep 2021 09:00:00 +0900"
#
# },
# {
# "title": "금호타이어, 전국 초등학생 대상 '<b>어린이</b> 교통안전교육' 실시",
# "originallink": "http://www.autodaily.co.kr/news/articleView.html?idxno=429690",
# "link": "http://www.autodaily.co.kr/news/articleView.html?idxno=429690",
# "description": "금호타이어에서 제작한 워크북에는 안전한 보행법, <b>어린이 보호구역</b>에서 지켜야 할 안전수칙, 교통안전 표지판, 바퀴 달린 놀이기구의 안전한 이용법, 도전! 안전 골든벨(퀴즈), 내가 만드는 안전한 학교 가는... ",
# "pubDate": "Thu, 30 Sep 2021 09:07:00 +0900"
#
# },
# {
# "title": "<b>어린이 보호구역</b> 네 모녀 사상 화물기사, 2심 감형",
# "originallink": "http://www.newsis.com/view/?id=NISX20210928_0001595767&cID=10201&pID=10200",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=003&aid=0010740386",
# "description": "기사내용 요약징역 5년→2년 6개월 &quot;합의한 점 등 두루 고려&quot; <b>어린이 보호구역</b> 횡단보도에서 네 모녀를 치어 사상케 한 혐의로 기소된 화물차 기사가 항소심에서 감형받았다. 광주고법 제2-2형사부(위광하·박정훈·성충용... ",
# "pubDate": "Tue, 28 Sep 2021 14:32:00 +0900"
#
# },
# {
# "title": "<b>어린이보호구역</b>서 일가족 사상케 한 트럭운전자 항소심서 감형",
# "originallink": "https://www.nocutnews.co.kr/news/5630709",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=079&aid=0003557061",
# "description": "<b>어린이보호구역</b>에서 일가족 4명을 들이받아 1명을 숨지게 한 혐의로 재판에 넘겨진 50대 트럭운전자가 항소심에서 감형받았다. 광주고등법원 형사2-2부(위광하 박정훈 성충용 고법판사)는 28일 특정범죄 가중처벌 등에... ",
# "pubDate": "Tue, 28 Sep 2021 15:04:00 +0900"
#
# },
# {
# "title": "광주 남부경찰, <b>어린이 보호구역</b> 불법 주·정차 단속",
# "originallink": "https://www.jnilbo.com/view/media/view?code=2021093010585539161",
# "link": "https://www.jnilbo.com/view/media/view?code=2021093010585539161",
# "description": "광주 남부경찰 교통안전계는 관내 초등학교 앞 불법 주·정차 단속을 했다고 30일 밝혔다.남부경찰은 불법 주·정차로 인한 <b>어린이</b> 교통사고 예방을 위해 남구 교통과와 합동으로 단속을 진행했다. 이번 단속은 불로초... ",
# "pubDate": "Thu, 30 Sep 2021 11:10:00 +0900"
#
# },
# {
# "title": "CJ대한통운, 군포 <b>어린이 보호구역</b> 횡단보도 30곳에 '노란 발자국' 설치",
# "originallink": "https://www.etoday.co.kr/news/view/2064881",
# "link": "https://www.etoday.co.kr/news/view/2064881",
# "description": "이투데이=김벼리 기자 | 교통사고 예방 도와 CJ대한통운 관계자들이 경기도 군포시 <b>어린이보호구역</b>에 노란발자국을 설치하고 있다. (사진제공=CJ대한통운) CJ대한통운은 굿네이버스와 함께 군포 지역 내 <b>어린이</b>집... ",
# "pubDate": "Tue, 28 Sep 2021 10:02:00 +0900"
#
# },
# {
# "title": "금호타이어, 전국 초등학생 대상 '<b>어린이</b> 교통안전교육' 실시",
# "originallink": "http://www.newslock.co.kr/news/articleView.html?idxno=46756",
# "link": "http://www.newslock.co.kr/news/articleView.html?idxno=46756",
# "description": "금호타이어에서 제작한 워크북에는 안전한 보행법, <b>어린이 보호구역</b>에서 지켜야 할 안전수칙, 교통안전 표지판, 바퀴 달린 놀이기구의 안전한 이용법, 도전! 안전 골든벨(퀴즈), 내가 만드는 안전한 학교 가는 길... ",
# "pubDate": "Thu, 30 Sep 2021 10:05:00 +0900"
#
# },
# {
# "title": "금호타이어, 전국 초등학생 대상 '<b>어린이</b> 교통안전교육' 실시",
# "originallink": "http://www.newspim.com/news/view/20210930000344",
# "link": "http://www.newspim.com/news/view/20210930000344",
# "description": "금호타이어에서 제작한 워크북에는 안전한 보행법, <b>어린이 보호구역</b>에서 지켜야 할 안전수칙, 교통안전 표지판, 바퀴 달린 놀이기구의 안전한 이용법, 도전! 안전 골든벨(퀴즈), 내가 만드는 안전한 학교 가는 길... ",
# "pubDate": "Thu, 30 Sep 2021 10:44:00 +0900"
#
# },
# {
# "title": "CJ대한통운, <b>어린이</b> 등하굣길에 '노란발자국' 부착",
# "originallink": "http://www.etnews.com/20210928000081",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=030&aid=0002971818",
# "description": "CJ대한통운이 경기도 군포시 <b>어린이 보호구역</b> 횡단보도에 '노란 발자국'을 설치하며 <b>어린이</b>들을 위한 안전한 등하굣길 만들기에 나섰다. CJ대한통운은 굿네이버스와 함께 군포 지역 내 <b>어린이</b>집, 초등학교 등 <b>어린이</b>... ",
# "pubDate": "Tue, 28 Sep 2021 10:42:00 +0900"
#
# },
# {
# "title": "금호타이어, 전국 초등학생 대상 '<b>어린이</b> 교통안전교육' 실시",
# "originallink": "https://www.ngetnews.com/news/articleView.html?idxno=403419",
# "link": "https://www.ngetnews.com/news/articleView.html?idxno=403419",
# "description": "금호타이어에서 제작한 워크북에는 안전한 보행법, <b>어린이 보호구역</b>에서 지켜야 할 안전수칙, 교통안전 표지판, 바퀴 달린 놀이기구의 안전한 이용법, 도전! 안전 골든벨(퀴즈), 내가 만드는 안전한 학교 가는 길... ",
# "pubDate": "Thu, 30 Sep 2021 09:09:00 +0900"
#
# },
# {
# "title": "금호타이어, 전국 초등학생 대상 '<b>어린이</b> 교통안전교육' 실시",
# "originallink": "http://www.taxtimes.co.kr/news/article.html?no=251746",
# "link": "http://www.taxtimes.co.kr/news/article.html?no=251746",
# "description": "금호타이어에서 제작한 워크북에는 안전한 보행법, <b>어린이 보호구역</b>에서 지켜야 할 안전수칙, 교통안전 표지판, 바퀴 달린 놀이기구의 안전한 이용법, 도전! 안전 골든벨(퀴즈), 내가 만드는 안전한 학교 가는 길... ",
# "pubDate": "Thu, 30 Sep 2021 13:48:00 +0900"
#
# },
# {
# "title": "CJ대한통운, 군포 <b>어린이 보호구역</b>에 ‘노란발자국’ 부착",
# "originallink": "http://www.nextdaily.co.kr/news/article.html?id=20210928800020",
# "link": "http://www.nextdaily.co.kr/news/article.html?id=20210928800020",
# "description": "CJ대한통운은 굿네이버스와 함께 군포 지역 내 <b>어린이</b>집, 초등학교 등 <b>어린이 보호구역</b> 횡단보도 30개소에 교통사고 예방을 돕는 ‘노란 발자국’을 설치한다고 28일 밝혔다. ‘노란 발자국’ 설치 작업은 군포시청... ",
# "pubDate": "Tue, 28 Sep 2021 11:42:00 +0900"
#
# },
# {
# "title": "CJ대한통운, <b>어린이</b> 등하굣길에 '노란발자국' 부착",
# "originallink": "http://www.inews24.com/view/1407280",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=031&aid=0000625982",
# "description": "CJ대한통운이 경기도 군포시 <b>어린이 보호구역</b> 횡단보도에 '노란 발자국'을 설치하며 <b>어린이</b>들을 위한 안전한 등하굣길 만들기에 나섰다. CJ대한통운이 굿네이버스와 함께 군포 지역 내 <b>어린이</b>집, 초등학교 등 <b>어린이</b>... ",
# "pubDate": "Tue, 28 Sep 2021 12:12:00 +0900"
#
# },
# {
# "title": "금호타이어, 전국 초등학생 대상 '<b>어린이</b> 교통안전교육' 실시",
# "originallink": "http://www.lcnews.co.kr/news/articleView.html?idxno=25001",
# "link": "http://www.lcnews.co.kr/news/articleView.html?idxno=25001",
# "description": "금호타이어에서 제작한 워크북에는 안전한 보행법, <b>어린이 보호구역</b>에서 지켜야 할 안전수칙, 교통안전 표지판, 바퀴 달린 놀이기구의 안전한 이용법, 도전! 안전 골든벨(퀴즈), 내가 만드는 안전한 학교 가는 길... ",
# "pubDate": "Thu, 30 Sep 2021 10:49:00 +0900"
#
# },
# {
# "title": "여수시, 안전속도 5030 “<b>어린이</b> 안전 우리가 지켜요”",
# "originallink": "https://www.wikitree.co.kr/articles/692945",
# "link": "https://www.wikitree.co.kr/articles/692945",
# "description": "여수시(시장 권오봉)는 지난 28일 미평초등학교 일대 <b>어린이 보호구역</b>에서 ‘안전속도 5030’ 및 ‘속도를 줄이면 <b>어린이</b>가 보입니다’를 주제로 교통안전 캠페인을 진행했다고 밝혔다. 이날 캠페인에는 녹색어머니회를... ",
# "pubDate": "Wed, 29 Sep 2021 10:28:00 +0900"
#
# },
# {
# "title": "CJ대한통운, 안전한 <b>어린이</b> 등하굣길 위해 팔 걷어",
# "originallink": "http://www.ajunews.com/view/20210928100118152",
# "link": "http://www.ajunews.com/view/20210928100118152",
# "description": "이보미 기자 lbm929@ajunews.com CJ대한통운이 경기도 군포시 <b>어린이보호구역</b>에 노란발자국을 설치하고 있다. [사진=CJ대한통운 제공 ] CJ대한통운은 굿네이버스와 함께 경기도 군포 지역 내 <b>어린이</b>집과 초등학교 등 <b>어린이</b>... ",
# "pubDate": "Tue, 28 Sep 2021 15:04:00 +0900"
#
# },
# {
# "title": "태백시, <b>어린이 보호구역</b> '노란신호등'으로 교체 공사",
# "originallink": "http://www.weeklytoday.com/news/articleView.html?idxno=408697",
# "link": "http://www.weeklytoday.com/news/articleView.html?idxno=408697",
# "description": "또한, 2018년 황지초 <b>어린이보호구역</b> 내 경보등 4개 설치한 것을 시작으로 2020년도에는 노란색 신호등을 상장초등학교 1개소 12개, 중앙초등학교 1개소 6개를 설치했으며 올해에는 철암초등학교 1개소 5개를... ",
# "pubDate": "Wed, 29 Sep 2021 12:08:00 +0900"
#
# },
# {
# "title": "DB손보, <b>어린이보호구역</b> 옐로카펫 100곳에 설치",
# "originallink": "https://view.asiae.co.kr/article/2021092710084037838",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=277&aid=0004974326",
# "description": "DB손해보험은 초록우산<b>어린이</b>재단과 <b>어린이보호구역</b> 교통안전을 위한 옐로카펫 설치와 소외계층 지원을 위한 사랑나눔 봉사협약을 체결했다고 27일 밝혔다. 옐로 카펫은 횡단보도 신호대기공간을 노란색으로 바꿔서... ",
# "pubDate": "Mon, 27 Sep 2021 10:06:00 +0900"
#
# },
# {
# "title": "태백시, <b>어린이 보호구역</b> 노란색 신호등 교체",
# "originallink": "http://www.shinailbo.co.kr/news/articleView.html?idxno=1465250",
# "link": "http://www.shinailbo.co.kr/news/articleView.html?idxno=1465250",
# "description": "또한, 지난 2018년 황지초등학교 <b>어린이보호구역</b> 내 경보등 4개 설치한 것을 시작으로 2020년도에는 노란색 신호등을 상장초등학교 1개소 12개, 중앙초등학교 1개소 6개를 설치했으며 올해에는 철암초등학교 1개소 5개를... ",
# "pubDate": "Wed, 29 Sep 2021 14:52:00 +0900"
#
# },
# {
# "title": "안성시, <b>어린이</b> 교통안전 합동 캠페인 전개",
# "originallink": "http://www.jejutwn.com/news/article.html?no=93978",
# "link": "http://www.jejutwn.com/news/article.html?no=93978",
# "description": "안성시는 9월 30일 양진초등학교 앞에서 <b>어린이보호구역</b> 교통문화 질서 확립 및 안전한 교통환경 조성을 위해 안성경찰서, 안성녹색어머니회, 안성모범운전자회, 양진초등학교 관계자 등 유관기관·협력단체 약 40명과... ",
# "pubDate": "Thu, 30 Sep 2021 12:45:00 +0900"
#
# },
# {
# "title": "여수시, 안전속도 5030 &quot;<b>어린이</b> 안전 우리가 지켜요&quot;",
# "originallink": "http://www.enewstoday.co.kr/news/articleView.html?idxno=1515062",
# "link": "http://www.enewstoday.co.kr/news/articleView.html?idxno=1515062",
# "description": "전남 여수시는 지난 28일 미평초등학교 일대 <b>어린이 보호구역</b>에서 '안전속도 5030' 및 '속도를 줄이면 <b>어린이</b>가 보입니다'를 주제로 교통안전 캠페인을 진행했다. 여수시가 지난 28일 미평초등학교 일대 <b>어린이</b>... ",
# "pubDate": "Wed, 29 Sep 2021 10:40:00 +0900"
#
# },
# {
# "title": "CJ대한통운, <b>어린이</b> 등하굣길에 '노란발자국' 부착",
# "originallink": "http://www.businesskorea.co.kr/news/articleView.html?idxno=77296",
# "link": "http://www.businesskorea.co.kr/news/articleView.html?idxno=77296",
# "description": "CJ대한통운이 경기도 군포시 <b>어린이보호구역</b>에 노란발자국을 설치하고 있다. '노란 발자국'은 <b>어린이</b>들이 횡단보도 신호대기 시 안전거리를 유지할 수 있도록 차도와 1m가량 떨어진 인도 양방향에 부착하는 발자국... ",
# "pubDate": "Tue, 28 Sep 2021 08:41:00 +0900"
#
# },
# {
# "title": "CJ대한통운, 군포에 <b>어린이</b> 교통사고 예방 '노란발자국' 설치한다",
# "originallink": "http://www.newspim.com/news/view/20210928001014",
# "link": "http://www.newspim.com/news/view/20210928001014",
# "description": "CJ대한통운이 경기도 군포시 <b>어린이보호구역</b>에 노란발자국을 설치하고 있다. [사진=CJ대한통운] CJ대한통운은 '노란 발자국'과 함께 보행자 정지선을 알리는 '노란 정지선'과 '<b>어린이 보호구역</b> 표지판'을 함께 설치한다.... ",
# "pubDate": "Tue, 28 Sep 2021 18:25:00 +0900"
#
# },
# {
# "title": "CJ대한통운, 군포에 <b>어린이</b> 안전 위한 '노란발자국' 설치",
# "originallink": "http://www.klnews.co.kr/news/articleView.html?idxno=302560",
# "link": "http://www.klnews.co.kr/news/articleView.html?idxno=302560",
# "description": "CJ대한통운은 굿네이버스와 함께 군포 지역 내 <b>어린이</b>집, 초등학교 등 <b>어린이 보호구역</b> 횡단보도 30개소에 교통사고 예방을 돕는 '노란발자국'을 설치한다고 28일 밝혔다. 이번 설치 작업은 군포시청, 군포경찰서와 협력을... ",
# "pubDate": "Tue, 28 Sep 2021 10:12:00 +0900"
#
# },
# {
# "title": "태백시, <b>어린이 보호구역</b> 노란신호등 교체",
# "originallink": "http://www.gukjenews.com/news/articleView.html?idxno=2317857",
# "link": "http://www.gukjenews.com/news/articleView.html?idxno=2317857",
# "description": "또한, 2018년 황지초 <b>어린이보호구역</b> 내 경보등 4개 설치한 것을 시작으로 2020년도에는 노란색 신호등을 상장초등학교 1개소 12개, 중앙초등학교 1개소 6개를 설치했으며 올해에는 철암초등학교 1개소 5개를... ",
# "pubDate": "Wed, 29 Sep 2021 13:04:00 +0900"
#
# },
# {
# "title": "CJ대한통운, 군포지역 <b>어린이</b> 등하굣길 '노란발자국' 부착",
# "originallink": "http://www.shinailbo.co.kr/news/articleView.html?idxno=1465025",
# "link": "http://www.shinailbo.co.kr/news/articleView.html?idxno=1465025",
# "description": "CJ대한통운은 굿네이버스와 함께 군포 지역 내 <b>어린이</b>집, 초등학교 등 <b>어린이 보호구역</b> 횡단보도 30개소에 교통사고 예방을 돕는 ‘노란 발자국’을 설치한다고 28일 밝혔다. 노란 발자국 설치는 군포시청, 군포경찰서와... ",
# "pubDate": "Tue, 28 Sep 2021 17:20:00 +0900"
#
# },
# {
# "title": "강동구, <b>어린이</b> 통학로 안전하게 지킨다",
# "originallink": "http://www.jejutwn.com/news/article.html?no=93414",
# "link": "http://www.jejutwn.com/news/article.html?no=93414",
# "description": "우선, ‘음성안내 보조장치’를 <b>어린이보호구역</b> 4개소 ▲강일초 ▲고일초(고덕유치원) ▲명덕초 ▲천동초에 설치하여 무단횡단을 방지하고 안전한 보행을 유도한다. 음성안내를 통해 운전자와 보행자에게 도로 상황 및... ",
# "pubDate": "Thu, 30 Sep 2021 09:11:00 +0900"
#
# },
# {
# "title": "CJ대한통운, <b>어린이</b> 등하굣길에 ‘노란발자국’ 부착",
# "originallink": "http://www.nspna.com/news/?mode=view&newsid=528537",
# "link": "http://www.nspna.com/news/?mode=view&newsid=528537",
# "description": "이복현 기자, CJ대한통운이 굿네이버스와 함께 군포 지역 내 <b>어린이</b>집, 초등학교 등 <b>어린이 보호구역</b> 횡단보도 30개소에 교통사고 예방을 돕는 ‘노란 발자국’을 설치한다. 노란 발자국 설치 작업은 군포시청... ",
# "pubDate": "Tue, 28 Sep 2021 12:54:00 +0900"
#
# },
# {
# "title": "&quot;횡단보도 앞에선 멈춰요!&quot;… CJ대한통운, <b>어린이</b> 등하굣길에 '노란 발자국' ...",
# "originallink": "http://moneys.mt.co.kr/news/mwView.php?no=2021092810358095204",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=417&aid=0000738398",
# "description": "CJ대한통운이 경기도 군포시 <b>어린이 보호구역</b> 횡단보도에 '노란 발자국'을 설치하며 <b>어린이</b>들을 위한 안전한 등하굣길 만들기에 나섰다. CJ대한통운은 굿네이버스와 함께 군포 지역 내 <b>어린이</b>집, 초등학교 등 <b>어린이</b>... ",
# "pubDate": "Tue, 28 Sep 2021 10:52:00 +0900"
#
# },
# {
# "title": "안성시, 유관기관·협력단체 합동 <b>어린이</b> 교통안전 캠페인 전개",
# "originallink": "http://www.weeklytoday.com/news/articleView.html?idxno=409358",
# "link": "http://www.weeklytoday.com/news/articleView.html?idxno=409358",
# "description": "▲ 안성시, 유관기관·협력단체 합동 <b>어린이</b> 교통안전 캠페인 전개 안성시는 9월 30일 양진초등학교 앞에서 <b>어린이보호구역</b> 교통문화 질서 확립 및 안전한 교통환경 조성을 위해 안성경찰서 안성녹색어머니회... ",
# "pubDate": "Thu, 30 Sep 2021 12:50:00 +0900"
#
# },
# {
# "title": "CJ대한통운, <b>어린이</b> 등하굣길에 ‘노란발자국’ 부착",
# "originallink": "https://www.cnbnews.com/news/article.html?no=512038",
# "link": "https://www.cnbnews.com/news/article.html?no=512038",
# "description": "▲ CNB,씨앤비,시앤비,CNB뉴스,씨앤비뉴스 CJ대한통운이 굿네이버스와 함께 군포 지역 내 <b>어린이</b>집·초등학교 등 <b>어린이 보호구역</b> 횡단보도 30개소에 교통사고 예방을 돕는 ‘노란 발자국’을 설치한다고 28일 밝혔다.... ",
# "pubDate": "Tue, 28 Sep 2021 16:06:00 +0900"
#
# },
# {
# "title": "[사회 단신] CJ대한통운, <b>어린이</b> 등하굣길 ‘노란발자국’ 부착 등",
# "originallink": "http://www.lawissue.co.kr/view.php?ud=202109281809082804f4ab64559d_12",
# "link": "http://www.lawissue.co.kr/view.php?ud=202109281809082804f4ab64559d_12",
# "description": "◇ CJ대한통운, <b>어린이</b> 등하굣길 ‘노란발자국’ 부착 CJ대한통운이 굿네이버스와 함께 군포 지역 내 <b>어린이</b>집, 초등학교 등 <b>어린이 보호구역</b> 횡단보도 30개소에 교통사고 예방을 돕는 ‘노란 발자국’을 설치한다고 28일... ",
# "pubDate": "Tue, 28 Sep 2021 18:12:00 +0900"
#
# },
# {
# "title": "제주경찰청, ‘<b>어린이</b> 교통안전지도 제작’ 공모전 개최",
# "originallink": "http://www.boannews.com/media/view.asp?idx=101112&kind=",
# "link": "http://www.boannews.com/media/view.asp?idx=101112&kind=",
# "description": "이번 공모전을 통해 접수된 출품작들을 대상으로 공정한 심사를 통해 우수작 9편을 선발 후 제주청장 상장 및 부상품 등을 수여할 예정이다.그간 경찰에서는 <b>어린이보호구역</b>(스쿨존) 내 <b>어린이</b> 교통사고를 예방하기... ",
# "pubDate": "Thu, 30 Sep 2021 13:32:00 +0900"
#
# },
# {
# "title": "CJ대한통운, 군포 <b>어린이 보호구역</b>에 교통안전 위한 '노란 발자국' 설치",
# "originallink": "http://www.choicenews.co.kr/news/articleView.html?idxno=85131",
# "link": "http://www.choicenews.co.kr/news/articleView.html?idxno=85131",
# "description": "사진=CJ대한통운 CJ대한통운은 28일 &quot;군포 지역 <b>어린이 보호구역</b> 횡단보도 30곳에 교통사고 예방을 돕는 '노란 발자국'을 설치한다&quot;고 밝혔다. CJ대한통운에 따르면 '노란 발자국'은 <b>어린이</b>들이 횡단보도 신호대기때... ",
# "pubDate": "Tue, 28 Sep 2021 16:14:00 +0900"
#
# },
# {
# "title": "이소영 &quot;<b>어린이 보호구역</b>에 미인가 대안학교도 포함하는 길 열려&quot;",
# "originallink": "http://www.enewstoday.co.kr/news/articleView.html?idxno=1515323",
# "link": "http://www.enewstoday.co.kr/news/articleView.html?idxno=1515323",
# "description": "<b>어린이 보호구역</b> 지정대상에 미인가 대안학교를 포함하는 등 <b>보호구역</b> 지정대상이 확대돼 <b>어린이</b> 안전을 더욱 두텁게 <b>보호</b>할 수 있는 길이 열렸다. 국회 더불어민주당 이소영 의원(경기 의왕·과천)에 따르면, <b>어린이</b>... ",
# "pubDate": "Thu, 30 Sep 2021 08:15:00 +0900"
#
# },
# {
# "title": "CJ대한통운, 군포 지역 <b>어린이 보호구역</b> '노란발자국' 부착",
# "originallink": "http://www.newslock.co.kr/news/articleView.html?idxno=46625",
# "link": "http://www.newslock.co.kr/news/articleView.html?idxno=46625",
# "description": "사진 CJ대한통운 제공 [뉴스락] CJ대한통운은 경기도 군포시 <b>어린이 보호구역</b> 횡단보도에 '노란 발자국'을 설치하며 안전한 등하굣길 만들기에 나선다고 28일 밝혔다. CJ대한통운은 굿네이버스와 함께 군포 지역 내... ",
# "pubDate": "Tue, 28 Sep 2021 15:11:00 +0900"
#
# },
# {
# "title": "CJ대한통운, 군포지역 <b>어린이</b> 등하굣길 ‘노란발자국’ 부착",
# "originallink": "https://www.dnews.co.kr/uhtml/view.jsp?idxno=202109281127249540270",
# "link": "https://www.dnews.co.kr/uhtml/view.jsp?idxno=202109281127249540270",
# "description": "30개소에 정지선, <b>보호구역</b> 표지판과 함께 설치 CJ대한통운이 경기도 군포시 <b>어린이 보호구역</b> 횡단보도에 ‘노란 발자국’을 설치하며 <b>어린이</b>들을 위한 안전한 등하굣길 만들기에 나섰다. 28일 CJ대한통운에 따르면... ",
# "pubDate": "Tue, 28 Sep 2021 11:30:00 +0900"
#
# },
# {
# "title": "CJ대한통운, <b>어린이</b> 등하굣길 안전 책임진다",
# "originallink": "https://www.ebn.co.kr/news/view/1501921/?sc=Naver",
# "link": "https://www.ebn.co.kr/news/view/1501921/?sc=Naver",
# "description": "CJ대한통운은 굿네이버스와 함께 군포 지역 내 <b>어린이</b>집, 초등학교 등 <b>어린이 보호구역</b> 횡단보도 30개소에 교통사고 예방을 돕는 ‘노란 발자국’을 설치한다고 28일 밝혔다. 설치 작업은 다음달 중순까지 순차 진행될... ",
# "pubDate": "Tue, 28 Sep 2021 08:58:00 +0900"
#
# },
# {
# "title": "CJ대한통운, <b>어린이</b> 교통사고 예방 앞장선다…횡단보도 ‘노란발자국’ 설치",
# "originallink": "http://www.dt.co.kr/contents.html?article_no=2021092802109932031002&ref=naver",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=029&aid=0002698378",
# "description": "CJ대한통운은 경기도 군포시 <b>어린이 보호구역</b> 횡단보도에 '노란발자국'을 설치하고 <b>어린이</b>들을 위한 안전한 등하굣길 만들기에 나섰다고 28일 밝혔다. 이를위해 CJ대한통운은 굿네이버스와 함께 군포 지역 내 <b>어린이</b>집... ",
# "pubDate": "Tue, 28 Sep 2021 09:54:00 +0900"
#
# },
# {
# "title": "DB손해보험, <b>어린이</b> 교통안전 지원 협약 체결",
# "originallink": "http://www.etnews.com/20210927000147",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=030&aid=0002971654",
# "description": "DB손해보험(대표 김정남)은 초록우산<b>어린이</b>재단(회장 이제훈)과 <b>어린이보호구역</b> 교통안전을 위한 옐로카펫 설치와 소외계층 지원을 위한 사랑 나눔 봉사 협약을 체결했다고 27일 밝혔다. DB손해보험이 추진하는 옐로카펫... ",
# "pubDate": "Mon, 27 Sep 2021 13:49:00 +0900"
#
# },
# {
# "title": "금호타이어, 전국 초등학생 대상 '<b>어린이</b> 교통안전교육' 실시",
# "originallink": "http://www.businesskorea.co.kr/news/articleView.html?idxno=77505",
# "link": "http://www.businesskorea.co.kr/news/articleView.html?idxno=77505",
# "description": "금호타이어에서 제작한 워크북에는 안전한 보행법, <b>어린이 보호구역</b>에서 지켜야 할 안전수칙, 교통안전 표지판, 바퀴 달린 놀이기구의 안전한 이용법, 도전! 안전 골든벨(퀴즈), 내가 만드는 안전한 학교 가는 길... ",
# "pubDate": "Thu, 30 Sep 2021 08:51:00 +0900"
#
# },
# {
# "title": "교통안전지킴이, <b>어린이</b> 등하굣길 우리가 지킨다!",
# "originallink": "http://www.gukjenews.com/news/articleView.html?idxno=2317354",
# "link": "http://www.gukjenews.com/news/articleView.html?idxno=2317354",
# "description": "한편 <b>어린이 보호구역</b>내 교통사고 발생률이 줄이기 위해 △교통안전표지판 설치 △<b>보호구역</b> 노면 표시 △무인교통 단속장비 설치 △과속 방지턱 설치 △스마트 횡단보도 설치 등을 추진중이다.",
# "pubDate": "Tue, 28 Sep 2021 17:56:00 +0900"
#
# },
# {
# "title": "제주경찰청, <b>어린이</b> 교통안전 지도제작 공모전",
# "originallink": "https://news.bbsi.co.kr/news/articleView.html?idxno=3045567",
# "link": "https://news.bbsi.co.kr/news/articleView.html?idxno=3045567",
# "description": "제주경찰청 관계자는 &quot;이번 공모전을 계기로 운전자들은 <b>어린이 보호구역</b>은 절대적 교통안전확보 <b>구역</b>, <b>어린이</b>는 움직이는 빨간 신호등이라는 사실을 잊지 말고 안전운전을 해 달라&quot;고 당부했습니다. 한편, 최근... ",
# "pubDate": "Tue, 28 Sep 2021 15:32:00 +0900"
#
# },
# {
# "title": "박상준 메디컬아이피 대표, <b>어린이</b> 교통안전 챌린지 동참",
# "originallink": "http://news.mk.co.kr/newsRead.php?no=920151&year=2021",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=105&oid=009&aid=0004857047",
# "description": "<b>어린이</b> 교통안전 릴레이 챌린지는 행정안전부와 교육부 주최로 <b>어린이 보호구역</b> 내 사고 예방과 <b>어린이</b> 교통안전을 최우선으로 하는 운전 문화 정착을 위해 마련된 공익 캠페인이다. 박 대표는 '1(일)단 멈춤! 2(이)쪽... ",
# "pubDate": "Mon, 27 Sep 2021 18:29:00 +0900"
#
# },
# {
# "title": "&quot;영주 <b>어린이</b> 등하굣길, 우리가 지킨다&quot;",
# "originallink": "http://www.dkilbo.com/news/articleView.html?idxno=345261",
# "link": "http://www.dkilbo.com/news/articleView.html?idxno=345261",
# "description": "한편 영주시는 <b>어린이 보호구역</b>내 교통사고 발생률이 줄이기 위해 △교통안전표지판 설치 △<b>보호구역</b> 노면 표시 △무인교통 단속장비 설치 △과속 방지턱 설치 △스마트 횡단보도 설치 등을 추진중이며, 경찰서... ",
# "pubDate": "Tue, 28 Sep 2021 20:37:00 +0900"
#
# },
# {
# "title": "강동구, <b>어린이</b> 통학로 안전하게 지킨다",
# "originallink": "http://www.shinailbo.co.kr/news/articleView.html?idxno=1465724",
# "link": "http://www.shinailbo.co.kr/news/articleView.html?idxno=1465724",
# "description": "우선 ‘음성안내 보조장치’를 <b>어린이보호구역</b> 4개소 △강일초 △고일초(고덕유치원) △명덕초 △천동초에 설치해 무단횡단을 방지하고 안전한 보행을 유도한다. 음성안내를 통해 운전자와 보행자에게 도로 상황 및... ",
# "pubDate": "Thu, 30 Sep 2021 10:54:00 +0900"
#
# },
# {
# "title": "여수시 교통안전 캠페인, 안전속도 5030 &quot;<b>어린이</b> 안전 우리가 지켜요&quot;",
# "originallink": "http://www.sisamagazine.co.kr/news/articleView.html?idxno=404349",
# "link": "http://www.sisamagazine.co.kr/news/articleView.html?idxno=404349",
# "description": "여수시(시장 권오봉)는 지난 28일 미평초등학교 일대 <b>어린이 보호구역</b>에서 '안전속도 5030' 및 '속도를 줄이면 <b>어린이</b>가 보입니다'를 주제로 교통안전 캠페인을 진행했다고 밝혔다. 이날 캠페인에는 녹색어머니회를... ",
# "pubDate": "Wed, 29 Sep 2021 15:11:00 +0900"
#
# },
# {
# "title": "DB손보, <b>어린이</b> 교통안전 위한 '옐로카펫' 설치",
# "originallink": "https://news.mtn.co.kr/newscenter/news_viewer.mtn?gidx=2021092712542826585",
# "link": "https://news.mtn.co.kr/newscenter/news_viewer.mtn?gidx=2021092712542826585",
# "description": "사진 = DB손해보험DB손해보험은 지난 16일 초록우산<b>어린이</b>재단과 <b>어린이보호구역</b> 교통안전을 위한 ‘옐로카펫’설치 및 소외계층 지원을 위한 ‘사랑나눔봉사’협약을 체결했다고 27일 밝혔다.<b>어린이</b> 교통사고 예방을... ",
# "pubDate": "Mon, 27 Sep 2021 13:50:00 +0900"
#
# },
# {
# "title": "경기북부경찰청, <b>어린이</b> 안전을 위해 주민의견 경청",
# "originallink": "http://www.joongboo.com/news/articleView.html?idxno=363505140",
# "link": "http://www.joongboo.com/news/articleView.html?idxno=363505140",
# "description": "경기북부경찰청과 경기도북부자치경찰위원회는 <b>어린이보호구역</b> 내 <b>어린이</b>들의 안전을 위해 '도민과 함께하는 <b>어린이보호구역</b> 도로안전시설 개선'을 시행 중이라고 29일 밝혔다. 경찰은 자치경찰시대에 발맞춰 주민들의... ",
# "pubDate": "Wed, 29 Sep 2021 17:38:00 +0900"
#
# },
# {
# "title": "CJ대한통운, 군포 <b>어린이</b> 등하굣길에 '노란발자국'부착",
# "originallink": "http://www.100ssd.co.kr/news/articleView.html?idxno=80975",
# "link": "http://www.100ssd.co.kr/news/articleView.html?idxno=80975",
# "description": "CJ대한통운이 경기도 군포시 <b>어린이 보호구역</b> 횡단보도에 '노란 발자국'을 설치, <b>어린이</b>들을 위한 안전한 등하굣길 만들기에 나섰다. CJ대한통운이 굿네이버스와 함께 군포 지역 내 <b>어린이</b>집, 초등학교 등 <b>어린이</b>... ",
# "pubDate": "Tue, 28 Sep 2021 10:42:00 +0900"
#
# },
# {
# "title": "과천시, <b>어린이보호구역</b> 사거리에 LED바닥신호등 설치",
# "originallink": "http://www.incheonilbo.com/news/articleView.html?idxno=1114013",
# "link": "http://www.incheonilbo.com/news/articleView.html?idxno=1114013",
# "description": "▲ 과천시가 최근 교통사고 없는 안전한 보행환경 조성을 위해 문원초 <b>어린이보호구역</b> 인근 사거리 횡단보도에 LED바닥형 보행신호등을 설치했다./사진제공=과천시 과천시는 교통사고 없는 안전한 보행환경 조성을 위해... ",
# "pubDate": "Tue, 28 Sep 2021 14:32:00 +0900"
#
# },
# {
# "title": "CJ대한통운, <b>어린이</b> 등하굣길에 ‘노란발자국’ 부착…“횡단보도 앞에선 잠시...",
# "originallink": "https://www.dailian.co.kr/news/view/1036328/?sc=Naver",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=119&aid=0002533167",
# "description": "“횡단보도 건너기 전에는 잠시 멈춰요.” CJ대한통운이 경기도 군포시 <b>어린이 보호구역</b> 횡단보도에 ‘노란 발자국’을 설치하며 <b>어린이</b>들을 위한 안전한 등하굣길 만들기에 나섰다. CJ대한통운이 굿네이버스와 함께... ",
# "pubDate": "Tue, 28 Sep 2021 10:08:00 +0900"
#
# },
# {
# "title": "DB손해보험, <b>어린이</b> 교통안전·소외계층 지원 나서",
# "originallink": "http://www.dt.co.kr/contents.html?article_no=2021092702109963075002&ref=naver",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=029&aid=0002698169",
# "description": "초록우산<b>어린이</b>재단과 협약식 진행 초등학교 100여곳에 옐로카펫 설치 DB손해보험은 지난 16일 초록우산<b>어린이</b>재단과 <b>어린이보호구역</b> 교통안전을 위한 '옐로카펫 설치' 및 소외계층 지원을 위한 '사랑나눔봉사' 협약을... ",
# "pubDate": "Mon, 27 Sep 2021 10:36:00 +0900"
#
# },
# {
# "title": "CJ대한통운, 군포지역 <b>어린이</b> 보행 안내 ‘노란발자국’ 부착",
# "originallink": "https://www.news2day.co.kr/article/20210928500119",
# "link": "https://www.news2day.co.kr/article/20210928500119",
# "description": "‘노란 정지선’과 <b>어린이보호구역</b> 표지판도 설치 CJ대한통운이 굿네이버스와 함께 경기도 군포지역 <b>어린이</b>를 교통안전을 위한 ‘노란발자국’ 부착을 실시했다고 28일 밝혔다. CJ대한통운이 굿네이버스와 함께 <b>어린이</b>... ",
# "pubDate": "Tue, 28 Sep 2021 12:22:00 +0900"
#
# },
# {
# "title": "영주시 교통안전지킴이 &quot;<b>어린이</b> 등하굣길 우리가 지킨다&quot;",
# "originallink": "http://www.hidomin.com/news/articleView.html?idxno=464422",
# "link": "http://www.hidomin.com/news/articleView.html?idxno=464422",
# "description": "한편 시는 <b>어린이 보호구역</b>내 교통사고 발생률이 줄이기 위해 △교통안전표지판 설치 △<b>보호구역</b> 노면 표시 △무인교통 단속 장비 설치 △과속 방지턱 설치 △스마트 횡단보도 설치 등을 추진 중이며, 경찰서, 교육지원청... ",
# "pubDate": "Tue, 28 Sep 2021 15:50:00 +0900"
#
# },
# {
# "title": "DB손해보험, <b>어린이보호구역</b> 교통사고 예방 위해 '옐로카펫' 설치 지원",
# "originallink": "https://www.businesspost.co.kr/BP?command=article_view&num=251775",
# "link": "https://www.businesspost.co.kr/BP?command=article_view&num=251775",
# "description": "DB손해보험이 <b>어린이보호구역</b> 교통사고 예방과 소외계층 <b>어린이</b> 후원에 나섰다. DB손해보험은 초록우산<b>어린이</b>재단과 '옐로카펫' 설치 및 '사랑나눔봉사' 협약을 체결했다고 27일 밝혔다. 박기현 DB손해보험 전략기획팀장... ",
# "pubDate": "Mon, 27 Sep 2021 15:54:00 +0900"
#
# },
# {
# "title": "DB손보, <b>어린이</b> 교통안전 위한 협약 체결",
# "originallink": "http://www.shinailbo.co.kr/news/articleView.html?idxno=1464076",
# "link": "http://www.shinailbo.co.kr/news/articleView.html?idxno=1464076",
# "description": "DB손해보험이 지난 16일 초록우산<b>어린이</b>재단과 <b>어린이보호구역</b> 교통안전을 위한 '옐로카펫' 설치 및 소외계층 지원을 위한 협약을 체결했다고 27일 밝혔다. 옐로 카펫은 횡단보도 신호대기공간을 노란색으로 구획화해... ",
# "pubDate": "Mon, 27 Sep 2021 13:44:00 +0900"
#
# },
# {
# "title": "제주경찰청, <b>어린이</b> 교통안전 지도제작 공모전",
# "originallink": "http://www.headlinejeju.co.kr/news/articleView.html?idxno=463606",
# "link": "http://www.headlinejeju.co.kr/news/articleView.html?idxno=463606",
# "description": "한편, 올해 제주에서 <b>어린이보호구역</b> 내 교통사고는 지난해에 비해 50% 감소했으나 속도위반은 매년 증가하고 있는 것으로 나타났다. 경찰에 따르면 지난해 1월부터 8월까지 도내 <b>어린이보호구역</b>에서 발생한... ",
# "pubDate": "Tue, 28 Sep 2021 10:46:00 +0900"
#
# },
# {
# "title": "제주경찰 ‘<b>어린이</b> 교통안전 지도 제작’ 공모전 개최",
# "originallink": "https://view.asiae.co.kr/article/2021092809391994706",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=277&aid=0004974936",
# "description": "<b>어린이보호구역</b>(스쿨존) 내 <b>어린이</b> 교통사고를 예방하기 위해 시설개선과 현장단속, 각종 제도 및 정책도 추진하고 있다. <b>어린이보호구역</b> 내 교통사고 및 속도위반 등 법규위반행위는 끊이지 않고 있다. <b>어린이보호구역</b>... ",
# "pubDate": "Tue, 28 Sep 2021 09:37:00 +0900"
#
# },
# {
# "title": "CJ대한통운, <b>어린이</b> 등하굣길에 교통사고 예방 ‘노란발자국’ 부착",
# "originallink": "https://www.ksg.co.kr/news/main_newsView.jsp?pNum=131864",
# "link": "https://www.ksg.co.kr/news/main_newsView.jsp?pNum=131864",
# "description": "CJ대한통운은 지난 28일 굿네이버스와 함께 경기도 군포 지역 내 <b>어린이</b>집, 초등학교 등 <b>어린이 보호구역</b> 횡단보도 30개소에 교통사고 예방을 돕는 ‘노란 발자국’을 설치한다고 밝혔다. ‘노란 발자국’ 설치 작업은... ",
# "pubDate": "Wed, 29 Sep 2021 10:24:00 +0900"
#
# },
# {
# "title": "이소영, &quot;<b>어린이 보호구역</b>에 미인가 대안학교도 포함하는 길 열려&quot;",
# "originallink": "http://www.newsworker.co.kr/news/articleView.html?idxno=130783",
# "link": "http://www.newsworker.co.kr/news/articleView.html?idxno=130783",
# "description": "<b>어린이 보호구역</b> 지정대상에 미인가 대안학교를 포함하는 등 <b>보호구역</b> 지정대상이 확대돼 <b>어린이</b> 안전을 더욱 두텁게 <b>보호</b>할 수 있는 길이 열렸다. 국회 더불어민주당 이소영 의원(경기 의왕·과천)에 따르면, <b>어린이</b>... ",
# "pubDate": "Wed, 29 Sep 2021 11:08:00 +0900"
#
# },
# {
# "title": "강동구도시관리공단은, <b>어린이보호구역</b>내 주거지주차구획 일제 정비",
# "originallink": "https://www.siminilbo.co.kr/news/newsview.php?ncode=1065590871947452",
# "link": "https://www.siminilbo.co.kr/news/newsview.php?ncode=1065590871947452",
# "description": "서울 강동구도시관리공단은 <b>어린이보호구역</b>내 주거지주차구획을 일제 정비한다고 밝혔다. <b>어린이보호구역</b> 주통학로는『도로교통법』에 따라 노상주차장을 운영할 수 없다. 하지만 주택가 주차난 문제로 부득이하게... ",
# "pubDate": "Wed, 29 Sep 2021 17:42:00 +0900"
#
# },
# {
# "title": "CJ대한통운, 안전한 등하굣길 만들기 나섰다...<b>어린이 보호구역</b> 횡단보도에 '...",
# "originallink": "http://www.paxetv.com/news/articleView.html?idxno=127646",
# "link": "http://www.paxetv.com/news/articleView.html?idxno=127646",
# "description": "CJ대한통운이 굿네이버스와 함께 군포 지역 내 <b>어린이</b>집, 초등학교 등 <b>어린이 보호구역</b> 횡단보도 30개소에 교통사고 예방을 돕는 '노란 발자국'을 설치합니다. '노란 발자국' 설치 작업은 군포시청, 군포경찰서와의 협력을... ",
# "pubDate": "Tue, 28 Sep 2021 10:49:00 +0900"
#
# },
# {
# "title": "파주시, 초등학교 앞 <b>어린이보호구역</b> 내 CCTV 설치",
# "originallink": "https://www.dnews.co.kr/uhtml/view.jsp?idxno=202109270958417670891",
# "link": "https://www.dnews.co.kr/uhtml/view.jsp?idxno=202109270958417670891",
# "description": "불법 주·정차 단속 경기 파주시(시장 최종환)가 금촌초등학교, 능안초등학교 등 <b>어린이보호구역</b> 내에 불법 주·정차 단속 CCTV를 설치하고 27일부터 단속한다. 이는 <b>어린이보호구역</b> 내 불법 주·정차로 인한 <b>어린이</b>... ",
# "pubDate": "Mon, 27 Sep 2021 11:00:00 +0900"
#
# },
# {
# "title": "DB손해보험, 옐로카펫 100여개 설치...<b>어린이</b> 교통안전 및 소외계층 지원",
# "originallink": "https://daily.hankooki.com/lpage/finance/202109/dh20210927112834148330.htm?s_ref=nv",
# "link": "https://daily.hankooki.com/lpage/finance/202109/dh20210927112834148330.htm?s_ref=nv",
# "description": "“사회공헌활동 통해 고객 행복 기여와 기업의 사회적 책임 다할 것” DB손해보험은 지난 16일 초록우산<b>어린이</b>재단과 <b>어린이보호구역</b> 교통안전을 위한 ‘옐로카펫 설치’ 및 소외계층 지원을 위한 ‘사랑나눔봉사’... ",
# "pubDate": "Mon, 27 Sep 2021 11:30:00 +0900"
#
# },
# {
# "title": "강동구, <b>어린이보호구역</b> 과속단속카메라 확대 설치",
# "originallink": "https://www.ibabynews.com/news/articleView.html?idxno=98706",
# "link": "https://www.ibabynews.com/news/articleView.html?idxno=98706",
# "description": "강동구는 안전한 등·하굣길 환경 조성을 위해 2021년 하반기 관내 <b>어린이보호구역</b> 14개소에 과속단속카메라를 설치한다고 밝혔다. ⓒ강동구청 강동구(구청장 이정훈)는 안전한 등·하굣길 환경 조성을 위해 2021년 하반기... ",
# "pubDate": "Wed, 29 Sep 2021 10:38:00 +0900"
#
# },
# {
# "title": "DB손보, <b>어린이보호구역</b> 100곳에 옐로카펫 설치",
# "originallink": "https://www.fetv.co.kr/news/article.html?no=96919",
# "link": "https://www.fetv.co.kr/news/article.html?no=96919",
# "description": " DB손해보험은 초록우산<b>어린이</b>재단과 <b>어린이보호구역</b> 교통안전을 위한 옐로카펫 설치와 소외계층 지원을 위한 사랑나눔 봉사협약&lt;사진&gt;을 체결했다고 27일 밝혔다. DB손보가 추진하는 옐로카펫 설치 캠페인은 횡단보도... ",
# "pubDate": "Mon, 27 Sep 2021 16:32:00 +0900"
#
# },
# {
# "title": "aT 대전세종충남본부, <b>어린이</b> 교통안전 챌린지 동참",
# "originallink": "http://www.ccnnews.co.kr/news/articleView.html?idxno=232776",
# "link": "http://www.ccnnews.co.kr/news/articleView.html?idxno=232776",
# "description": "한국농수산식품유통공사 대전세종충남지역본부(aT, 본부장 배민식)는 <b>어린이 보호구역</b> 내 교통사고를 예방하고 <b>어린이 보호</b>를 위한 사회적 공감대 형성을 위해 '<b>어린이</b> 교통안전 릴레이 챌린지'에 동참했다고 29일... ",
# "pubDate": "Wed, 29 Sep 2021 11:54:00 +0900"
#
# },
# {
# "title": "(제주), 제주지역 <b>어린이</b> 교통사고 증가세",
# "originallink": "http://www.jibs.co.kr/news/articles/articlesDetail/17790?feed=na",
# "link": "http://www.jibs.co.kr/news/articles/articlesDetail/17790?feed=na",
# "description": "다만 <b>어린이 보호구역</b> 안에서의 사고는 올해 4건 발생에 4명이 다쳤고, 지난해 절반 수준으로 나타났습니다. 제주경찰청은 다음 달 말까지 초등학생들을 대상으로 교통안전 지도제작 공모전을 열고 <b>어린이</b> 눈높이에서... ",
# "pubDate": "Tue, 28 Sep 2021 17:29:00 +0900"
#
# },
# {
# "title": "CJ대한통운, 군포지역 <b>어린이</b> 등하굣길에 '노란발자국' 부착",
# "originallink": "http://www.koreastocknews.com/news/articleView.html?idxno=66940",
# "link": "http://www.koreastocknews.com/news/articleView.html?idxno=66940",
# "description": "CJ대한통운이 경기도 군포시 <b>어린이 보호구역</b> 횡단보도 30개소에 '노란 발자국'을 설치했다. 사진=CJ대한통운  CJ대한통운(000120)은 경기도 군포시 <b>어린이 보호구역</b> 횡단보도에 '노란 발자국'을 설치하며 <b>어린이</b>들을 위한... ",
# "pubDate": "Tue, 28 Sep 2021 15:43:00 +0900"
#
# },
# {
# "title": "CJ대한통운, <b>어린이</b> 등하굣길에 '노란발자국' 의미는?",
# "originallink": "http://www.sportsq.co.kr/news/articleView.html?idxno=432380",
# "link": "http://www.sportsq.co.kr/news/articleView.html?idxno=432380",
# "description": " &quot;횡단보도 건너기 전에는 잠시 멈춰요.&quot; CJ대한통운이 경기도 군포시 <b>어린이 보호구역</b> 횡단보도에 '노란 발자국'을 설치하며 <b>어린이</b>들을 위한 안전한 등하굣길 만들기에 나섰다. CJ대한통운은 28일 &quot;굿네이버스와 함께... ",
# "pubDate": "Tue, 28 Sep 2021 15:28:00 +0900"
#
# },
# {
# "title": "CJ대한통운, <b>어린이</b> 교통사고 예방...등하굣길 '노란발자국' 설치",
# "originallink": "http://www.lcnews.co.kr/news/articleView.html?idxno=24865",
# "link": "http://www.lcnews.co.kr/news/articleView.html?idxno=24865",
# "description": "CJ대한통운, <b>어린이</b> 등하굣길에 '노란발자국' 부착 (사진=대한통운)  CJ대한통운이 경기도 군포시 <b>어린이 보호구역</b> 횡단보도에 '노란 발자국'을 설치하며 <b>어린이</b>들을 위한 안전한 등하굣길 만들기에 나섰다. 28일... ",
# "pubDate": "Tue, 28 Sep 2021 10:57:00 +0900"
#
# },
# {
# "title": "인천서부경찰서, <b>어린이</b> 교통사고 예방 등굣길 교통안전 캠페인 실시",
# "originallink": "http://www.kmaeil.com/news/articleView.html?idxno=308451",
# "link": "http://www.kmaeil.com/news/articleView.html?idxno=308451",
# "description": "캠페인에 참여한 관계자는 &quot;현재 정문 앞 주정차로 인해 <b>어린이</b> 교통사고 위험이 높은데 10월 21일 부터는 <b>어린이보호구역</b> 내에선 원칙적으로 모든 차의 주정차가 금지되며, <b>어린이</b> 통학 차량도 허용된 곳에서만... ",
# "pubDate": "Thu, 30 Sep 2021 00:07:00 +0900"
#
# },
# {
# "title": "영등포구, 지역내 <b>어린이보호구역</b>내 노상주차장 전면 폐쇄",
# "originallink": "https://www.siminilbo.co.kr/news/newsview.php?ncode=1065594701064109",
# "link": "https://www.siminilbo.co.kr/news/newsview.php?ncode=1065594701064109",
# "description": "▲ 사진제공=영등포구청 서울 영등포구(구청장 채현일)는 올해 말까지 지역내 <b>어린이보호구역</b>(스쿨존)내 운영 중인 모든 노상주차장을 전면 폐쇄한다고 27일 밝혔다. 이는 <b>어린이보호구역</b>내 불법주정차된 차량이... ",
# "pubDate": "Mon, 27 Sep 2021 21:08:00 +0900"
#
# },
# {
# "title": "CJ대한통운, <b>어린이</b> 등하굣길 안전거리 유지 돕는 ‘노란발자국’ 부착 나서",
# "originallink": "http://www.thebigdata.co.kr/view.php?ud=202109281040111140d0a8833aad_23",
# "link": "http://www.thebigdata.co.kr/view.php?ud=202109281040111140d0a8833aad_23",
# "description": "CJ대한통운이 굿네이버스와 함께 경기도 군포시 <b>어린이 보호구역</b> 횡단보도에 ‘노란 발자국’을 설치하며 <b>어린이</b>들을 위한 안전한 등하굣길 만들기에 나선다고 28일 밝혔다. '노란발자국'은 <b>어린이</b>들이 신호대기 시... ",
# "pubDate": "Tue, 28 Sep 2021 11:01:00 +0900"
#
# },
# {
# "title": " CJ대한통운, 횡단보도앞 '잠깐 멈춤'...<b>어린이</b> 등하굣길에 '노란발자국' 부...",
# "originallink": "http://www.datasom.co.kr/news/articleView.html?idxno=117978",
# "link": "http://www.datasom.co.kr/news/articleView.html?idxno=117978",
# "description": "CJ대한통운 관계자들이 경기도 군포시 <b>어린이보호구역</b>에 노란발자국을 설치하고 있다. (사진=CJ대한통운) CJ대한통운이 굿네이버스와 함께 군포 지역 내 <b>어린이</b>집, 초등학교 등 <b>어린이 보호구역</b> 횡단보도 30개소에... ",
# "pubDate": "Tue, 28 Sep 2021 15:57:00 +0900"
#
# },
# {
# "title": "DB손해보험, <b>어린이보호구역</b> 교통안전 '옐로카펫' 설치",
# "originallink": "http://www.newspim.com/news/view/20210927000854",
# "link": "http://www.newspim.com/news/view/20210927000854",
# "description": " DB손해보험(대표 김정남)은 최근 초록우산<b>어린이</b>재단(회장 이제훈)과 <b>어린이보호구역</b> 교통안전을 위한 '옐로카펫'설치 및 소외계층 지원을 위한 '사랑나눔봉사'협약을 체결했다고 27일 밝혔다. <b>어린이</b> 교통사고... ",
# "pubDate": "Mon, 27 Sep 2021 16:16:00 +0900"
#
# },
# {
# "title": "미추2<b>구역</b> 학세권 아파트 '주안 센트럴팰리스' 조합원 모집 마감임박",
# "originallink": "http://www.sisamagazine.co.kr/news/articleView.html?idxno=404162",
# "link": "http://www.sisamagazine.co.kr/news/articleView.html?idxno=404162",
# "description": "<b>어린이보호구역</b> 15개 지역에 단속 카메라 29대를 설치해 안전한 통학로를 확보하고 <b>어린이보호구역</b> 안전운전 문화정착을 위해 최선을 다하고 있다. 또한 장애아전문 <b>어린이</b> 집인 국공립 두리 하나<b>어린이</b>집과... ",
# "pubDate": "Wed, 29 Sep 2021 09:01:00 +0900"
#
# },
# {
# "title": "DB손보, <b>어린이</b> 교통사고 예방 위해 '옐로카펫' 설치 등 협약 체결",
# "originallink": "http://www.fntimes.com/html/view.php?ud=202109272025065254b1587365b_18",
# "link": "http://www.fntimes.com/html/view.php?ud=202109272025065254b1587365b_18",
# "description": "DB손해보험은 지난 16일 초록우산<b>어린이</b>재단과 <b>어린이보호구역</b> 교통안전을 위한 ‘옐로카펫’ 설치 및 소외계층 지원을 위한 ‘사랑나눔봉사’ 협약을 체결했다고 27일 밝혔다. 옐로 카펫 설치 캠페인은 <b>어린이</b>... ",
# "pubDate": "Mon, 27 Sep 2021 20:26:00 +0900"
#
# },
# {
# "title": "[미래 신산업 허브, 인천] 통학길 안전 강화, 무인단속카메라 설치미래 주역 ...",
# "originallink": "https://www.joongang.co.kr/article/25010587",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=025&aid=0003138320",
# "description": "학교를 가리던 방음벽의 담쟁이 넝쿨을 제거하고 노란색으로 <b>어린이 보호 구역</b>을 표시했다. 운행 제한 속도를 시속 50km에서 30km로 하향 조정하고 불법 우회전을 막는 교통안전장치를 마련했다. 중구청과 협의해 경찰은... ",
# "pubDate": "Wed, 29 Sep 2021 00:05:00 +0900"
#
# },
# {
# "title": "CJ대한통운, <b>어린이</b> 등하굣길에 '노란발자국' 부착…&quot;횡단보도 앞에선 잠시 멈...",
# "originallink": "http://www.dailysmart.co.kr/news/articleView.html?idxno=50308",
# "link": "http://www.dailysmart.co.kr/news/articleView.html?idxno=50308",
# "description": "CJ대한통운이 경기도 군포시 <b>어린이보호구역</b>에 노란발자국을 설치하고 있다. 사진=CJ대한통운  &quot;횡단보도 건너기 전에는 잠시 멈춰요&quot; CJ대한통운이 경기도 군포시 <b>어린이 보호구역</b> 횡단보도에 '노란 발자국'을 설치하며... ",
# "pubDate": "Tue, 28 Sep 2021 09:57:00 +0900"
#
# },
# {
# "title": "파주시, 초등학교 앞 <b>어린이보호구역</b> 내 불법 주·정차 CCTV 설치",
# "originallink": "http://www.enewstoday.co.kr/news/articleView.html?idxno=1514453",
# "link": "http://www.enewstoday.co.kr/news/articleView.html?idxno=1514453",
# "description": " 파주시(시장 최종환)가 금촌초등학교, 능안초등학교 등 <b>어린이보호구역</b> 내에 불법 주·정차 단속 CCTV를 설치하고 27일부터 단속한다. 초등학교 앞 <b>어린이보호구역</b> 내 불법 주·정차 CCTV 설치. [사진=파주시] 이는... ",
# "pubDate": "Mon, 27 Sep 2021 10:15:00 +0900"
#
# },
# {
# "title": "이소영 의원 &quot;<b>어린이보호구역</b>에 미인가 대안학교 포함하는 길 열려&quot;",
# "originallink": "https://www.ibabynews.com/news/articleView.html?idxno=98698",
# "link": "https://www.ibabynews.com/news/articleView.html?idxno=98698",
# "description": "<b>어린이보호구역</b> 지정 대상에 미인가 대안학교를 포함할 수 있도록 하는 '도로교통법 개정안'이 통과됐다. ⓒ베이비뉴스 <b>어린이 보호구역</b> 지정 대상에 미인가 대안학교를 포함하는 등 <b>보호구역</b> 지정대상이 확대돼 <b>어린이</b>... ",
# "pubDate": "Wed, 29 Sep 2021 09:48:00 +0900"
#
# },
# {
# "title": "광주 <b>어린이보호구역</b> 사망사고 운전자, 항소심서 징역 2년 6개월 선고 받아.....",
# "originallink": "http://www.idsn.co.kr/news/articleView.html?idxno=55742",
# "link": "http://www.idsn.co.kr/news/articleView.html?idxno=55742",
# "description": "<b>어린이보호구역</b> 자료사진(매일안전신문 DB)  광주 <b>어린이보호구역</b>(스쿨존)에서 사망사로를 낸 운전자가 항소심에서 징역 2년 6개월을 선고 받았다. 이는 징역 5년을 선고한 원심을 파기하고 감형을 받은 것이다.... ",
# "pubDate": "Tue, 28 Sep 2021 17:05:00 +0900"
#
# },
# {
# "title": "&quot;횡단보도 앞에선 잠시 멈춰요&quot;...CJ대한통운, <b>어린이</b> 등하굣길 '노란발자국'...",
# "originallink": "http://www.newsquest.co.kr/news/articleView.html?idxno=89028",
# "link": "http://www.newsquest.co.kr/news/articleView.html?idxno=89028",
# "description": "CJ대한통운이 경기도 군포시 <b>어린이보호구역</b>에 노란발자국을 설치하고 있다. [CJ대한통운 제공]  CJ대한통운이 <b>어린이</b>들을 위해 안전한 등하굣길 만들기에 나섰다. CJ대한통운이 굿네이버스와 함께 군포 지역 내... ",
# "pubDate": "Tue, 28 Sep 2021 11:57:00 +0900"
#
# },
# {
# "title": "파주시, 초등학교 앞 <b>어린이보호구역</b> 내 불법 주·정차 CCTV 설치",
# "originallink": "http://www.kmaeil.com/news/articleView.html?idxno=307558",
# "link": "http://www.kmaeil.com/news/articleView.html?idxno=307558",
# "description": "파주시가 금촌초등학교, 능안초등학교 등 <b>어린이보호구역</b> 내에 불법 주·정차 단속 CCTV를 설치하고 27일부터 단속한다. (사진=파주시) 파주시가 금촌초등학교, 능안초등학교 등 <b>어린이보호구역</b> 내에 불법 주·정차 단속... ",
# "pubDate": "Mon, 27 Sep 2021 09:55:00 +0900"
#
# },
# {
# "title": "DB손보, 초록우산<b>어린이</b>재단과 ‘사랑나눔봉사’ 협약 맺어",
# "originallink": "http://www.insnews.co.kr/design_php/news_view.php?num=67024&firstsec=1&secondsec=13",
# "link": "http://www.insnews.co.kr/design_php/news_view.php?num=67024&firstsec=1&secondsec=13",
# "description": "DB손해보험은 지난 16일 초록우산<b>어린이</b>재단과 <b>어린이보호구역</b> 교통안전을 위한 ‘옐로카펫’ 설치 및 소외계층 지원을 위한 ‘사랑나눔봉사’ 협약을 맺었다고 27일 밝혔다. ‘옐로카펫’ 캠페인은 횡단보도 신호대기... ",
# "pubDate": "Mon, 27 Sep 2021 11:50:00 +0900"
#
# },
# {
# "title": "DB손보, <b>어린이</b> 교통안전 및 소외계층 지원 위한 협약 체결",
# "originallink": "http://www.fins.co.kr/news/articleView.html?idxno=91471",
# "link": "http://www.fins.co.kr/news/articleView.html?idxno=91471",
# "description": "DB손해보험이 지난 16일 초록우산<b>어린이</b>재단과 <b>어린이보호구역</b> 교통안전을 위한 '옐로카펫'설치 및 소외계층 지원을 위한 '사랑나눔봉사'협약을 체결했다고 밝혔다. DB손보가 추진하고 있는 '옐로 카펫' 설치 캠페인은... ",
# "pubDate": "Mon, 27 Sep 2021 16:27:00 +0900"
#
# },
# {
# "title": "DB손보, <b>어린이</b> 교통안전과 소외계층 지원 위한 '사랑나눔봉사' 협약 체결",
# "originallink": "https://www.ekn.kr/web/view.php?key=20210927010004037",
# "link": "https://www.ekn.kr/web/view.php?key=20210927010004037",
# "description": "DB손해보험은 지난 16일 초록우산<b>어린이</b>재단과 <b>어린이보호구역</b> 교통안전을 위한 ‘옐로카펫’ 설치와 소외계층 지원을 위한 ‘사랑나눔봉사’ 협약을 체결했다고 27일 밝혔다. <b>어린이</b> 교통사고 예방을 위해... ",
# "pubDate": "Mon, 27 Sep 2021 10:54:00 +0900"
#
# }
# ]
# }
# {
# "lastBuildDate": "Thu, 30 Sep 2021 14:17:54 +0900",
# "total": 104777,
# "start": 101,
# "display": 100,
# "items": [
# {
# "title": "DB손해보험, <b>어린이</b> 교통안전 및 소외계층 지원을 위한 협약 체결",
# "originallink": "http://www.datanews.co.kr/news/article.html?no=115502",
# "link": "http://www.datanews.co.kr/news/article.html?no=115502",
# "description": "DB손해보험(대표 김정남)은 초록우산<b>어린이</b>재단(회장 이제훈)과 <b>어린이보호구역</b> 교통안전을 위한 옐로카펫 설치 및 소외계층 지원을 위한 '사랑나눔봉사 협약'을 체결했다고 27일 밝혔다. <b>어린이</b> 교통사고 예방을 위해... ",
# "pubDate": "Mon, 27 Sep 2021 10:04:00 +0900"
#
# },
# {
# "title": "이소영 &quot;<b>어린이 보호구역</b> 지정에 미인가 대안학교 포함하는 길 열려&quot;",
# "originallink": "http://www.iminju.net/news/articleView.html?idxno=75494",
# "link": "http://www.iminju.net/news/articleView.html?idxno=75494",
# "description": "ⓒ 뉴시스 <b>어린이 보호구역</b> 지정대상에 미인가 대안학교도 포함돼 <b>어린이</b> 안전을 더 두텁게 <b>보호</b>할 수 있게 됐다. 더불어민주당 이소영 의원이 발의한 '도로교통법 개정안'이 28일 국회 본회의를 통과하면서 <b>어린이</b>... ",
# "pubDate": "Tue, 28 Sep 2021 18:07:00 +0900"
#
# },
# {
# "title": "DB손해보험, <b>어린이</b> 교통안전 및 소외계층 지원 위해 팔 걷어",
# "originallink": "http://www.weeklytoday.com/news/articleView.html?idxno=407816",
# "link": "http://www.weeklytoday.com/news/articleView.html?idxno=407816",
# "description": "[사진=DB손해보험] DB손해보험(대표 김정남)이 지난 16일 초록우산<b>어린이</b>재단(회장 이제훈)과 <b>어린이보호구역</b> 교통안전을 위한 '옐로카펫' 설치 및 소외계층 지원을 위한 '사랑나눔봉사' 협약을 체결했다고 밝혔다.... ",
# "pubDate": "Mon, 27 Sep 2021 13:04:00 +0900"
#
# },
# {
# "title": "(제주), 제주지역 <b>어린이</b> 교통사고 증가세",
# "originallink": "http://www.jibs.co.kr/news/replay/viewNewsReplayDetail/2021092820533703806?feed=na",
# "link": "http://www.jibs.co.kr/news/replay/viewNewsReplayDetail/2021092820533703806?feed=na",
# "description": "발생한 <b>어린이</b> 교통사고는 170건으로 지난해보다 7% 늘었습니다. 다친 <b>어린이</b>도 217명으로 8% 증가했습니다. 반면 <b>어린이 보호구역</b> 안에서 발생한 교통사고는 4건으로 지난해 절반으로 줄었습니다. JIBS 이효형() 기자",
# "pubDate": "Tue, 28 Sep 2021 21:11:00 +0900"
#
# },
# {
# "title": "메디컬아이피 박상준 대표, '<b>어린이</b> 교통안전 챌린지' 동참",
# "originallink": "http://www.bosa.co.kr/news/articleView.html?idxno=2158952",
# "link": "http://www.bosa.co.kr/news/articleView.html?idxno=2158952",
# "description": "'<b>어린이</b> 교통안전 릴레이 챌린지'는 행정안전부와 교육부 주최로 <b>어린이 보호구역</b> 내 사고 예방과 <b>어린이</b> 교통안전을 최우선으로 하는 운전 문화 정착을 위해 마련된 공익 캠페인이다. 박상준 대표는 '1(일)단 멈춤! 2(이)... ",
# "pubDate": "Mon, 27 Sep 2021 10:22:00 +0900"
#
# },
# {
# "title": "메디컬아이피 박상준 대표, '<b>어린이</b> 교통안전 챌린지' 동참",
# "originallink": "http://www.docdocdoc.co.kr/news/articleView.html?idxno=2014920",
# "link": "http://www.docdocdoc.co.kr/news/articleView.html?idxno=2014920",
# "description": "'<b>어린이</b> 교통안전 릴레이 챌린지'는 행정안전부와 교육부 주최로 <b>어린이 보호구역</b> 내 사고 예방과 <b>어린이</b> 교통안전을 최우선으로 하는 운전 문화 정착을 위해 마련된 공익 캠페인이다. 박상준 대표는 '1(일)단... ",
# "pubDate": "Mon, 27 Sep 2021 18:04:00 +0900"
#
# },
# {
# "title": "DB손보, <b>어린이</b> 교통안전 위한 '옐로카펫' 설치 협약 체결",
# "originallink": "https://www.ebn.co.kr/news/view/1501746/?sc=Naver",
# "link": "https://www.ebn.co.kr/news/view/1501746/?sc=Naver",
# "description": "DB손해보험은 지난 16일 초록우산<b>어린이</b>재단과 <b>어린이보호구역</b> 교통안전을 위한 ‘옐로카펫’ 설치 및 소외계층 지원을 위한 ‘사랑나눔봉사’ 협약을 체결했다고 27일 밝혔다. <b>어린이</b> 교통사고 예방을 위해 DB손보가... ",
# "pubDate": "Mon, 27 Sep 2021 09:06:00 +0900"
#
# },
# {
# "title": "파주시, 초등학교 앞 <b>어린이보호구역</b> 내 불법 주·정차 CCTV 설치·단속",
# "originallink": "http://www.weeklytoday.com/news/articleView.html?idxno=407855",
# "link": "http://www.weeklytoday.com/news/articleView.html?idxno=407855",
# "description": "▲ 파주시, 초등학교 앞 <b>어린이보호구역</b> 내 불법 주·정차 CCTV 설치·단속 파주시가 금촌초등학교, 능안초등학교 등 <b>어린이보호구역</b> 내에 불법 주·정차 단속 CCTV를 설치하고 27일부터 단속한다. 이는 <b>어린이보호구역</b> 내... ",
# "pubDate": "Mon, 27 Sep 2021 10:24:00 +0900"
#
# },
# {
# "title": "광주·전남 <b>어린이보호구역</b> 과속 적발 4년새 '껑충'",
# "originallink": "http://www.newsis.com/view/?id=NISX20210924_0001592231&cID=10809&pID=10800",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=003&aid=0010734999",
# "description": "기사내용 요약광주 2017년 4114건→2020년 2만8607건, 약7배 급증 전남도 최근 4년 사이 5배 늘어…단속 장비 대폭 확충 광주·전남 지역 <b>어린이보호구역</b>(스쿨존) 속도위반 적발 건 수가 최근 4년 사이 큰 폭으로... ",
# "pubDate": "Fri, 24 Sep 2021 13:59:00 +0900"
#
# },
# {
# "title": "파주시, 초등학교 앞 <b>어린이보호구역</b>...불법 주·정차 CCTV 설치",
# "originallink": "http://www.gukjenews.com/news/articleView.html?idxno=2316088",
# "link": "http://www.gukjenews.com/news/articleView.html?idxno=2316088",
# "description": "파주시, 초등학교 앞 <b>어린이보호구역</b>...불법 주·정차 CCTV 설치.(사진제공.파주시)  이운안 기자 = 파주시(시장 최종환)가 금촌초등학교, 능안초등학교 등 <b>어린이보호구역</b> 내에 불법 주·정차 단속 CCTV를... ",
# "pubDate": "Mon, 27 Sep 2021 11:56:00 +0900"
#
# },
# {
# "title": "DB손해보험, <b>어린이</b> 교통안전 위해 횡단보도 '옐로카펫' 설치 나서",
# "originallink": "http://www.enewstoday.co.kr/news/articleView.html?idxno=1514393",
# "link": "http://www.enewstoday.co.kr/news/articleView.html?idxno=1514393",
# "description": "[사진=DB손해보험] DB손해보험이 <b>어린이보호구역</b> 교통안전을 위해 전국 100여개 초등학교의 횡단보도 옐로카펫을 설치·보수한다. 27일 DB손해보험이 초록우산<b>어린이</b>재단과 옐로카펫 설치 및 소외계층 지원을 위한... ",
# "pubDate": "Mon, 27 Sep 2021 09:15:00 +0900"
#
# },
# {
# "title": "메디컬아이피 박상준 대표, ‘<b>어린이</b> 교통안전 챌린지’ 동참",
# "originallink": "http://www.bokuennews.com/news/article.html?no=208225",
# "link": "http://www.bokuennews.com/news/article.html?no=208225",
# "description": "‘<b>어린이</b> 교통안전 릴레이 챌린지’는 행정안전부와 교육부 주최로 <b>어린이 보호구역</b> 내 사고 예방과 <b>어린이</b> 교통안전을 최우선으로 하는 운전 문화 정착을 위해 마련된 공익 캠페인이다. 박상준 대표는 ‘1(일)단... ",
# "pubDate": "Mon, 27 Sep 2021 10:38:00 +0900"
#
# },
# {
# "title": "광주 서구, 미세먼지 안심 <b>어린이</b> 통학로 조성",
# "originallink": "http://www.newsmaker.or.kr/news/articleView.html?idxno=122457",
# "link": "http://www.newsmaker.or.kr/news/articleView.html?idxno=122457",
# "description": "광주 서구(구청장 서대석)가 화개초등학교와 마개초등학교 앞 등 금호2동 주요 <b>어린이보호구역</b> 울타리 3곳에 대기오염물질을 정화하는 미세먼지 흡착필터를 설치했다. 자동차 등에서 배출하고 있는 미세먼지를 비롯한... ",
# "pubDate": "Mon, 27 Sep 2021 06:36:00 +0900"
#
# },
# {
# "title": "광주 서구, 미세먼지 안심 <b>어린이</b> 통학로 조성",
# "originallink": "http://www.sisamagazine.co.kr/news/articleView.html?idxno=403925",
# "link": "http://www.sisamagazine.co.kr/news/articleView.html?idxno=403925",
# "description": "광주 서구(구청장 서대석)가 화개초등학교와 마개초등학교 앞 등 금호2동 주요 <b>어린이보호구역</b> 울타리 3곳에 대기오염물질을 정화하는 미세먼지 흡착필터를 설치했다. 광주 서구, 미세먼지 안심 <b>어린이</b> 통학로 조성(사진... ",
# "pubDate": "Mon, 27 Sep 2021 20:29:00 +0900"
#
# },
# {
# "title": "DB손해보험, <b>어린이</b> 교통안전 및 소외계층 지원 나서",
# "originallink": "http://www.paxetv.com/news/articleView.html?idxno=127512",
# "link": "http://www.paxetv.com/news/articleView.html?idxno=127512",
# ...
# "pubDate": "Tue, 20 Jul 2021 12:02:00 +0900"
#
# },
# {
# "title": "김철민 의원, 더 안전한 <b>어린이 보호구역</b> 위한 '도로교통법' 대표발의",
# "originallink": "http://www.sisamagazine.co.kr/news/articleView.html?idxno=365403",
# "link": "http://www.sisamagazine.co.kr/news/articleView.html?idxno=365403",
# "description": "김철민 의원 더불어민주당 김철민 의원(국회 교육위원회, 안산 상록을)은 20일(화), <b>어린이 보호구역</b> 내 횡단보도에 보행자 신호기 설치를 확대하는 내용의 &lt;도로교통법&gt; 개정안을 대표발의했다고 밝혔다. 현행법에 따르면... ",
# "pubDate": "Tue, 20 Jul 2021 13:26:00 +0900"
#
# },
# {
# "title": "김철민 의원, 더 안전한 '<b>어린이 보호구역</b>' 위한 '도로교통법' 대표 발의",
# "originallink": "http://www.incheonilbo.com/news/articleView.html?idxno=1105850",
# "link": "http://www.incheonilbo.com/news/articleView.html?idxno=1105850",
# "description": "▲ 더불어민주당 김철민 국회의원 더불어민주당 김철민 의원(경기 안산상록을)은 20일 <b>어린이 보호구역</b> 내 횡단보도에 보행자 신호기 설치를 확대하는 내용의 '도로교통법' 개정안을 대표 발의했다. 개정안은 <b>어린이</b>... ",
# "pubDate": "Tue, 20 Jul 2021 13:48:00 +0900"
#
# },
# {
# "title": "김철민 의원, 더 안전한 ‘<b>어린이 보호구역</b>’ 위한 '도로교통법' 대표발의",
# "originallink": "http://www.shinailbo.co.kr/news/articleView.html?idxno=1438507",
# "link": "http://www.shinailbo.co.kr/news/articleView.html?idxno=1438507",
# "description": "더불어민주당 김철민 의원(국회 교육위원회, 안산 상록을)은 20일 <b>어린이 보호구역</b> 내 횡단보도에 보행자 신호기 설치를 확대하는 내용의 '도로교통법' 개정안을 대표발의했다고 밝혔다. 현행법에 따르면 <b>어린이 보호구역</b>... ",
# "pubDate": "Tue, 20 Jul 2021 17:50:00 +0900"
#
# },
# {
# "title": "김철민 의원, 더 안전한 '<b>어린이 보호구역</b>' 위한 '도로교통법' 대표발의",
# "originallink": "http://www.gukjenews.com/news/articleView.html?idxno=2271017",
# "link": "http://www.gukjenews.com/news/articleView.html?idxno=2271017",
# "description": "사진=국제뉴스 DB 더불어민주당 김철민 의원(국회 교육위원회, 안산 상록을)은 20일 <b>어린이 보호구역</b> 내 횡단보도에 보행자 신호기 설치를 확대하는 내용의 '도로교통법'개정안을 대표 발의 했다. 현행법에 따르면 <b>어린이</b>... ",
# "pubDate": "Tue, 20 Jul 2021 22:48:00 +0900"
#
# },
# {
# "title": "김철민, 더 안전한 <b>어린이 보호구역</b> 만드는 '도로교통법 개정안' 발의",
# "originallink": "http://www.joongboo.com/news/articleView.html?idxno=363495382",
# "link": "http://www.joongboo.com/news/articleView.html?idxno=363495382",
# "description": "국회 교육위원회 소속인 김철민 더불어민주당 의원(안산상록을)은 20일 <b>어린이 보호구역</b> 내 횡단보도에 보행자 신호기 설치를 확대하는 내용의 '도로교통법 개정안'을 발의했다고 밝혔다. 개정안은 <b>어린이 보호구역</b> 내... ",
# "pubDate": "Tue, 20 Jul 2021 19:02:00 +0900"
#
# },
# {
# "title": "與김철민 “<b>어린이 보호구역</b> 내 신호등 확대”…법안 대표발의",
# "originallink": "http://news.heraldcorp.com/view.php?ud=20210720000864",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=100&oid=016&aid=0001864035",
# "description": "김철민 더불어민주당 의원은 20일 <b>어린이 보호구역</b> 내 횡단보도에 보행자 신호기 설치를 늘리는 내용의 도로교통법 개정안을 대표발의했다고 밝혔다. 현행법은 <b>어린이 보호구역</b> 내 도로에 우선적으로 설치하도록 하는... ",
# "pubDate": "Tue, 20 Jul 2021 16:03:00 +0900"
#
# },
# {
# "title": "김철민 의원, 더 안전한 <b>어린이 보호구역</b> 만들기 '도로교통법' 대표발의",
# "originallink": "http://www.kihoilbo.co.kr/news/articleView.html?idxno=938117",
# "link": "http://www.kihoilbo.co.kr/news/articleView.html?idxno=938117",
# "description": "기호일보, KIHOILBO 더불어민주당 김철민(국회 교육위원회, 안산 상록을) 의원은 20일 <b>어린이 보호구역</b> 내 횡단보도에 보행자 신호기 설치를 확대하는 내용의 &lt;도로교통법&gt; 개정안을 대표발의했다고 밝혔다. 현행법에 따르면... ",
# "pubDate": "Tue, 20 Jul 2021 16:02:00 +0900"
#
# },
# {
# "title": "김철민 의원 &quot;<b>어린이 보호구역</b> 내 횡단보도에 신호기 설치 확대를&quot;",
# "originallink": "http://www.kyeongin.com/main/view.php?key=20210720010003743",
# "link": "http://www.kyeongin.com/main/view.php?key=20210720010003743",
# "description": "김철민 의원 더불어민주당 김철민(안산상록을) 의원은 20일 <b>어린이 보호구역</b> 내 횡단보도에 보행자 신호기 설치를 확대하는 '도로교통법 개정안'을 발의했다.현행법은 <b>어린이 보호구역</b> 내 도로에는 무인 단속용 장비와 함께... ",
# "pubDate": "Tue, 20 Jul 2021 15:48:00 +0900"
#
# },
# {
# "title": "구리시,5개 초등학교(<b>어린이보호구역</b> 내) 횡단보도 옐로카펫 5개소,‘노란발자...",
# "originallink": "http://www.viva100.com/main/view.php?key=20210720010004743",
# "link": "http://www.viva100.com/main/view.php?key=20210720010004743",
# "description": "구리시,5개 초등학교(<b>어린이보호구역</b> 내) 횡단보도 옐로카펫 5개소,‘노란발자국’3개소설치 경기 구리시는 관내 5개 초등학교(<b>어린이보호구역</b> 내) 인근 횡단보도 주변에 옐로카펫 5개소, ‘노란발자국’ 3개소를 설치... ",
# "pubDate": "Tue, 20 Jul 2021 09:04:00 +0900"
#
# },
# {
# "title": "증평군, <b>어린이보호구역</b> 교통안전도 도내 1위 기록",
# "originallink": "http://www.breaknews.com/821744",
# "link": "http://www.breaknews.com/821744",
# "description": "증평군이 충북지역에서 <b>어린이보호구역</b>의 교통 환경이 가장 안전한 것으로 나타났다. 지난 15일 충북경찰청이 발표한 ‘<b>어린이보호구역</b>별 교통환경 위험도’평가... ",
# "pubDate": "Mon, 19 Jul 2021 23:36:00 +0900"
#
# },
# {
# "title": "강화되는 스쿨존 규제…<b>어린이보호구역</b> 사고 대비하려면?",
# "originallink": "https://economist.co.kr/2021/07/22/finance/insurance/20210722155000273.html",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=101&oid=243&aid=0000014689",
# "description": "<b>어린이보호구역</b>(스쿨존) 사고를 줄이기 위한 정부의 규제가 점차 강화되면서 해당 규정에 대한 운전자들의 관심이 높아지고 있다. 행정안전부는 지난 5월 11일부터 개정 도로교통법 시행령에 따라 <b>어린이보호구역</b> 내 주... ",
# "pubDate": "Thu, 22 Jul 2021 15:50:00 +0900"
#
# },
# {
# "title": "<b>어린이보호구역</b>에 시속 60㎞ 속도제한… 동방초등학교 등하교 학생들 위험 노...",
# "originallink": "http://www.kbsm.net/default/index_view_page.php?idx=318029&part_idx=320",
# "link": "http://www.kbsm.net/default/index_view_page.php?idx=318029&part_idx=320",
# "description": "정부의 안전속도 5030정책 도입으로 도심지역뿐만 아니라 자동차 전용도로를 제외한 국도 전 지역의 차량 제한속도가 점차 하향될 것으로 전망되는 가운데 경주시 월성동 동방초등학교 앞 국도7호선은 <b>어린이보호구역</b>임... ",
# "pubDate": "Mon, 19 Jul 2021 16:34:00 +0900"
#
# },
# {
# "title": "양산시, <b>어린이보호구역</b> 내 무인교통단속 장비 대폭 확충",
# "originallink": "http://www.busan.com/view/busan/view.php?code=2021071910144508031",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=082&aid=0001107685",
# "description": "<b>어린이</b> 보행 안전 확보를 위해 <b>어린이보호구역</b>을 중심으로 무인교통단속 장비 확충에 나선 양산시. 양산시 제공 경남 양산시는 <b>어린이</b> 보행 안전 확보를 위해 <b>어린이보호구역</b>을 중심으로 무인교통단속 장비를 대폭... ",
# "pubDate": "Mon, 19 Jul 2021 10:16:00 +0900"
#
# },
# {
# "title": "증평군, <b>어린이보호구역</b> 교통안전도 도내 1위 차지",
# "originallink": "http://www.gukjenews.com/news/articleView.html?idxno=2269322",
# "link": "http://www.gukjenews.com/news/articleView.html?idxno=2269322",
# "description": "<b>어린이보호구역</b> 모습.(제공=증평군청) 충북 증평군이 충북지역에서 <b>어린이보호구역</b>의 교통 환경이 가장 안전한 것으로 나타났다. 지난 15일 충북경찰청이 발표한 '<b>어린이보호구역</b>별 교통환경 위험도' 평가 결과에서... ",
# "pubDate": "Mon, 19 Jul 2021 08:26:00 +0900"
#
# },
# {
# "title": "증평 <b>어린이보호구역</b>, 충북서 가장 안전",
# "originallink": "http://www.newsis.com/view/?id=NISX20210719_0001517472&cID=10806&pID=10800",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=003&aid=0010614412",
# "description": "충북 증평군의 <b>어린이보호구역</b>이 가장 안전한 것으로 나타났다. 19일 증평군에 따르면 충북경찰청이 최근 발표한 ‘<b>어린이보호구역</b>별 교통환경 위험도’ 평가 결과 증평군은 83.8점을 얻었다. 충북 11개 시·군 가운데... ",
# "pubDate": "Mon, 19 Jul 2021 09:39:00 +0900"
#
# },
# {
# "title": "증평군, <b>어린이보호구역</b> 교통안전도 충북 1위",
# "originallink": "http://www.chungnamilbo.co.kr/news/articleView.html?idxno=613578",
# "link": "http://www.chungnamilbo.co.kr/news/articleView.html?idxno=613578",
# "description": "증평군, <b>어린이보호구역</b> 정비(사진=증평군)   충북 증평군이 충북지역에서 <b>어린이보호구역</b>의 교통 환경이 가장 안전한 것으로 나타났다. 지난 15일 충북경찰청이 발표한'<b>어린이보호구역</b>별 교통환경 위험도'평가... ",
# "pubDate": "Mon, 19 Jul 2021 09:52:00 +0900"
#
# },
# {
# "title": "충북서 가장 안전한 <b>어린이보호구역</b>은?…<b>어린이</b>들 생각한 증평의 ‘안전한 통...",
# "originallink": "https://www.khan.co.kr/local/Chungbuk/article/202107191556001",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=032&aid=0003086399",
# "description": "증평군의 <b>어린이보호구역</b>이 충북지역에서 가장 안전한 것으로 나타났다. 증평군은 지난 15일 충북경찰청이 발표한 ‘<b>어린이보호구역</b>별 교통환경 위험도’평가에서 83.8점을 기록했다고 19일 밝혔다. 충북 11개 시·군 중... ",
# "pubDate": "Mon, 19 Jul 2021 15:57:00 +0900"
#
# },
# {
# "title": "증평군, <b>어린이보호구역</b> 교통안전도 도내 1위",
# "originallink": "http://www.bzeronews.com/news/articleView.html?idxno=483295",
# "link": "http://www.bzeronews.com/news/articleView.html?idxno=483295",
# "description": "증평군이 충북지역에서 <b>어린이보호구역</b>의 교통 환경이 가장 안전한 것으로 나타났다. 지난 15일 충북경찰청이 발표한'<b>어린이보호구역</b>별 교통환경 위험도'평가 결과에서 증평군은 83.8점으로 도내에서 유일하게 80점... ",
# "pubDate": "Mon, 19 Jul 2021 17:06:00 +0900"
#
# },
# {
# "title": "증평군, <b>어린이보호구역</b> 관리 도내 최고",
# "originallink": "http://www.dynews.co.kr/news/articleView.html?idxno=638192",
# "link": "http://www.dynews.co.kr/news/articleView.html?idxno=638192",
# "description": "［동양일보 김진식 기자］증평군이 충북도내 <b>어린이보호구역</b> 중 교통 환경이 가장 안전한 것으로 나타났다. 지난 15일 충북경찰청이 발표에 따르면'<b>어린이보호구역</b>별 교통환경 위험도'평가 결과에서 증평군은 83.... ",
# "pubDate": "Mon, 19 Jul 2021 12:00:00 +0900"
#
# },
# {
# "title": "증평군, <b>어린이보호구역</b> 교통안전도 도내 으뜸",
# "originallink": "http://www.ggilbo.com/news/articleView.html?idxno=859111",
# "link": "http://www.ggilbo.com/news/articleView.html?idxno=859111",
# "description": "증평지역 <b>어린이보호구역</b>의 교통 환경이 충북에서 가장 안전한 것으로 나타났다. 사진은 삼보초 앞 도로 <b>어린이 보호구역</b> 모습. 증평군 제공 증평군이 충북지역에서 <b>어린이보호구역</b>의 교통 환경이 가장 안전한 것으로... ",
# "pubDate": "Mon, 19 Jul 2021 11:22:00 +0900"
#
# },
# {
# "title": "증평, <b>어린이보호구역</b> 교통안전도 '1위'",
# "originallink": "https://www.cctoday.co.kr/news/articleView.html?idxno=2146345",
# "link": "https://www.cctoday.co.kr/news/articleView.html?idxno=2146345",
# "description": "증평군 제공[충청투데이 ] 증평군이 충북에서 <b>어린이보호구역</b> 교통 환경이 가장 안전한 것으로 나타났다.19일 군에 따르면 충북경찰청이 지난 15일 발표한 '<b>어린이보호구역</b>별 교통환경 위험도' 평가 결과에서 군이 83.... ",
# "pubDate": "Mon, 19 Jul 2021 19:44:00 +0900"
#
# },
# {
# "title": "증평군, <b>어린이보호구역</b> 교통안전도 도내 1위",
# "originallink": "https://www.inews365.com/news/article.html?no=674926",
# "link": "https://www.inews365.com/news/article.html?no=674926",
# "description": "［충북일보］ 증평군이 충북지역에서 <b>어린이보호구역</b>의 교통 환경이 가장 안전한 것으로 나타났다. 지난 15일 충북경찰청이 발표한 '<b>어린이보호구역</b>별 교통환경 위험도'평가 결과 증평군은 83.8점으로 도내에서... ",
# "pubDate": "Mon, 19 Jul 2021 13:14:00 +0900"
#
# },
# {
# "title": "증평군 <b>어린이보호구역</b> 교통안전도 '충북 1위'",
# "originallink": "http://www.newspim.com/news/view/20210719000622",
# "link": "http://www.newspim.com/news/view/20210719000622",
# "description": "증평군이 충북에서 <b>어린이보호구역</b>의 교통 환경이 가장 안전한 것으로 나타났다. 19일 증평군에 따르면 충북경찰청이 발표한 '<b>어린이보호구역</b>별 교통환경 위험도'평가 결과 군은 83.8점으로 도내에서 유일하게 80점... ",
# "pubDate": "Mon, 19 Jul 2021 13:14:00 +0900"
#
# },
# {
# "title": "양산시 <b>어린이보호구역</b> 31곳, 무인교통단속장비 설치",
# "originallink": "http://www.gnnews.co.kr/news/articleView.html?idxno=479435",
# "link": "http://www.gnnews.co.kr/news/articleView.html?idxno=479435",
# "description": "양산시가 <b>어린이보호구역</b> 내 무인교통단속 장비 설치를 대폭 확대한다. 시는 <b>어린이</b> 보행안전 확보를 위해 총 19억4400만원(국비 9억5600만원, 교육부 3200만원, 시비 9억5600만원)을 투입해 무인교통단속 장비를... ",
# "pubDate": "Wed, 21 Jul 2021 21:04:00 +0900"
#
# },
# {
# "title": "온양5동 주민자치위원회, <b>어린이보호구역</b> 내 교통안전 캠페인",
# "originallink": "https://www.dnews.co.kr/uhtml/view.jsp?idxno=202107201043326800511",
# "link": "https://www.dnews.co.kr/uhtml/view.jsp?idxno=202107201043326800511",
# "description": "온양5동 주민자치위원회(위원장 오진용)는 지난 19일관내 용화초등학교 주변 <b>어린이보호구역</b> 내에서 교통안전 캠페인을 실시했다. 이번 캠페인은 <b>어린이</b> 교통사고 예방을 위해 <b>어린이 보호구역</b>에서 서행하기... ",
# "pubDate": "Tue, 20 Jul 2021 13:20:00 +0900"
#
# },
# {
# "title": "[현장르포] <b>어린이보호구역</b>내 과태료 상향에도 불법 주·정차 여전",
# "originallink": "http://www.kyeongin.com/main/view.php?key=20210718010003248",
# "link": "http://www.kyeongin.com/main/view.php?key=20210718010003248",
# "description": "지난 16일 오후 성남시 분당구 정자동 백현초등학교 정문 앞 <b>어린이보호구역</b>에 불법 주·정차가 심각한 모습이다. 2021.7.16 /신현정 기자 god@kyeongin.com <b>어린이보호구역</b> 내 불법 주·정차를 하면 부과되는 과태료가 두... ",
# "pubDate": "Sun, 18 Jul 2021 15:50:00 +0900"
#
# },
# {
# "title": "아산 온양5동 주민차치위, <b>어린이 보호구역</b> 내 교통안전캠페인",
# "originallink": "http://www.jbnews.com/news/articleView.html?idxno=1345034",
# "link": "http://www.jbnews.com/news/articleView.html?idxno=1345034",
# "description": "이날 캠페인은 개학철 <b>어린이</b> 교통사고 예방을 위해 <b>어린이 보호구역</b>에서 서행하기, 불법주정차 금지, <b>어린이</b> 통학버스 앞지르기 금지, 차량 신호 및 정지선 지키기 등 <b>어린이보호구역</b> 내 과속 등 엄정한 법집행과... ",
# "pubDate": "Mon, 19 Jul 2021 17:46:00 +0900"
#
# },
# {
# "title": "광양시, <b>어린이보호구역</b> 불법 주·정차 집중단속",
# "originallink": "http://www.newspim.com/news/view/20210728000639",
# "link": "http://www.newspim.com/news/view/20210728000639",
# "description": " 전남 광양시는 <b>어린이보호구역</b> 내 11개소에 고정형 단속 CCTV를 추가 설치해 오는 9월 1일부터 집중단속에 들어간다고 29일 밝혔다. 추가 설치 지역은 덕례초와 광양서초, 광양동초, 칠성초, 용강초, 마로초... ",
# "pubDate": "Wed, 28 Jul 2021 13:17:00 +0900"
#
# },
# {
# "title": "재개발 공사장 대형 가림막 <b>어린이 보호구역</b> 덮쳐",
# "originallink": "https://busanmbc.co.kr/article/sLytF2S4fJstX6lp",
# "link": "https://busanmbc.co.kr/article/sLytF2S4fJstX6lp",
# "description": "오늘(6) 오전 11시 반쯤, 수영구 광안동의 한 아파트 재개발 공사장에서 20여m 높이 공사장 가림막이 넘어져 <b>어린이 보호구역</b>을 덮쳤습니다. 다행히 인명 피해는 없었으며 업체 측이 크레인을 동원해 3시간가량 복구... ",
# "pubDate": "Fri, 06 Aug 2021 16:06:00 +0900"
#
# },
# {
# "title": "창원 <b>어린이보호구역</b> 내 노상주차장 11곳 폐쇄",
# "originallink": "http://www.idomin.com/news/articleView.html?idxno=767362",
# "link": "http://www.idomin.com/news/articleView.html?idxno=767362",
# "description": "창원지역 <b>어린이보호구역</b> 내 노상주차장 11곳 246면이 폐지된다. '<b>어린이보호구역</b>으로 지정된 경우 노상주차장을 폐지해야 한다'는 주차장법 개정안이 13일 시행된 데 따른 조치다. 폐지 예정 주차장은 마산합포구 4곳... ",
# "pubDate": "Mon, 19 Jul 2021 05:48:00 +0900"
#
# },
# {
# "title": "태백시, <b>어린이보호구역</b> 교통안전시설 개선 사업 추진",
# "originallink": "http://www.boannews.com/media/view.asp?idx=99154&kind=",
# "link": "http://www.boannews.com/media/view.asp?idx=99154&kind=",
# "description": "태백시는 <b>어린이</b>들의 안전한 통학로 조성을 위해 <b>어린이보호구역</b>에 교통안전시설 개선 사업을 추진한다. 시는 <b>어린이보호구역</b> 내 보행자 안전 확보를 위해 황지초등학교 등 4개소 <b>어린이보호구역</b>에 1억8,600만원 예산을... ",
# "pubDate": "Sat, 17 Jul 2021 09:08:00 +0900"
#
# },
# {
# "title": "전주시자원봉사센터, 초등학교에 ‘교통안전 투명우산’ 배부",
# "originallink": "https://www.geconomy.co.kr/news/article.html?no=153018",
# "link": "https://www.geconomy.co.kr/news/article.html?no=153018",
# "description": "또 운전자들의 <b>어린이 보호구역</b>에 대한 경각심을 높일 수 있도록 스쿨존 제한속도를 나타내 ‘는30㎞’와 ‘STOP’이라는 문구도 넣어졌다. 이날 행사에 참석한 전주녹색어머니연합회 회원들은 초등학생들의 교통안전... ",
# "pubDate": "Tue, 28 Sep 2021 13:45:00 +0900"
#
# },
# {
# "title": "장수경찰서, 스쿨존 안전 무빙툰 제작 언택트 홍보 실시",
# "originallink": "http://www.domin.co.kr/news/articleView.html?idxno=1355514",
# "link": "http://www.domin.co.kr/news/articleView.html?idxno=1355514",
# "description": "이번에 제작된 무빙툰은 스쿨존 내 등·하굣길 <b>어린이</b> 안전 확보를 위한 <b>어린이 보호구역</b> 내 안전운행 및 안전보행 관련 홍보를 내용으로 하고 있다. 장수서는 제작된 무빙툰을 교육청, 각 학교 홈페이지 게시 및 SNS 등... ",
# "pubDate": "Tue, 28 Sep 2021 20:12:00 +0900"
#
# },
# {
# "title": "고양교육지원청,‘고양시 교통안전협의체’ 실무회의 개최",
# "originallink": "https://www.siminilbo.co.kr/news/newsview.php?ncode=1065584875236246",
# "link": "https://www.siminilbo.co.kr/news/newsview.php?ncode=1065584875236246",
# "description": "이어서 고양시청에서는 2022년도 교통안전 주요예산 편성(안) 및 제4차 교통안전 기본계획수립을, 경찰서에서는 <b>어린이보호구역</b> 도로안전시설 개선 계획 및 초등학교 학생 승·하차 및 회차 장소 설치에 대하여... ",
# "pubDate": "Wed, 29 Sep 2021 17:18:00 +0900"
#
# },
# {
# "title": "증평군, <b>어린이보호구역</b> 교통안전도 도내 1위",
# "originallink": "https://www.news1.kr/articles/?4375834",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=421&aid=0005486256",
# "description": "충북 증평군이 도내에서 <b>어린이보호구역</b> 교통 환경이 가장 안전한 것으로 나타났다. 19일 군에 따르면 충북경찰청이 발표한 '<b>어린이보호구역</b>별 교통 환경 위험도' 평가 결과에서 증평군은 83.8점으로 도내 시·군 평균 74.... ",
# "pubDate": "Mon, 19 Jul 2021 10:21:00 +0900"
#
# },
# {
# "title": "국민권익위, 전라남도 관내 ‘교통안전 저해 도로변 가로수’ 전국 최초 일괄...",
# "originallink": "http://www.jejutwn.com/news/article.html?no=93668",
# "link": "http://www.jejutwn.com/news/article.html?no=93668",
# "description": "이를 알리기 위해 30일 오후 2시 전남 무안군 남악중학교 앞에서 이정희 국민권익위 부위원장, 문금주 전라남도 행정부지사, 김재규 전남경찰청장, 김산 무안군수가 참석한 가운데 <b>어린이보호구역</b> 내 속도제한 표지판을... ",
# "pubDate": "Thu, 30 Sep 2021 11:43:00 +0900"
#
# },
# {
# "title": "울산 북구 송정초 <b>어린이보호구역</b>, 위험천만 등하굣길 사고 우려",
# "originallink": "http://www.ksilbo.co.kr/news/articleView.html?idxno=907137",
# "link": "http://www.ksilbo.co.kr/news/articleView.html?idxno=907137",
# "description": "▲ 15일 북구 송정초등학교 인근에서 학생들이 <b>어린이 보호구역</b> 내 끊긴 인도로 통행하고 있다.울산 북구 송정초등학교 <b>어린이 보호구역</b> 일대 인도가 중간에 끊기고 차도와 맞닿아 있어 학생들의 안전사고 등 우려가... ",
# "pubDate": "Fri, 16 Jul 2021 00:12:00 +0900"
#
# },
# {
# "title": "'민식이법' 이후에도 불안…충북 <b>어린이보호구역</b> 38%만 '상급'",
# "originallink": "https://www.news1.kr/articles/?4372623",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=421&aid=0005479828",
# "description": "충북도내 <b>어린이보호구역</b> 교통 안전도를 점검한 결과 10곳 중 6곳 이상이 중·하 등급인 것으로 조사됐다. 15일 충북경찰청에 따르면 지난 3월2일~5월7일 도내 <b>어린이보호구역</b> 728곳을 대상으로 교통환경지수를 평가... ",
# "pubDate": "Thu, 15 Jul 2021 11:43:00 +0900"
#
# },
# {
# "title": "강동구, <b>어린이보호구역</b>에 태양광 과속경보 시스템 설치",
# "originallink": "http://news.heraldcorp.com/view.php?ud=20210715000094",
# "link": "https://news.naver.com/main/read.naver?mode=LSD&mid=sec&sid1=102&oid=016&aid=0001861653",
# "description": "서울 강동구(구청장 이정훈)는 <b>어린이보호구역</b> 내 <b>어린이</b>들의 안전한 보행 환경 조성을 위해 고덕초·선사초 2개소에 차량의 주행속도 감속을 유도하는 태양광 과속경보시스템을 설치했다고 15일 밝혔다. 태양광... ",
# "pubDate": "Thu, 15 Jul 2021 08:44:00 +0900"
#
# }
# ]
# }

# %%
#부정어사전 추가
n = pd.read_csv('../data/크롤링/사전/neg_pol_word.csv',sep='\n')
nag = []
for i in n['0']:
    nag.append(i)

# %%
#부정어사전 추가
p = pd.read_csv('../data/크롤링/사전/neg_pol_word.csv',sep='\n')
pos = []
for i in p['0']:
    pos.append(i)

#불용리스트 만들기
stopwords = ['보호','스쿨존','구역','노인','어린이','등','교통','곳','지정','안전','사업','일','시설','위해','및','년','장애인','위','경로당','설치','주변',
            '교통사고','보행자','보행','환경','도로','시','유치원','이번','중','조례','복지','차량','올해','애인','개','개소','억','관내',
            '의원','전국','발생','추가','이','물','월','원','확대','내','현재','광주','리','지역','최근','대전','것','지난해','초등학교','관','인구',
            '존','완료','대한','투입','공단','기자','대해','지난','마을','로','수','총','시행','조성','추진','공원','경찰정','경찰','충남',
            '회','또','군','신규','계획','안','광주시','시스템','생활','활동','중구','어르신','윤','실버','서울시회관','경우','통행','기준','어린이집',
            '진행','구','경기도','만','윤','복지관','아산시','대책','기관','인근','행사','점검','부과','지원','대폭','도시','억원','횡단보도','전통','도',
            '서울시','시장','회관','운영','가운데','민주당','공사','제조','요양원','개정','이상','규칙','고','지자체','앞','억만원','운전',
            '자동차','릴레이','광양시','주차장','린지','인천','위원회','사진','행정안전부','도로교통법','확보','우산','정착','캠페인','무인','주민',
            '보험','울타리','문화','전남','청장','를','우선','체결','확산','주민','무인','경찰청','초록','현대차','충북','국비','통해','합동대선',
            '사고','교체','내용','경기','최','한국','대표','나눔','건','계층','폐지','자녀','봉사','자치','달','스프링','시작',
            '국토교통부','제공','건','대구','손해','본부장','어린이재단','판','숲','서울특별시','협약','국민']

#불용어사전 추가
for i in stopwords:
    pos.append(i)

# %%
#분리
def get_tags(text, ntags=50):
    spliter = Okt()
    nouns = spliter.nouns(text)
    count = Counter(nouns)
    words = dict(count.most_common(ntags))
    
    #불용어 사전안에 있으면 삭제
    for i in pos:
        if i in words:
            del words[i]
    return words

# %%
rtags = get_tags(rtext, ntags=400)
# print(rtags)

Wordcloud(rtags, '어린이보호구역','../data/WordCloud/mask/mask3.jpeg')
