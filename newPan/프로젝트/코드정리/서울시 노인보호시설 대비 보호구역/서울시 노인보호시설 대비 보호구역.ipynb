# %%
import warnings
warnings.filterwarnings(action='ignore') 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import matplotlib
import platform
import seaborn as sns 
import matplotlib
matplotlib.rcParams['font.family']
if platform.system() == 'Windows':
    matplotlib.rc('font', family='Malgun Gothic')
    #Malgun 
# %matplotlib inline

# %%
df1 = pd.read_csv('../data/노인보호시설 대비 보호구역/서울특별시 사회복지시설(노인여가복지시설) 목록.csv',encoding='cp949')
df2 = pd.read_csv('../data/노인보호시설 대비 보호구역/서울특별시 경로당 정보.csv')
df_m = pd.read_csv('../data/노인보호시설 대비 보호구역/서울시 전통시장 현황.csv')

# %%
df1.head()
# Out:
#               시설명   시설코드      시설종류명(시설유형) 시설종류상세명(시설종류) 자치구(시)구분  시설장명  \
# 0  성북구립 상월곡실버복지센터  A0495  (노인) 노인복지관(소규모)      노인여가복지시설      자치구   김경회
# 1   서초구립양재노인종합복지관  A0724       (노인) 노인복지관      노인여가복지시설      자치구  전경아
# 2   강서구립봉제산노인복지센터  A0922  (노인) 노인복지관(소규모)      노인여가복지시설      자치구   서순애
# 3     시립중랑노인종합복지관  A1022       (노인) 노인복지관      노인여가복지시설      자치구   조희정
# 4   강남구립강남노인종합복지관  A1165       (노인) 노인복지관      노인여가복지시설      자치구   고영한
#
#         시군구코드 시군구명                                   시설주소
# 0  1129000000  성북구              서울특별시 성북구 화랑로18길 6 (상월곡동)
# 1  1165000000  서초구  서울특별시 서초구 강남대로30길 73-7양재노인종합복지관 (양재동)
# 2  1150000000  강서구                  서울특별시 강서구 초록마을로15길 12
# 3  1126000000  중랑구                서울특별시 중랑구 겸재로9길 45(면목동)
# 4  1168000000  강남구       서울특별시 강남구 삼성로 628강남노인종합복지관 (삼성동)

# %%
df2
# Out:
#         번호               사업장명                       소재지전체주소  도로명전체주소  \
# 0     3745       정릉꿈에그린(아)경로당         서울특별시 성북구 정릉동 정릉꿈에그린       NaN
# 1     3744       구파발10단 제3경로당       서울특별시 은평구 진관동 은평뉴타운구파발       NaN
# 2     3743        아현 아이파크 경로당           서울특별시 마포구 아현동 104동       NaN
# 3     3742  상암월드컵파크12단지(아)경로당    서울특별시 마포구 상암동 상암월드컵파크12단지       NaN
# 4     3741    상암월드컵파크11단지 경로당    서울특별시 마포구 상암동 상암월드컵파크11단지       NaN
# ...    ...                ...                           ...      ...
# 3740     5        마곡엠밸리6단지경로당                서울특별시 강서구 마곡동       NaN
# 3741     4              큰덕경로당                서울특별시 마포구 공덕동       NaN
# 3742     3          구립양평3가경로당        서울특별시 영등포구 양평동3가 36번지       NaN
# 3743     2   백련산힐스테이트1차아파트경로당                서울특별시 은평구 응암동       NaN
# 3744     1   백련산힐스테이트2차아파트경로당  서울특별시 은평구 응암동 백련산힐스테이트2차아파트       NaN
#
#          인허가일자 영업상태명  폐업일자  휴업시작일자  휴업종료일자  재개업일자  소재지면적  소재지우편번호  입소정원  \
# 0     20170808   운영중   NaN     NaN     NaN    NaN    NaN      NaN   NaN
# 1     20121212   운영중   NaN     NaN     NaN    NaN    NaN      NaN  22.0
# 2     20180406   운영중   NaN     NaN     NaN    NaN    NaN      NaN  23.0
# 3     20110414   운영중   NaN     NaN     NaN    NaN    NaN      NaN   NaN
# 4     20121024   운영중   NaN     NaN     NaN    NaN    NaN      NaN  36.0
# ...        ...   ...   ...     ...     ...    ...    ...      ...   ...
# 3740  20160801   운영중   NaN     NaN     NaN    NaN    NaN      NaN  58.0
# 3741  20111014   운영중   NaN     NaN     NaN    NaN    NaN      NaN   0.0
# 3742  19890706   운영중   NaN     NaN     NaN    NaN    NaN      NaN   0.0
# 3743  20131121   운영중   NaN     NaN     NaN    NaN    NaN      NaN   0.0
# 3744  20121009   운영중   NaN     NaN     NaN    NaN    NaN      NaN   NaN
#
#       자격소유인원수  총인원수      위치정보(X)      위치정보(Y)         인허가번호 상세영업상태명
# 0         NaN   NaN          NaN          NaN  3.070000e+15      운영
# 1         NaN   NaN          NaN          NaN  3.110000e+15      운영
# 2         NaN   NaN          NaN          NaN  3.130000e+15      운영
# 3         NaN   NaN          NaN          NaN  3.130000e+15      운영
# 4         NaN   NaN          NaN          NaN  3.130000e+15      운영
# ...       ...   ...          ...          ...           ...     ...
# 3740      NaN   NaN          NaN          NaN  3.150000e+15      운영
# 3741      NaN   NaN          NaN          NaN  3.130000e+15      운영
# 3742      NaN   NaN  189979.7788  447187.5807  3.180000e+15      운영
# 3743      NaN   NaN          NaN          NaN  3.110000e+15      운영
# 3744      NaN   NaN          NaN          NaN  3.110000e+15      운영
#
# [3745 rows x 19 columns]

# %%
df3 = pd.read_csv('../data/노인보호시설 대비 보호구역/서울시 년도별 노인보호구역 지정현황.csv')
df3
# Out:
#       연번  자치구             시설명   위치   지정일  비고
# 0      1  종로구       종로노인종합복지관  이화동  2009
# 1      2  종로구  종로노인종합복지관 무악센터  무악동  2016
# 2      3  종로구        서울노인복지센터  경운동  2016
# 3      4  종로구            락희거리  낙원동  2017
# 4      5  종로구     종묘광장공원 동순라길  인의동  2018
# ..   ...  ...             ...  ...   ...  ..
# 158  159  강동구          성내천경로당  성내동  2014
# 159  160  강동구       성암장수마을요양원  성내동  2016
# 160  161  강동구       강동노인종합복지관  명일동  2018
# 161  162  강동구           쉼터경로당  천호동  2019
# 162  163  강동구         구립강암경로당  암사동  2020
#
# [163 rows x 6 columns]

# %%
# count = [[len(df1)+len(df2)],[len(df3)]]
# count
count = [len(df1)+len(df2)+len(df_m),len(df3)]

# %%
columns = ['노인 이용시설','노인 보호구역']

# %%
all = pd.DataFrame(count)

# %%
all = all.T
all
# Out:
#       0    1
# 0  3842  163

# %%
all.columns = columns

# %%
all
# Out:
#    노인 이용시설  노인 보호구역
# 0     3842      163

# %%
all = all.T

# %%
all.columns = ['갯수']

# %%
all.index
# Out:
# Index(['노인 이용시설', '노인 보호구역'], dtype='object')

# %%
import matplotlib.pyplot as plt

data = all['갯수']
colors = ['#99CCFF', '#AAB9FF']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}
plt.title('노인 보호구역과 노인 이용시설 비교 ')
plt.pie(data,labels=all.index, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.show()
