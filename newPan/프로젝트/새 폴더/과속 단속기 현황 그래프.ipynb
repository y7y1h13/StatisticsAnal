# %%
#과속+신호,과속,신호 3개 한개로 묶기, 총 3가지 그래프 보여주기

# %%
import warnings
warnings.filterwarnings(action='ignore') 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import matplotlib
import platform
import seaborn as sns 
import matplotlib
matplotlib.rcParams['font.family']
if platform.system() == 'Windows':
    matplotlib.rc('font', family='Malgun Gothic')
    #Malgun 
# %matplotlib inline

# %%
df1 = pd.read_csv('./노인무인단속장비.csv')
df2 = pd.read_csv('./어린이무인단속장비 현황 (1).csv')

# %%
df1
# Out:
#        시도    계  과속+신호  과속  신호  주정차   방범
# 0     서울시  128      4   0   1   18  105
# 1   종   로    4      0   0   0    1    3
# 2   중   구   19      0   0   0    6   13
# 3   용   산    2      1   0   0    0    1
# 4   성   동    6      0   0   0    4    2
# 5   광   진    1      0   0   0    1    0
# 6     동대문    3      0   0   0    0    3
# 7   중   랑    4      0   0   0    0    4
# 8   성   북    0      0   0   0    0    0
# 9   강   북    0      0   0   0    0    0
# 10  도   봉    0      0   0   0    0    0
# 11  노   원    2      0   0   1    0    1
# 12  은   평   44      1   0   0    0   43
# 13    서대문    1      0   0   0    0    1
# 14  마   포    0      0   0   0    0    0
# 15  양   천    5      1   0   0    1    3
# 16  강   서    0      0   0   0    0    0
# 17  구   로    0      0   0   0    0    0
# 18  금   천    0      0   0   0    0    0
# 19    영등포    3      1   0   0    2    0
# 20  동   작    0      0   0   0    0    0
# 21  관   악   11      0   0   0    3    8
# ...

# %%
df1 == ' '
# Out:
#        시도      계  과속+신호     과속     신호    주정차     방범
# 0   False  False  False  False  False  False  False
# 1   False  False  False  False  False  False  False
# 2   False  False  False  False  False  False  False
# 3   False  False  False  False  False  False  False
# 4   False  False  False  False  False  False  False
# 5   False  False  False  False  False  False  False
# 6   False  False  False  False  False  False  False
# 7   False  False  False  False  False  False  False
# 8   False  False  False  False  False  False  False
# 9   False  False  False  False  False  False  False
# 10  False  False  False  False  False  False  False
# 11  False  False  False  False  False  False  False
# 12  False  False  False  False  False  False  False
# 13  False  False  False  False  False  False  False
# 14  False  False  False  False  False  False  False
# 15  False  False  False  False  False  False  False
# 16  False  False  False  False  False  False  False
# ...

# %%
df1.fillna(0)
# Out:
#        시도    계  과속+신호  과속  신호  주정차   방범
# 0     서울시  128      4   0   1   18  105
# 1   종   로    4      0   0   0    1    3
# 2   중   구   19      0   0   0    6   13
# 3   용   산    2      1   0   0    0    1
# 4   성   동    6      0   0   0    4    2
# 5   광   진    1      0   0   0    1    0
# 6     동대문    3      0   0   0    0    3
# 7   중   랑    4      0   0   0    0    4
# 8   성   북    0      0   0   0    0    0
# 9   강   북    0      0   0   0    0    0
# 10  도   봉    0      0   0   0    0    0
# 11  노   원    2      0   0   1    0    1
# 12  은   평   44      1   0   0    0   43
# 13    서대문    1      0   0   0    0    1
# 14  마   포    0      0   0   0    0    0
# 15  양   천    5      1   0   0    1    3
# 16  강   서    0      0   0   0    0    0
# 17  구   로    0      0   0   0    0    0
# 18  금   천    0      0   0   0    0    0
# 19    영등포    3      1   0   0    2    0
# 20  동   작    0      0   0   0    0    0
# 21  관   악   11      0   0   0    3    8
# ...

# %%
# df1['과속+신호'] = df1['과속+신호'].str.replace(' ','0')
# df1['과속'] = df1['과속'].str.replace(' ','0')
# df1['신호'] = df1['신호'].str.replace(' ','0')
# df1['주정차'] = df1['주정차'].str.replace(' ','0')
# df1['방범'] = df1['방범'].str.replace(' ','0')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시도      26 non-null     object
#  1   계       26 non-null     int64
#  2   과속+신호   26 non-null     int64
#  3   과속      26 non-null     int64
#  4   신호      26 non-null     int64
#  5   주정차     26 non-null     int64
#  6   방범      26 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 1.5+ KB

# %%
df1 = df1.astype({'시도':'object','계':'int64','과속+신호':'int64','과속':'int64','신호':'int64','주정차':'int64','방범':'int64'})

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시도      26 non-null     object
#  1   계       26 non-null     int64
#  2   과속+신호   26 non-null     int64
#  3   과속      26 non-null     int64
#  4   신호      26 non-null     int64
#  5   주정차     26 non-null     int64
#  6   방범      26 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 1.5+ KB

# %%
df1['과속+신호 all'] = df1['과속+신호']+df1['과속']+df1['신호']
df1
# Out:
#        시도    계  과속+신호  과속  신호  주정차   방범  과속+신호 all
# 0     서울시  128      4   0   1   18  105          5
# 1   종   로    4      0   0   0    1    3          0
# 2   중   구   19      0   0   0    6   13          0
# 3   용   산    2      1   0   0    0    1          1
# 4   성   동    6      0   0   0    4    2          0
# 5   광   진    1      0   0   0    1    0          0
# 6     동대문    3      0   0   0    0    3          0
# 7   중   랑    4      0   0   0    0    4          0
# 8   성   북    0      0   0   0    0    0          0
# 9   강   북    0      0   0   0    0    0          0
# 10  도   봉    0      0   0   0    0    0          0
# 11  노   원    2      0   0   1    0    1          1
# 12  은   평   44      1   0   0    0   43          1
# 13    서대문    1      0   0   0    0    1          0
# 14  마   포    0      0   0   0    0    0          0
# 15  양   천    5      1   0   0    1    3          1
# 16  강   서    0      0   0   0    0    0          0
# ...

# %%
df1 = df1.drop(['시도','계','과속+신호','과속','신호'], axis=1)

# %%
df1
# Out:
#     주정차   방범  과속+신호 all
# 0    18  105          5
# 1     1    3          0
# 2     6   13          0
# 3     0    1          1
# 4     4    2          0
# 5     1    0          0
# 6     0    3          0
# 7     0    4          0
# 8     0    0          0
# 9     0    0          0
# 10    0    0          0
# 11    0    1          1
# 12    0   43          1
# 13    0    1          0
# 14    0    0          0
# 15    1    3          1
# 16    0    0          0
# 17    0    0          0
# 18    0    0          0
# 19    2    0          1
# 20    0    0          0
# 21    3    8          0
# 22    0    2          0
# 23    0   13          0
# 24    0    6          0
# 25    0    2          0

# %%
pd.DataFrame(df1).to_csv('old.csv')

# %%
df2
# Out:
#        시도     계  과속+신호  과속  신호  주정차    방범
# 0     서울시  4725    343  94   1  664  3623
# 1   종   로    25      0   0   0    0    25
# 2   중   구   236      5   0   0   18   213
# 3   용   산    86      0   1   1    7    77
# 4   성   동   193     32   1   0   29   131
# 5   광   진   232     14   2   0   11   205
# 6     동대문   105     14  11   0    3    77
# 7   중   랑   155     11   2   0   24   118
# 8   성   북   144     23   4   0   89    28
# 9   강   북   193     16   2   0   81    94
# 10  도   봉   131     20   4   0   46    61
# 11  노   원   258      2   0   0   49   207
# 12  은   평   676      3  13   0   22   638
# 13    서대문   102     19  11   0   36    36
# 14  마   포   107     12   1   0    8    86
# 15  양   천   290     21   9   0   22   238
# 16  강   서   129      3   1   0    1   124
# 17  구   로   237     36   3   0   23   175
# 18  금   천    60      0  11   0    0    49
# 19    영등포   204      4   0   0   27   173
# 20  동   작   140     16   7   0    4   113
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시도      26 non-null     object
#  1   계       26 non-null     int64
#  2   과속+신호   26 non-null     int64
#  3   과속      26 non-null     int64
#  4   신호      26 non-null     int64
#  5   주정차     26 non-null     int64
#  6   방범      26 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 1.5+ KB

# %%
df2['과속+신호 all'] = df2['과속+신호']+df2['과속']+df2['신호']
df2
# Out:
#        시도     계  과속+신호  과속  신호  주정차    방범  과속+신호 all
# 0     서울시  4725    343  94   1  664  3623        438
# 1   종   로    25      0   0   0    0    25          0
# 2   중   구   236      5   0   0   18   213          5
# 3   용   산    86      0   1   1    7    77          2
# 4   성   동   193     32   1   0   29   131         33
# 5   광   진   232     14   2   0   11   205         16
# 6     동대문   105     14  11   0    3    77         25
# 7   중   랑   155     11   2   0   24   118         13
# 8   성   북   144     23   4   0   89    28         27
# 9   강   북   193     16   2   0   81    94         18
# 10  도   봉   131     20   4   0   46    61         24
# 11  노   원   258      2   0   0   49   207          2
# 12  은   평   676      3  13   0   22   638         16
# 13    서대문   102     19  11   0   36    36         30
# 14  마   포   107     12   1   0    8    86         13
# 15  양   천   290     21   9   0   22   238         30
# 16  강   서   129      3   1   0    1   124          4
# ...

# %%
df2.fillna(0)
# Out:
#        시도     계  과속+신호  과속  신호  주정차    방범  과속+신호 all
# 0     서울시  4725    343  94   1  664  3623        438
# 1   종   로    25      0   0   0    0    25          0
# 2   중   구   236      5   0   0   18   213          5
# 3   용   산    86      0   1   1    7    77          2
# 4   성   동   193     32   1   0   29   131         33
# 5   광   진   232     14   2   0   11   205         16
# 6     동대문   105     14  11   0    3    77         25
# 7   중   랑   155     11   2   0   24   118         13
# 8   성   북   144     23   4   0   89    28         27
# 9   강   북   193     16   2   0   81    94         18
# 10  도   봉   131     20   4   0   46    61         24
# 11  노   원   258      2   0   0   49   207          2
# 12  은   평   676      3  13   0   22   638         16
# 13    서대문   102     19  11   0   36    36         30
# 14  마   포   107     12   1   0    8    86         13
# 15  양   천   290     21   9   0   22   238         30
# 16  강   서   129      3   1   0    1   124          4
# ...

# %%
df2 = df2.drop(['시도','계','과속+신호','과속','신호'], axis=1)
df2
# Out:
#     주정차    방범  과속+신호 all
# 0   664  3623        438
# 1     0    25          0
# 2    18   213          5
# 3     7    77          2
# 4    29   131         33
# 5    11   205         16
# 6     3    77         25
# 7    24   118         13
# 8    89    28         27
# 9    81    94         18
# 10   46    61         24
# 11   49   207          2
# 12   22   638         16
# 13   36    36         30
# 14    8    86         13
# 15   22   238         30
# 16    1   124          4
# 17   23   175         39
# 18    0    49         11
# 19   27   173          4
# 20    4   113         23
# 21   64   165         29
# 22   34    86         21
# 23   54   185         24
# 24    8   180         25
# 25    4   139          4

# %%
df2.fillna(0)
# Out:
#     주정차    방범  과속+신호 all
# 0   664  3623        438
# 1     0    25          0
# 2    18   213          5
# 3     7    77          2
# 4    29   131         33
# 5    11   205         16
# 6     3    77         25
# 7    24   118         13
# 8    89    28         27
# 9    81    94         18
# 10   46    61         24
# 11   49   207          2
# 12   22   638         16
# 13   36    36         30
# 14    8    86         13
# 15   22   238         30
# 16    1   124          4
# 17   23   175         39
# 18    0    49         11
# 19   27   173          4
# 20    4   113         23
# 21   64   165         29
# 22   34    86         21
# 23   54   185         24
# 24    8   180         25
# 25    4   139          4

# %%
pd.DataFrame(df1).to_csv('kids.csv')

# %%
print(df1[:1])
print(df2[:1])
# Out:
#    주정차   방범  과속+신호 all
# 0   18  105          5
#    주정차    방범  과속+신호 all
# 0  664  3623        438

# %%
all=df1.iloc[:1]
all
# Out:
#    주정차   방범  과속+신호 all
# 0   18  105          5

# %%
all1 = df2.iloc[:1]
all1
# Out:
#    주정차    방범  과속+신호 all
# 0  664  3623        438

# %%
all_df = pd.concat([all,all1], axis=0)
all_df
# Out:
#    주정차    방범  과속+신호 all
# 0   18   105          5
# 0  664  3623        438

# %%
all_df = all_df.reset_index()
all_df
# Out:
#    index  주정차    방범  과속+신호 all
# 0      0   18   105          5
# 1      0  664  3623        438

# %%
all_df = all_df.drop(['index'], axis=1)
all_df
# Out:
#    주정차    방범  과속+신호 all
# 0   18   105          5
# 1  664  3623        438

# %%
all_df = all_df.reindex(columns=['과속+신호 all','주정차','방범'])

# %%
all_df = all_df.T
all_df
# Out:
#              0     1
# 과속+신호 all    5   438
# 주정차         18   664
# 방범         105  3623

# %%
all_df.columns = ['노인','어린이']
all_df
# Out:
#             노인   어린이
# 과속+신호 all    5   438
# 주정차         18   664
# 방범         105  3623

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 과속+신호 all to 방범
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   노인      3 non-null      int64
#  1   어린이     3 non-null      int64
# dtypes: int64(2)
# memory usage: 72.0+ bytes

# %%
all_df = all_df.T
all_df
# Out:
#      과속+신호 all  주정차    방범
# 노인           5   18   105
# 어린이        438  664  3623

# %%
all_df.index
# Out:
# Index(['노인', '어린이'], dtype='object')

# %%
print (type(all_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
plt.rcParams["figure.figsize"] = (14,7)
plt.rcParams['font.size'] = 12
ax = all_df.plot.bar(y=['주정차','방범','과속+신호 all'],rot=0,color=['r','c','b'],width=0.8)
for temp in ax.patches:
    ax.annotate('%d'%temp.get_height(),(temp.get_x()+temp.get_width()/2 , temp.get_height()) , ha = 'center' , va='bottom',fontsize=13)
    plt.title('노인과 어린이 cctv 개수 비교')
plt.show()

# %%
# plt.rcParams["figure.figsize"] = (14,7)
# plt.rcParams['font.size'] = 12
# ax = all_df.plot.bar(y=['노인','어린이'],rot=0,color=['r','c'],width=0.8)
# for temp in ax.patches:
#     ax.annotate('%d'%temp.get_height(),(temp.get_x()+temp.get_width()/2 , temp.get_height()) , ha = 'center' , va='bottom',fontsize=13)
# plt.show()

# %%
all_df.plot(kind='barh')
plt.title('노인과 어린이 과속단속 비교')
plt.xlabel("데이터 값")
plt.show()

# %%
import matplotlib.pyplot as plt

ratio = [128, 3623]
labels = ['노인', '어린이']
explode = [0.05, 0.05]
plt.title('노인과 어린이 과속단속 비교')
plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True)
plt.show()

# %%
all_df.index
# Out:
# Index(['노인', '어린이'], dtype='object')

# %%
keyword = input('입력:')
data = all_df[keyword]
colors = ['#FF73BE', '#AAB9FF']
wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}
plt.title('노인, 어린이 보호구역 ' +keyword +' 단속카메라 현황')
plt.pie(data,labels=all_df.index, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops)
plt.show()
# Out:
# 입력:방범

# %%
# import matplotlib.pyplot as plt


# ratio = [128, 3623]
# labels = ['노인', '어린이']
# colors = ['#FF73BE', '#AAB9FF']
# wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 5}

# plt.pie(ratio, labels=all_df.columns, autopct='%.1f%%', startangle=260, counterclock=False, colors=colors, wedgeprops=wedgeprops)
# plt.show()

# %%
plt.pie(all_df['방범'], labels=all_df.index, autopct='%1f%%', startangle=200)
# Out:
# ([<matplotlib.patches.Wedge at 0x2d1905263d0>,
# ...
#  [Text(-0.9963719584131691, -0.46609325299547755, '노인'),
#   Text(0.9963719365937679, 0.46609329963901497, '어린이')],
#  [Text(-0.5434756136799104, -0.25423268345207867, '2.816524%'),
#   Text(0.5434756017784188, 0.2542327088940081, '97.183478%')])
